# %%
# !pip install segyio
# !pip install segysak
# !pip install patchify
# !pip install segmentation_models_3D
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segyio
#   Downloading segyio-1.9.9-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.0 MB/s
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from segyio) (1.21.6)
# Installing collected packages: segyio
# Successfully installed segyio-1.9.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segysak
#   Downloading segysak-0.3.4-py3-none-any.whl (310 kB)
#      |████████████████████████████████| 310 kB 8.1 MB/s
# Requirement already satisfied: more-itertools>=8.0 in /usr/local/lib/python3.7/dist-packages (from segysak) (8.14.0)
# Requirement already satisfied: xarray in /usr/local/lib/python3.7/dist-packages (from segysak) (0.20.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.7.3)
# Requirement already satisfied: distributed in /usr/local/lib/python3.7/dist-packages (from segysak) (1.25.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from segysak) (1.3.5)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: segyio in /usr/local/lib/python3.7/dist-packages (from segysak) (1.9.9)
# Collecting setuptools-scm
#   Downloading setuptools_scm-7.0.5-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.7 MB/s
# Requirement already satisfied: dask in /usr/local/lib/python3.7/dist-packages (from segysak) (2.12.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from segysak) (7.1.2)
# Collecting h5netcdf
#   Downloading h5netcdf-1.0.2-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from segysak) (4.64.0)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.7.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.3.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.0.4)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.1.1)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.4.8)
# Requirement already satisfied: toolz>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (0.12.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.15.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (3.13)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.2.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.4.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed->segysak) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (21.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->h5netcdf->segysak) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->h5netcdf->segysak) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2.8.2)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (2.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.1.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.12.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (57.4.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->setuptools-scm->segysak) (3.8.1)
# Installing collected packages: setuptools-scm, h5netcdf, addict, segysak
# Successfully installed addict-2.4.0 h5netcdf-1.0.2 segysak-0.3.4 setuptools-scm-7.0.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.21.6)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation_models_3D
#   Downloading segmentation_models_3D-1.0.4-py3-none-any.whl (33 kB)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.5 MB/s
# Collecting classification-models-3D>=1.0.6
#   Downloading classification_models_3D-1.0.6-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.7 MB/s
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_3D) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (1.21.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (3.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.6.3)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.47.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.17.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.26.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (4.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (57.4.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.2)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (14.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.2.0)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.5.3)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->segmentation_models_3D) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->segmentation_models_3D) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.0.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.8)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.24.3)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.2.0)
# Installing collected packages: keras-applications, classification-models-3D, segmentation-models-3D
# Successfully installed classification-models-3D-1.0.6 keras-applications-1.0.8 segmentation-models-3D-1.0.4

# %%
import tensorflow as tf
import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.8.2
# 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import segyio
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import segmentation_models_3D as sm
from patchify import patchify, unpatchify
import Augment as a
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam
from keras.models import load_model
from segysak.segy import segy_header_scan, segy_header_scrape, get_segy_texthead, segy_loader
from keras.metrics import MeanIoU
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from matplotlib.colors import LinearSegmentedColormap
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19
from keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
# Out:
# /usr/local/lib/python3.7/dist-packages/segysak/segy/_segy_core.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Normalization
def normalization(data, clip_factor=2.5):
  clipFactor = clip_factor
  std0 = np.std(data)
  stdClip = std0 * clipFactor
  clippedCube = np.clip(data, -stdClip, +stdClip)
  return np.asarray(clippedCube / stdClip, dtype='single')

# %% [markdown]
# ## Dataset Preparation

# %%
train_seismic_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/train/seis'
train_fault_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/train/fault'

valid_seismic_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/validation/seis'
valid_fault_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/validation/fault'

# %%
train_seis_input = []
train_fault_output = []

index = [0, 63, 127]
for i in os.listdir(train_seismic_path):
  for j in index:
    # iline
    train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    # xline
    train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])
    train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])

# %%
valid_seis_input = []
valid_fault_output = []

for i in os.listdir(valid_seismic_path):
  for j in index:
    # iline
    valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    # xline
    valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])
    valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])

# %%
np.array(train_seis_input).tofile('/content/drive/MyDrive/UTP_dGB_Documents/data/train/seis/1200.dat')
np.array(train_fault_output).tofile('/content/drive/MyDrive/UTP_dGB_Documents/data/train/fault/1200.dat')

# %%
np.array(valid_seis_input).tofile('/content/drive/MyDrive/UTP_dGB_Documents/data/validation/seis/1200.dat')
np.array(valid_fault_output).tofile('/content/drive/MyDrive/UTP_dGB_Documents/data/validation/fault/1200.dat')

# %% [markdown]
# ## Data Augmentation

# %%
train_seis_input = np.reshape(np.fromfile('/content/drive/MyDrive/UTP_dGB_Documents/data/train/seis/1200.dat', dtype=np.single), (1200, 128, 128))
train_fault_output = np.reshape(np.fromfile('/content/drive/MyDrive/UTP_dGB_Documents/data/train/fault/1200.dat', dtype=np.single), (1200, 128, 128))
valid_seis_input = np.reshape(np.fromfile('/content/drive/MyDrive/UTP_dGB_Documents/data/validation/seis/1200.dat', dtype=np.single), (120, 128, 128))
valid_fault_output = np.reshape(np.fromfile('/content/drive/MyDrive/UTP_dGB_Documents/data/validation/fault/1200.dat', dtype=np.single), (120, 128, 128))

# %%
aug = a.Augment()

# %%
train_seis_input_gds = []
train_fault_output_gds = []

for i in range(len(train_seis_input)):
  p1 = train_seis_input[i, :, :]
  t1 = train_fault_output[i, :, :]
  aug_result = aug.GridDistort(p1, t1)
  train_seis_input_gds.append(aug_result[0])
  train_fault_output_gds.append(aug_result[1])

# %%
train_seis_input_shr = []
train_fault_output_shr = []

for i in range(len(train_seis_input)):
  p1 = train_seis_input[i, :, :]
  t1 = train_fault_output[i, :, :]
  aug_result = aug.Sharpen(p1, t1)
  train_seis_input_shr.append(aug_result[0])
  train_fault_output_shr.append(aug_result[1])

# %%
train_seis_input_aug = np.append(train_seis_input_gds, np.array(train_seis_input_shr), axis=0)
train_fault_output_aug = np.append(train_fault_output_gds, np.array(train_fault_output_shr), axis=0)

# %%
train_seis_input = np.append(train_seis_input, train_seis_input_aug, axis=0)
train_fault_output = np.append(train_fault_output, train_fault_output_aug, axis=0)

# %%
X_train = np.stack((train_seis_input,)*3, axis=-1)
X_test = np.stack((valid_seis_input,)*3, axis=-1)

train_mask = np.expand_dims(train_fault_output, axis=3)
y_train = tf.keras.utils.to_categorical(train_mask, num_classes=2)
test_mask = np.expand_dims(valid_fault_output, axis=3)
y_test = tf.keras.utils.to_categorical(test_mask, num_classes=2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (3600, 128, 128, 3)
# (120, 128, 128, 3)
# (3600, 128, 128, 2)
# (120, 128, 128, 2)

# %%
X_train_norm = normalization(X_train)
X_test_norm = normalization(X_test)

# %%
fig, ax = plt.subplots(1, 2, figsize=(5,5))
ax[0].imshow(X_train_norm[1, :, :, 1].T, cmap='Greys')
ax[1].imshow(y_train[1, :, :, 1].T, cmap='Greys_r')
fig.suptitle('Training Dataset')
plt.show()

# %% [markdown]
# ## Training

# %% [markdown]
# ##### UNet

# %%
batch_size = 8
image_size = 128

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %%
def UNet():
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    # encoder
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    # bridge
    bn = bottleneck(p4, f[4])
    
    # decoder
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model_unet = UNet()
model_unet.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
plot_model(model_unet)

# %%
train_steps = len(X_train_norm)//batch_size
valid_steps = len(X_test_norm)//batch_size

# %%
history_1 = model_unet.fit(X_train_norm, 
                    y_train,
                    batch_size=batch_size, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test_norm, y_test), ) # callbacks=EarlyStopping(monitor='val_acc', mode='max',patience=10))
# Out:
# Epoch 1/100
# 450/450 [==============================] - 23s 21ms/step - loss: 0.2002 - acc: 0.9404 - val_loss: 0.1506 - val_acc: 0.9505
# Epoch 2/100
# 450/450 [==============================] - 10s 21ms/step - loss: 0.1296 - acc: 0.9554 - val_loss: 0.1203 - val_acc: 0.9576
# Epoch 3/100
# 450/450 [==============================] - 10s 21ms/step - loss: 0.1136 - acc: 0.9596 - val_loss: 0.1202 - val_acc: 0.9595
# Epoch 4/100
# 450/450 [==============================] - 10s 21ms/step - loss: 0.1060 - acc: 0.9613 - val_loss: 0.1084 - val_acc: 0.9614
# Epoch 5/100
# 450/450 [==============================] - 10s 21ms/step - loss: 0.0991 - acc: 0.9629 - val_loss: 0.1065 - val_acc: 0.9616
# Epoch 6/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0949 - acc: 0.9639 - val_loss: 0.1250 - val_acc: 0.9616
# Epoch 7/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0880 - acc: 0.9654 - val_loss: 0.1060 - val_acc: 0.9626
# Epoch 8/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0833 - acc: 0.9666 - val_loss: 0.1081 - val_acc: 0.9620
# Epoch 9/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0790 - acc: 0.9678 - val_loss: 0.1207 - val_acc: 0.9634
# Epoch 10/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0765 - acc: 0.9687 - val_loss: 0.1097 - val_acc: 0.9627
# Epoch 11/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0706 - acc: 0.9704 - val_loss: 0.1326 - val_acc: 0.9630
# Epoch 12/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0679 - acc: 0.9713 - val_loss: 0.1250 - val_acc: 0.9634
# Epoch 13/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0647 - acc: 0.9725 - val_loss: 0.1310 - val_acc: 0.9625
# Epoch 14/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0615 - acc: 0.9738 - val_loss: 0.1350 - val_acc: 0.9636
# Epoch 15/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0582 - acc: 0.9751 - val_loss: 0.1574 - val_acc: 0.9635
# Epoch 16/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0564 - acc: 0.9757 - val_loss: 0.1388 - val_acc: 0.9622
# Epoch 17/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0565 - acc: 0.9758 - val_loss: 0.1422 - val_acc: 0.9618
# Epoch 18/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0546 - acc: 0.9765 - val_loss: 0.1505 - val_acc: 0.9623
# Epoch 19/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0524 - acc: 0.9775 - val_loss: 0.1494 - val_acc: 0.9622
# Epoch 20/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0510 - acc: 0.9781 - val_loss: 0.1515 - val_acc: 0.9630
# Epoch 21/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0492 - acc: 0.9788 - val_loss: 0.1769 - val_acc: 0.9620
# Epoch 22/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0471 - acc: 0.9797 - val_loss: 0.1668 - val_acc: 0.9630
# Epoch 23/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0468 - acc: 0.9799 - val_loss: 0.1846 - val_acc: 0.9622
# Epoch 24/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0460 - acc: 0.9803 - val_loss: 0.1847 - val_acc: 0.9624
# Epoch 25/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0452 - acc: 0.9806 - val_loss: 0.1508 - val_acc: 0.9612
# Epoch 26/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0486 - acc: 0.9793 - val_loss: 0.1485 - val_acc: 0.9612
# Epoch 27/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0464 - acc: 0.9802 - val_loss: 0.1927 - val_acc: 0.9625
# Epoch 28/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0416 - acc: 0.9821 - val_loss: 0.1856 - val_acc: 0.9623
# Epoch 29/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0407 - acc: 0.9826 - val_loss: 0.1861 - val_acc: 0.9625
# Epoch 30/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0408 - acc: 0.9825 - val_loss: 0.1839 - val_acc: 0.9621
# Epoch 31/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0424 - acc: 0.9819 - val_loss: 0.1631 - val_acc: 0.9620
# Epoch 32/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0431 - acc: 0.9816 - val_loss: 0.1859 - val_acc: 0.9620
# Epoch 33/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0408 - acc: 0.9826 - val_loss: 0.2038 - val_acc: 0.9622
# Epoch 34/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0395 - acc: 0.9831 - val_loss: 0.1891 - val_acc: 0.9620
# Epoch 35/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0384 - acc: 0.9836 - val_loss: 0.2046 - val_acc: 0.9624
# Epoch 36/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0376 - acc: 0.9839 - val_loss: 0.1916 - val_acc: 0.9619
# Epoch 37/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0384 - acc: 0.9836 - val_loss: 0.1852 - val_acc: 0.9619
# Epoch 38/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0381 - acc: 0.9837 - val_loss: 0.1920 - val_acc: 0.9622
# Epoch 39/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0371 - acc: 0.9841 - val_loss: 0.1747 - val_acc: 0.9624
# Epoch 40/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0439 - acc: 0.9815 - val_loss: 0.1639 - val_acc: 0.9615
# Epoch 41/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0453 - acc: 0.9809 - val_loss: 0.1946 - val_acc: 0.9628
# Epoch 42/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0362 - acc: 0.9845 - val_loss: 0.2168 - val_acc: 0.9627
# Epoch 43/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0336 - acc: 0.9857 - val_loss: 0.2259 - val_acc: 0.9627
# Epoch 44/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0332 - acc: 0.9858 - val_loss: 0.2169 - val_acc: 0.9623
# Epoch 45/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0336 - acc: 0.9857 - val_loss: 0.2254 - val_acc: 0.9626
# Epoch 46/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0337 - acc: 0.9856 - val_loss: 0.2217 - val_acc: 0.9623
# Epoch 47/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0342 - acc: 0.9854 - val_loss: 0.2352 - val_acc: 0.9622
# Epoch 48/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0351 - acc: 0.9850 - val_loss: 0.2127 - val_acc: 0.9625
# Epoch 49/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0356 - acc: 0.9848 - val_loss: 0.2068 - val_acc: 0.9621
# Epoch 50/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0336 - acc: 0.9857 - val_loss: 0.2180 - val_acc: 0.9626
# Epoch 51/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0331 - acc: 0.9859 - val_loss: 0.2191 - val_acc: 0.9624
# Epoch 52/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0322 - acc: 0.9863 - val_loss: 0.2231 - val_acc: 0.9623
# Epoch 53/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0325 - acc: 0.9861 - val_loss: 0.2090 - val_acc: 0.9617
# Epoch 54/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0331 - acc: 0.9859 - val_loss: 0.2520 - val_acc: 0.9622
# Epoch 55/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0329 - acc: 0.9859 - val_loss: 0.2447 - val_acc: 0.9622
# Epoch 56/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0328 - acc: 0.9860 - val_loss: 0.2349 - val_acc: 0.9627
# Epoch 57/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0316 - acc: 0.9865 - val_loss: 0.2174 - val_acc: 0.9620
# Epoch 58/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0312 - acc: 0.9867 - val_loss: 0.2373 - val_acc: 0.9627
# Epoch 59/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0312 - acc: 0.9867 - val_loss: 0.2032 - val_acc: 0.9619
# Epoch 60/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0307 - acc: 0.9869 - val_loss: 0.2424 - val_acc: 0.9623
# Epoch 61/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0308 - acc: 0.9868 - val_loss: 0.2491 - val_acc: 0.9622
# Epoch 62/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0311 - acc: 0.9867 - val_loss: 0.2083 - val_acc: 0.9617
# Epoch 63/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0309 - acc: 0.9868 - val_loss: 0.2263 - val_acc: 0.9622
# Epoch 64/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0303 - acc: 0.9871 - val_loss: 0.1912 - val_acc: 0.9621
# Epoch 65/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0305 - acc: 0.9870 - val_loss: 0.2556 - val_acc: 0.9622
# Epoch 66/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0296 - acc: 0.9874 - val_loss: 0.2398 - val_acc: 0.9628
# Epoch 67/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0294 - acc: 0.9874 - val_loss: 0.2457 - val_acc: 0.9626
# Epoch 68/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0301 - acc: 0.9871 - val_loss: 0.2506 - val_acc: 0.9622
# Epoch 69/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0294 - acc: 0.9875 - val_loss: 0.2557 - val_acc: 0.9624
# Epoch 70/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0302 - acc: 0.9871 - val_loss: 0.2440 - val_acc: 0.9619
# Epoch 71/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0298 - acc: 0.9873 - val_loss: 0.2794 - val_acc: 0.9622
# Epoch 72/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0289 - acc: 0.9877 - val_loss: 0.2708 - val_acc: 0.9622
# Epoch 73/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0287 - acc: 0.9877 - val_loss: 0.2313 - val_acc: 0.9623
# Epoch 74/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0285 - acc: 0.9878 - val_loss: 0.2327 - val_acc: 0.9622
# Epoch 75/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0285 - acc: 0.9878 - val_loss: 0.2750 - val_acc: 0.9627
# Epoch 76/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0281 - acc: 0.9880 - val_loss: 0.2400 - val_acc: 0.9621
# Epoch 77/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0292 - acc: 0.9875 - val_loss: 0.2869 - val_acc: 0.9621
# Epoch 78/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0284 - acc: 0.9879 - val_loss: 0.2386 - val_acc: 0.9621
# Epoch 79/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0271 - acc: 0.9884 - val_loss: 0.2885 - val_acc: 0.9624
# Epoch 80/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0273 - acc: 0.9884 - val_loss: 0.2396 - val_acc: 0.9622
# Epoch 81/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0280 - acc: 0.9881 - val_loss: 0.2661 - val_acc: 0.9618
# Epoch 82/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0273 - acc: 0.9883 - val_loss: 0.2737 - val_acc: 0.9621
# Epoch 83/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0273 - acc: 0.9883 - val_loss: 0.2408 - val_acc: 0.9615
# Epoch 84/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0277 - acc: 0.9882 - val_loss: 0.2584 - val_acc: 0.9622
# Epoch 85/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0275 - acc: 0.9883 - val_loss: 0.2733 - val_acc: 0.9622
# Epoch 86/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0267 - acc: 0.9886 - val_loss: 0.2684 - val_acc: 0.9619
# Epoch 87/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0267 - acc: 0.9886 - val_loss: 0.2705 - val_acc: 0.9623
# Epoch 88/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0265 - acc: 0.9887 - val_loss: 0.2613 - val_acc: 0.9617
# Epoch 89/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0265 - acc: 0.9887 - val_loss: 0.2755 - val_acc: 0.9619
# Epoch 90/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0264 - acc: 0.9887 - val_loss: 0.2597 - val_acc: 0.9622
# Epoch 91/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0264 - acc: 0.9888 - val_loss: 0.2634 - val_acc: 0.9622
# Epoch 92/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0263 - acc: 0.9888 - val_loss: 0.2705 - val_acc: 0.9621
# Epoch 93/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0263 - acc: 0.9888 - val_loss: 0.2298 - val_acc: 0.9625
# Epoch 94/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0259 - acc: 0.9890 - val_loss: 0.2940 - val_acc: 0.9621
# Epoch 95/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0258 - acc: 0.9890 - val_loss: 0.2931 - val_acc: 0.9622
# Epoch 96/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0255 - acc: 0.9891 - val_loss: 0.2616 - val_acc: 0.9627
# Epoch 97/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0272 - acc: 0.9884 - val_loss: 0.2650 - val_acc: 0.9625
# Epoch 98/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0267 - acc: 0.9886 - val_loss: 0.2062 - val_acc: 0.9618
# Epoch 99/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0289 - acc: 0.9877 - val_loss: 0.2707 - val_acc: 0.9623
# Epoch 100/100
# 450/450 [==============================] - 10s 22ms/step - loss: 0.0252 - acc: 0.9893 - val_loss: 0.2998 - val_acc: 0.9625

# %% [markdown]
# ##### UNet VGG19

# %%
def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_vgg19_unet(input_shape, freeze=1):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained VGG19 Model """
    vgg19 = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)
    
    """ 
        Select Freeze layer 
        VGG 19, consist of 22 trainable layers
        Freeze = True, all layers freeze not fine tune
        Freeze = False, all layers fine tune
        Freeze = 1, 1 last layers freeze
        Freeze = 21, 1 last layers fine tune, else freeze
    """
    if freeze > 0:
      for layer in vgg19.layers[-freeze:]:
        layer.trainable = False
    elif freeze == True:
      for layer in vgg19.layers[:]:
        layer.trainable = False
    elif freeze == False:
      for layer in vgg19.layers[:]:
        layer.trainable = True
    
    for layer in vgg19.layers:
      print(layer, layer.trainable)

    """ Encoder """
    s1 = vgg19.get_layer("block1_conv2").output         ## (512 x 512)
    s2 = vgg19.get_layer("block2_conv2").output         ## (256 x 256)
    s3 = vgg19.get_layer("block3_conv4").output         ## (128 x 128)
    s4 = vgg19.get_layer("block4_conv4").output         ## (64 x 64)

    """ Bridge """
    b1 = vgg19.get_layer("block5_conv4").output         ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

    """ Output """
    outputs = Conv2D(2, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="VGG19_U-Net")
    return model

# %%
input_shape = (128,128, 3)
model_unet_vgg = build_vgg19_unet(input_shape, freeze=4)
model_unet_vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# <keras.engine.input_layer.InputLayer object at 0x7fd690310450> True
# <keras.layers.convolutional.Conv2D object at 0x7fd69c144c90> True
# <keras.layers.convolutional.Conv2D object at 0x7fd69045abd0> True
# <keras.layers.pooling.MaxPooling2D object at 0x7fd69c16bb50> True
# <keras.layers.convolutional.Conv2D object at 0x7fd69c0c25d0> True
# <keras.layers.convolutional.Conv2D object at 0x7fd690238a10> True
# <keras.layers.pooling.MaxPooling2D object at 0x7fd6903b2e10> True
# <keras.layers.convolutional.Conv2D object at 0x7fd69c16bd50> True
# <keras.layers.convolutional.Conv2D object at 0x7fd6901c2250> True
# <keras.layers.convolutional.Conv2D object at 0x7fd6901d2210> True
# <keras.layers.convolutional.Conv2D object at 0x7fd690457e90> True
# <keras.layers.pooling.MaxPooling2D object at 0x7fd6903af6d0> True
# <keras.layers.convolutional.Conv2D object at 0x7fd69023c590> True
# <keras.layers.convolutional.Conv2D object at 0x7fd6901e3dd0> True
# <keras.layers.convolutional.Conv2D object at 0x7fd6901ebed0> True
# <keras.layers.convolutional.Conv2D object at 0x7fd6901df9d0> True
# <keras.layers.pooling.MaxPooling2D object at 0x7fd6901f4090> True
# <keras.layers.convolutional.Conv2D object at 0x7fd690231550> True
# <keras.layers.convolutional.Conv2D object at 0x7fd69017d110> False
# <keras.layers.convolutional.Conv2D object at 0x7fd69017db90> False
# <keras.layers.convolutional.Conv2D object at 0x7fd6901f9750> False
# <keras.layers.pooling.MaxPooling2D object at 0x7fd690230910> False
# Model: "VGG19_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_2[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  1049088    ['block5_conv4[0][0]']
#  ose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'block4_conv4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 512)  2048       ['conv2d_19[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_20[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_1[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_21[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_22[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_3[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'block2_conv2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_6[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_23[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_24[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 64  256        ['conv2d_25[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 64  256        ['conv2d_26[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 2)  130         ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 31,172,098
# Trainable params: 24,088,834
# Non-trainable params: 7,083,264
# __________________________________________________________________________________________________

# %%
model_unet_vgg.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
plot_model(model_unet_vgg)

# %%
history_2 = model_unet_vgg.fit(X_train_norm, 
                    y_train,
                    batch_size=8, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test_norm, y_test), ) # callbacks=EarlyStopping(monitor='val_acc', mode='max',patience=10))
# Out:
# Epoch 1/100
# 450/450 [==============================] - 71s 145ms/step - loss: 0.2010 - acc: 0.9343 - val_loss: 0.1379 - val_acc: 0.9548
# Epoch 2/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.1226 - acc: 0.9584 - val_loss: 0.1174 - val_acc: 0.9613
# Epoch 3/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.1104 - acc: 0.9615 - val_loss: 0.1158 - val_acc: 0.9604
# Epoch 4/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.1033 - acc: 0.9633 - val_loss: 0.1284 - val_acc: 0.9564
# Epoch 5/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0969 - acc: 0.9647 - val_loss: 0.1098 - val_acc: 0.9609
# Epoch 6/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0918 - acc: 0.9659 - val_loss: 0.1094 - val_acc: 0.9648
# Epoch 7/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0871 - acc: 0.9670 - val_loss: 0.1001 - val_acc: 0.9646
# Epoch 8/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0820 - acc: 0.9682 - val_loss: 0.1017 - val_acc: 0.9650
# Epoch 9/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0786 - acc: 0.9690 - val_loss: 0.1073 - val_acc: 0.9627
# Epoch 10/100
# 450/450 [==============================] - 65s 143ms/step - loss: 0.0746 - acc: 0.9703 - val_loss: 0.0985 - val_acc: 0.9659
# Epoch 11/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0710 - acc: 0.9712 - val_loss: 0.1138 - val_acc: 0.9662
# Epoch 12/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0674 - acc: 0.9723 - val_loss: 0.1194 - val_acc: 0.9657
# Epoch 13/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0632 - acc: 0.9737 - val_loss: 0.1247 - val_acc: 0.9665
# Epoch 14/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0603 - acc: 0.9748 - val_loss: 0.1211 - val_acc: 0.9652
# Epoch 15/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0586 - acc: 0.9754 - val_loss: 0.1160 - val_acc: 0.9662
# Epoch 16/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0552 - acc: 0.9767 - val_loss: 0.1207 - val_acc: 0.9660
# Epoch 17/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0535 - acc: 0.9773 - val_loss: 0.1243 - val_acc: 0.9664
# Epoch 18/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0537 - acc: 0.9774 - val_loss: 0.1289 - val_acc: 0.9654
# Epoch 19/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0511 - acc: 0.9783 - val_loss: 0.1453 - val_acc: 0.9655
# Epoch 20/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0478 - acc: 0.9797 - val_loss: 0.1431 - val_acc: 0.9653
# Epoch 21/100
# 450/450 [==============================] - 64s 143ms/step - loss: 0.0450 - acc: 0.9808 - val_loss: 0.1492 - val_acc: 0.9661
# Epoch 22/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0438 - acc: 0.9813 - val_loss: 0.1466 - val_acc: 0.9652
# Epoch 23/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0429 - acc: 0.9817 - val_loss: 0.1458 - val_acc: 0.9646
# Epoch 24/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0407 - acc: 0.9827 - val_loss: 0.1645 - val_acc: 0.9645
# Epoch 25/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0387 - acc: 0.9835 - val_loss: 0.1631 - val_acc: 0.9650
# Epoch 26/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0382 - acc: 0.9837 - val_loss: 0.1534 - val_acc: 0.9638
# Epoch 27/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0380 - acc: 0.9838 - val_loss: 0.1704 - val_acc: 0.9648
# Epoch 28/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0352 - acc: 0.9850 - val_loss: 0.1902 - val_acc: 0.9650
# Epoch 29/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0339 - acc: 0.9856 - val_loss: 0.1778 - val_acc: 0.9646
# Epoch 30/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0327 - acc: 0.9861 - val_loss: 0.2008 - val_acc: 0.9639
# Epoch 31/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0315 - acc: 0.9866 - val_loss: 0.1950 - val_acc: 0.9651
# Epoch 32/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0308 - acc: 0.9869 - val_loss: 0.1839 - val_acc: 0.9642
# Epoch 33/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0302 - acc: 0.9871 - val_loss: 0.2026 - val_acc: 0.9650
# Epoch 34/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0295 - acc: 0.9875 - val_loss: 0.1961 - val_acc: 0.9643
# Epoch 35/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0284 - acc: 0.9880 - val_loss: 0.2056 - val_acc: 0.9649
# Epoch 36/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0274 - acc: 0.9884 - val_loss: 0.1982 - val_acc: 0.9646
# Epoch 37/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0285 - acc: 0.9880 - val_loss: 0.1579 - val_acc: 0.9581
# Epoch 38/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0285 - acc: 0.9879 - val_loss: 0.2226 - val_acc: 0.9645
# Epoch 39/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0246 - acc: 0.9896 - val_loss: 0.2004 - val_acc: 0.9635
# Epoch 40/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0240 - acc: 0.9899 - val_loss: 0.2187 - val_acc: 0.9648
# Epoch 41/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0238 - acc: 0.9900 - val_loss: 0.2478 - val_acc: 0.9642
# Epoch 42/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0229 - acc: 0.9903 - val_loss: 0.2366 - val_acc: 0.9645
# Epoch 43/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0226 - acc: 0.9904 - val_loss: 0.2367 - val_acc: 0.9643
# Epoch 44/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0226 - acc: 0.9905 - val_loss: 0.2455 - val_acc: 0.9645
# Epoch 45/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0219 - acc: 0.9907 - val_loss: 0.2226 - val_acc: 0.9642
# Epoch 46/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0216 - acc: 0.9909 - val_loss: 0.2322 - val_acc: 0.9642
# Epoch 47/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0217 - acc: 0.9908 - val_loss: 0.2453 - val_acc: 0.9645
# Epoch 48/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0221 - acc: 0.9907 - val_loss: 0.2435 - val_acc: 0.9647
# Epoch 49/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0194 - acc: 0.9918 - val_loss: 0.2536 - val_acc: 0.9646
# Epoch 50/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0187 - acc: 0.9922 - val_loss: 0.2574 - val_acc: 0.9646
# Epoch 51/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0186 - acc: 0.9922 - val_loss: 0.2529 - val_acc: 0.9646
# Epoch 52/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0186 - acc: 0.9922 - val_loss: 0.2620 - val_acc: 0.9642
# Epoch 53/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0185 - acc: 0.9922 - val_loss: 0.2840 - val_acc: 0.9647
# Epoch 54/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0179 - acc: 0.9925 - val_loss: 0.2778 - val_acc: 0.9641
# Epoch 55/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0175 - acc: 0.9927 - val_loss: 0.2736 - val_acc: 0.9644
# Epoch 56/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0172 - acc: 0.9928 - val_loss: 0.2766 - val_acc: 0.9645
# Epoch 57/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0168 - acc: 0.9930 - val_loss: 0.2872 - val_acc: 0.9645
# Epoch 58/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0161 - acc: 0.9932 - val_loss: 0.2747 - val_acc: 0.9643
# Epoch 59/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0161 - acc: 0.9933 - val_loss: 0.2911 - val_acc: 0.9645
# Epoch 60/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0154 - acc: 0.9935 - val_loss: 0.2986 - val_acc: 0.9640
# Epoch 61/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0155 - acc: 0.9935 - val_loss: 0.3155 - val_acc: 0.9646
# Epoch 62/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0153 - acc: 0.9936 - val_loss: 0.3063 - val_acc: 0.9643
# Epoch 63/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0147 - acc: 0.9939 - val_loss: 0.2995 - val_acc: 0.9643
# Epoch 64/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0144 - acc: 0.9940 - val_loss: 0.3278 - val_acc: 0.9635
# Epoch 65/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0141 - acc: 0.9941 - val_loss: 0.3428 - val_acc: 0.9646
# Epoch 66/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0139 - acc: 0.9942 - val_loss: 0.3105 - val_acc: 0.9642
# Epoch 67/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0137 - acc: 0.9943 - val_loss: 0.3145 - val_acc: 0.9641
# Epoch 68/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0131 - acc: 0.9946 - val_loss: 0.3119 - val_acc: 0.9643
# Epoch 69/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0126 - acc: 0.9948 - val_loss: 0.3334 - val_acc: 0.9642
# Epoch 70/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0126 - acc: 0.9948 - val_loss: 0.3481 - val_acc: 0.9646
# Epoch 71/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0125 - acc: 0.9948 - val_loss: 0.3385 - val_acc: 0.9641
# Epoch 72/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0124 - acc: 0.9949 - val_loss: 0.3468 - val_acc: 0.9643
# Epoch 73/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0121 - acc: 0.9950 - val_loss: 0.3526 - val_acc: 0.9640
# Epoch 74/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0121 - acc: 0.9950 - val_loss: 0.3528 - val_acc: 0.9642
# Epoch 75/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0113 - acc: 0.9954 - val_loss: 0.3761 - val_acc: 0.9645
# Epoch 76/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0111 - acc: 0.9955 - val_loss: 0.3713 - val_acc: 0.9641
# Epoch 77/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0109 - acc: 0.9955 - val_loss: 0.3666 - val_acc: 0.9642
# Epoch 78/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0107 - acc: 0.9956 - val_loss: 0.3599 - val_acc: 0.9638
# Epoch 79/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0105 - acc: 0.9957 - val_loss: 0.3663 - val_acc: 0.9636
# Epoch 80/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0104 - acc: 0.9958 - val_loss: 0.3866 - val_acc: 0.9641
# Epoch 81/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0101 - acc: 0.9959 - val_loss: 0.3782 - val_acc: 0.9642
# Epoch 82/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0103 - acc: 0.9958 - val_loss: 0.3859 - val_acc: 0.9644
# Epoch 83/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0103 - acc: 0.9958 - val_loss: 0.4051 - val_acc: 0.9640
# Epoch 84/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0095 - acc: 0.9961 - val_loss: 0.3913 - val_acc: 0.9641
# Epoch 85/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0094 - acc: 0.9962 - val_loss: 0.4113 - val_acc: 0.9640
# Epoch 86/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0092 - acc: 0.9963 - val_loss: 0.4123 - val_acc: 0.9643
# Epoch 87/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0089 - acc: 0.9964 - val_loss: 0.4197 - val_acc: 0.9644
# Epoch 88/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0088 - acc: 0.9965 - val_loss: 0.4470 - val_acc: 0.9643
# Epoch 89/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0089 - acc: 0.9964 - val_loss: 0.3976 - val_acc: 0.9634
# Epoch 90/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0088 - acc: 0.9965 - val_loss: 0.4273 - val_acc: 0.9641
# Epoch 91/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0083 - acc: 0.9967 - val_loss: 0.4389 - val_acc: 0.9638
# Epoch 92/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0081 - acc: 0.9967 - val_loss: 0.4528 - val_acc: 0.9642
# Epoch 93/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0081 - acc: 0.9967 - val_loss: 0.4338 - val_acc: 0.9640
# Epoch 94/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0078 - acc: 0.9969 - val_loss: 0.4616 - val_acc: 0.9642
# Epoch 95/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0077 - acc: 0.9969 - val_loss: 0.4408 - val_acc: 0.9642
# Epoch 96/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0075 - acc: 0.9970 - val_loss: 0.4441 - val_acc: 0.9641
# Epoch 97/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0074 - acc: 0.9971 - val_loss: 0.4440 - val_acc: 0.9642
# Epoch 98/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0073 - acc: 0.9971 - val_loss: 0.4599 - val_acc: 0.9643
# Epoch 99/100
# 450/450 [==============================] - 65s 144ms/step - loss: 0.0072 - acc: 0.9971 - val_loss: 0.4510 - val_acc: 0.9641
# Epoch 100/100
# 450/450 [==============================] - 65s 145ms/step - loss: 0.0070 - acc: 0.9972 - val_loss: 0.4684 - val_acc: 0.9639

# %%
#plot the training and validation IoU and loss at each epoch
loss_1 = history_1.history['loss']
val_loss_1 = history_1.history['val_loss']
epochs = range(1, len(loss_1) + 1)
plt.plot(epochs, loss_1, 'y-', label='UNet Training loss')
plt.plot(epochs, val_loss_1, 'r-', label='UNet Validation loss')
loss_2 = history_2.history['loss']
val_loss_2 = history_2.history['val_loss']
epochs = range(1, len(loss_2) + 1)
plt.plot(epochs, loss_2, 'y--', label='UNet VGG Training loss')
plt.plot(epochs, val_loss_2, 'r--', label='UNet VGG Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend()
plt.show()

acc_1 = history_1.history['acc']
val_acc_1 = history_1.history['val_acc']
acc_2 = history_2.history['acc']
val_acc_2 = history_2.history['val_acc']
epochs = range(1, len(acc_1) + 1)
plt.plot(epochs, acc_1, 'y-', label='UNet Training Acc')
plt.plot(epochs, val_acc_1, 'r-', label='UNet Validation Acc')
epochs = range(1, len(acc_2) + 1)
plt.plot(epochs, acc_2, 'y--', label='UNet VGG Training Acc')
plt.plot(epochs, val_acc_2, 'r--', label='UNet VGG Validation Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.ylim([0.8, 1])
plt.legend()
plt.show()

# %%
#Predict on the test data
y_pred_1=model_unet.predict(X_test_norm)
y_pred_argmax_1=np.argmax(y_pred_1, axis=3)
y_pred_2=model_unet_vgg.predict(X_test_norm)
y_pred_argmax_2=np.argmax(y_pred_2, axis=3)
y_test_argmax = np.argmax(y_test, axis=3)

# %%
IOU_keras_1 = MeanIoU(num_classes=2)  
IOU_keras_1.update_state(y_test_argmax, y_pred_argmax_1)
print("Mean IoU Test UNet=", IOU_keras_1.result().numpy())
IOU_keras_2 = MeanIoU(num_classes=2)  
IOU_keras_2.update_state(y_test_argmax, y_pred_argmax_2)
print("Mean IoU Test UNet VGG=", IOU_keras_2.result().numpy())
# Out:
# Mean IoU Test UNet= 0.7336446
# Mean IoU Test UNet VGG= 0.7468418

# %%
plt.figure(figsize=(15, 3))
ax1 = plt.subplot(141)
ax2 = plt.subplot(142)
ax3 = plt.subplot(143)
ax4 = plt.subplot(144)
randil = np.random.randint(0, len(X_test_norm), 1)[0]
ax1.imshow(X_test_norm[randil, : , :, 1].T)
ax2.imshow(y_test_argmax[randil, : , :].T)
ax3.imshow(y_pred_argmax_1[randil, : , :].T)
ax4.imshow(y_pred_argmax_2[randil, : , :].T)
ax1.set_title('Input')
ax2.set_title('Ground Truth')
ax3.set_title('UNet')
ax4.set_title('UNet VGG')
plt.tight_layout()
plt.show()

# %%
# model_unet.save('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_1200data.h5')

# %%
# model_unet_vgg.save('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_vgg_1200data.h5')

# %% [markdown]
# ## Prediction

# %%
model_unet = load_model('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_1200data.h5', compile=False)

# %%
model_unet_vgg = load_model('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_vgg_1200data.h5', compile=False)

# %%
# Prediction
seismic = np.reshape(np.fromfile("/content/drive/MyDrive/UTP_dGB_Documents/data/prediction/f3d/gxl.dat",dtype=np.single),(512,384,128))
seismic.shape
# Out:
# (512, 384, 128)

# %%
seisnorm = normalization(seismic)

# %%
def prediction(seismic, model, mode='inline'):
  # Append 2D seismic into 3D seismic
  if mode=='inline':
    predicted = []
    for i in range(seismic.shape[0]):
      val_input = seismic[i, :, :]
      patches = patchify(val_input, (128, 128), step=128)
      predicted_patches = []
      for i in range(patches.shape[0]):
        for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_3ch = np.stack((single_patch,)*3, axis=-1)
          single_patch_3ch_input = np.expand_dims(single_patch_3ch, axis=0)
          single_patch_prediction = model.predict(single_patch_3ch_input)
          single_patch_prediction_argmax = np.argmax(single_patch_prediction, axis=3)[0,:,:]
          predicted_patches.append(single_patch_prediction_argmax)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patches.shape[2], patches.shape[3]))
      reconstructed_seismic = unpatchify(predicted_patches_reshaped, val_input.shape)
      predicted.append(reconstructed_seismic)
    return np.array(predicted)
  elif mode=='crossline':
    predicted = []
    for i in range(seismic.shape[1]):
      val_input = seismic[:, i, :]
      patches = patchify(val_input, (128, 128), step=128)
      predicted_patches = []
      for i in range(patches.shape[0]):
        for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_3ch = np.stack((single_patch,)*3, axis=-1)
          single_patch_3ch_input = np.expand_dims(single_patch_3ch, axis=0)
          single_patch_prediction = model.predict(single_patch_3ch_input)
          single_patch_prediction_argmax = np.argmax(single_patch_prediction, axis=3)[0,:,:]
          predicted_patches.append(single_patch_prediction_argmax)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patches.shape[2], patches.shape[3]))
      reconstructed_seismic = unpatchify(predicted_patches_reshaped, val_input.shape)
      predicted.append(reconstructed_seismic)
    return np.array(predicted)

# %%
unet_predicted_il = prediction(seisnorm, model_unet, mode='inline')
unet_predicted_xl = prediction(seisnorm, model_unet, mode='crossline')

# %%
unet_vgg_predicted_il = prediction(seisnorm, model_unet_vgg, mode='inline')
unet_vgg_predicted_xl = prediction(seisnorm, model_unet_vgg, mode='crossline')

# %%
# def prediction(model):
#   il_range = np.arange(0, 640, 128)
#   pred_3d = []
#   for i in range(384):
#     pred_2d = []
#     for j in range(0, 4):
#       il_min = il_range[j]
#       il_max = il_range[j+1]
#       seis = seismic[il_min:il_max, i, :]
#       pred = np.stack((seis,)*3, axis=-1)
#       pred_2d.append(pred)
#     pred_3d.append(np.vstack(np.argmax(model.predict(np.array(pred_2d)), axis=3)))
#   return np.array(pred_3d).reshape(512, 384, 128)

# %%
# unet_prediction = prediction(seisnorm, model_unet)

# %%
# unet_vgg_prediction = prediction(seisnorm, model_unet_vgg)

# %%
ncolors = 256
color_array = plt.get_cmap('gray')(range(ncolors))
color_array[:,-1] = np.linspace(0.0,0,ncolors)
color_array[253:256] = [1, 0.0, 0., 1]
map_object = LinearSegmentedColormap.from_list(name='fault',colors=color_array)
plt.register_cmap(cmap=map_object)

# %%
vm = np.percentile(seisnorm, 99)

# %%
il = 53
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(seisnorm[il,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0].imshow(unet_predicted_il[il, :, :].T, cmap='fault')
ax[0].set_title('UNet')
ax[1].imshow(seisnorm[il,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1].imshow(unet_vgg_predicted_il[il, :, :].T, cmap='fault')
ax[1].set_title('UNet VGG')
plt.suptitle('Inline')
plt.show()

# %%
xl = 24
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(seisnorm[:,xl,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0].imshow(unet_predicted_xl[xl, :, :].T, cmap='fault')
ax[0].set_title('UNet')
ax[1].imshow(seisnorm[:,xl,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1].imshow(unet_vgg_predicted_xl[xl, :, :].T, cmap='fault')
ax[1].set_title('UNet VGG')
plt.suptitle('Crossline')
plt.show()

# %%
print(unet_predicted_il.shape)
print(unet_predicted_xl.shape)
print(unet_vgg_predicted_il.shape)
print(unet_vgg_predicted_xl.shape)
unet_predicted_xl_transposed = np.moveaxis(unet_predicted_xl, 1, 0)
print(unet_predicted_xl_transposed.shape)
unet_vgg_predicted_xl_transposed = np.moveaxis(unet_vgg_predicted_xl, 1, 0)
print(unet_vgg_predicted_xl_transposed.shape)
# Out:
# (512, 384, 128)
# (384, 512, 128)
# (512, 384, 128)
# (384, 512, 128)
# (512, 384, 128)
# (512, 384, 128)

# %%
combined_unet = unet_predicted_il + unet_predicted_xl_transposed
combined_unet[combined_unet > 0] = 1
combined_unet_vgg = unet_vgg_predicted_il + unet_vgg_predicted_xl_transposed
combined_unet_vgg[combined_unet_vgg > 0] = 1

# %%
combined_unet_vgg.shape
# Out:
# (512, 384, 128)

# %%
il = 53
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(seisnorm[il,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0].imshow(combined_unet[il, :, :].T, cmap='fault')
ax[0].set_title('UNet')
ax[1].imshow(seisnorm[il,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1].imshow(combined_unet_vgg[il, :, :].T, cmap='fault')
ax[1].set_title('UNet VGG')
plt.suptitle('Inline')
plt.show()

# %%
xl = 24
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(seisnorm[:,xl,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0].imshow(combined_unet[:, xl, :].T, cmap='fault')
ax[0].set_title('UNet')
ax[1].imshow(seisnorm[:,xl,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1].imshow(combined_unet_vgg[:, xl, :].T, cmap='fault')
ax[1].set_title('UNet VGG')
plt.suptitle('Crossline')
plt.show()

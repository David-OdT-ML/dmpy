# %%
# !pip install segyio
# !pip install segysak
# !pip install patchify
# !pip install segmentation_models_3D
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: segyio in /usr/local/lib/python3.7/dist-packages (1.9.9)
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from segyio) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: segysak in /usr/local/lib/python3.7/dist-packages (0.3.4)
# Requirement already satisfied: xarray in /usr/local/lib/python3.7/dist-packages (from segysak) (0.20.2)
# Requirement already satisfied: addict in /usr/local/lib/python3.7/dist-packages (from segysak) (2.4.0)
# Requirement already satisfied: segyio in /usr/local/lib/python3.7/dist-packages (from segysak) (1.9.9)
# Requirement already satisfied: h5netcdf in /usr/local/lib/python3.7/dist-packages (from segysak) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.7.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.21.6)
# Requirement already satisfied: more-itertools>=8.0 in /usr/local/lib/python3.7/dist-packages (from segysak) (8.13.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from segysak) (1.3.5)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from segysak) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from segysak) (4.64.0)
# Requirement already satisfied: setuptools-scm in /usr/local/lib/python3.7/dist-packages (from segysak) (7.0.5)
# Requirement already satisfied: distributed in /usr/local/lib/python3.7/dist-packages (from segysak) (1.25.3)
# Requirement already satisfied: dask in /usr/local/lib/python3.7/dist-packages (from segysak) (2.12.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.0.4)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.4.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (3.13)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.4.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.15.0)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.3.0)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.7.0)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.1.1)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.2.0)
# Requirement already satisfied: toolz>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (0.12.0)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed->segysak) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (21.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->h5netcdf->segysak) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->h5netcdf->segysak) (3.0.9)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2.8.2)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (2.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->setuptools-scm->segysak) (3.8.1)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: patchify in /usr/local/lib/python3.7/dist-packages (0.2.3)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.21.6)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: segmentation_models_3D in /usr/local/lib/python3.7/dist-packages (1.0.4)
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_3D) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_3D) (1.0.8)
# Requirement already satisfied: classification-models-3D>=1.0.6 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_3D) (1.0.6)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (1.21.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (3.1.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.15.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (4.1.1)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.5.3)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.3.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (57.4.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.2.0)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.14.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.26.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.47.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (14.0.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.17.3)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->segmentation_models_3D) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->segmentation_models_3D) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.35.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.4.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.23.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2022.6.15)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.2.0)

# %%
import tensorflow as tf
import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.8.2
# 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import segyio
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import segmentation_models_3D as sm
from patchify import patchify, unpatchify
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam
from segysak.segy import segy_header_scan, segy_header_scrape, get_segy_texthead, segy_loader
from keras.metrics import MeanIoU
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from matplotlib.colors import LinearSegmentedColormap
# Out:
# Segmentation Models: using `tf.keras` framework.
# /usr/local/lib/python3.7/dist-packages/segysak/segy/_segy_core.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
train_seismic_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/train/seis'
train_fault_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/train/fault'

valid_seismic_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/validation/seis'
valid_fault_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/validation/fault'

# %%
train_seis_input = []
train_fault_output = []

for i in os.listdir(train_seismic_path):
  rand_xl = np.random.randint(0, 128, 1)[0]
  train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, rand_xl, :])
  train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, rand_xl, :])

# %%
valid_seis_input = []
valid_fault_output = []

for i in os.listdir(valid_seismic_path):
  rand_xl = np.random.randint(0, 128, 1)[0]
  valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, rand_xl, :])
  valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, rand_xl, :])

# %%
X_train = np.stack((train_seis_input,)*3, axis=-1)
X_test = np.stack((valid_seis_input,)*3, axis=-1)

train_mask = np.expand_dims(train_fault_output, axis=3)
y_train = tf.keras.utils.to_categorical(train_mask, num_classes=2)
test_mask = np.expand_dims(valid_fault_output, axis=3)
y_test = tf.keras.utils.to_categorical(test_mask, num_classes=2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (200, 128, 128, 3)
# (20, 128, 128, 3)
# (200, 128, 128, 2)
# (20, 128, 128, 2)

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose
from tensorflow.keras.models import Model

# %%
batch_size = 8
image_size = 128

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %%
def UNet():
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    bn = bottleneck(p4, f[4])
    
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model_unet = UNet()
model_unet.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
train_steps = len(X_train)//batch_size
valid_steps = len(X_test)//batch_size

# %%
history_1 = model_unet.fit(X_train, 
                    y_train,
                    batch_size=batch_size, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 25/25 [==============================] - 4s 43ms/step - loss: 0.3455 - acc: 0.8734 - val_loss: 0.3119 - val_acc: 0.9128
# Epoch 2/100
# 25/25 [==============================] - 1s 21ms/step - loss: 0.2658 - acc: 0.9279 - val_loss: 0.3020 - val_acc: 0.9128
# Epoch 3/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.2646 - acc: 0.9279 - val_loss: 0.2967 - val_acc: 0.9128
# Epoch 4/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2593 - acc: 0.9279 - val_loss: 0.2942 - val_acc: 0.9128
# Epoch 5/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2575 - acc: 0.9279 - val_loss: 0.3169 - val_acc: 0.9128
# Epoch 6/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2534 - acc: 0.9279 - val_loss: 0.2982 - val_acc: 0.9128
# Epoch 7/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2448 - acc: 0.9279 - val_loss: 0.2775 - val_acc: 0.9128
# Epoch 8/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2337 - acc: 0.9279 - val_loss: 0.2649 - val_acc: 0.9128
# Epoch 9/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2232 - acc: 0.9279 - val_loss: 0.2518 - val_acc: 0.9128
# Epoch 10/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.2074 - acc: 0.9279 - val_loss: 0.2371 - val_acc: 0.9128
# Epoch 11/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.1966 - acc: 0.9319 - val_loss: 0.2312 - val_acc: 0.9212
# Epoch 12/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1909 - acc: 0.9357 - val_loss: 0.2238 - val_acc: 0.9227
# Epoch 13/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1821 - acc: 0.9376 - val_loss: 0.2258 - val_acc: 0.9253
# Epoch 14/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1779 - acc: 0.9395 - val_loss: 0.2258 - val_acc: 0.9258
# Epoch 15/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1673 - acc: 0.9418 - val_loss: 0.2130 - val_acc: 0.9307
# Epoch 16/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1574 - acc: 0.9446 - val_loss: 0.1960 - val_acc: 0.9316
# Epoch 17/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1497 - acc: 0.9465 - val_loss: 0.2141 - val_acc: 0.9344
# Epoch 18/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1430 - acc: 0.9482 - val_loss: 0.2045 - val_acc: 0.9348
# Epoch 19/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1363 - acc: 0.9499 - val_loss: 0.1953 - val_acc: 0.9352
# Epoch 20/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1293 - acc: 0.9515 - val_loss: 0.2031 - val_acc: 0.9346
# Epoch 21/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1252 - acc: 0.9525 - val_loss: 0.2006 - val_acc: 0.9339
# Epoch 22/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1230 - acc: 0.9524 - val_loss: 0.2146 - val_acc: 0.9368
# Epoch 23/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1119 - acc: 0.9559 - val_loss: 0.2291 - val_acc: 0.9360
# Epoch 24/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.1108 - acc: 0.9560 - val_loss: 0.2038 - val_acc: 0.9369
# Epoch 25/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0987 - acc: 0.9594 - val_loss: 0.2247 - val_acc: 0.9365
# Epoch 26/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0913 - acc: 0.9619 - val_loss: 0.2190 - val_acc: 0.9371
# Epoch 27/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0919 - acc: 0.9614 - val_loss: 0.2443 - val_acc: 0.9370
# Epoch 28/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0882 - acc: 0.9629 - val_loss: 0.2223 - val_acc: 0.9368
# Epoch 29/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0824 - acc: 0.9647 - val_loss: 0.2339 - val_acc: 0.9363
# Epoch 30/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0785 - acc: 0.9663 - val_loss: 0.2702 - val_acc: 0.9373
# Epoch 31/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0747 - acc: 0.9677 - val_loss: 0.2832 - val_acc: 0.9364
# Epoch 32/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0734 - acc: 0.9683 - val_loss: 0.2671 - val_acc: 0.9377
# Epoch 33/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0681 - acc: 0.9705 - val_loss: 0.2938 - val_acc: 0.9372
# Epoch 34/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0652 - acc: 0.9716 - val_loss: 0.3291 - val_acc: 0.9366
# Epoch 35/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0642 - acc: 0.9719 - val_loss: 0.3494 - val_acc: 0.9374
# Epoch 36/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0618 - acc: 0.9732 - val_loss: 0.3034 - val_acc: 0.9367
# Epoch 37/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0596 - acc: 0.9740 - val_loss: 0.3523 - val_acc: 0.9366
# Epoch 38/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0594 - acc: 0.9741 - val_loss: 0.3661 - val_acc: 0.9358
# Epoch 39/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0557 - acc: 0.9759 - val_loss: 0.3423 - val_acc: 0.9374
# Epoch 40/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0530 - acc: 0.9771 - val_loss: 0.3604 - val_acc: 0.9382
# Epoch 41/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0526 - acc: 0.9773 - val_loss: 0.4059 - val_acc: 0.9358
# Epoch 42/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0521 - acc: 0.9775 - val_loss: 0.3719 - val_acc: 0.9367
# Epoch 43/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0503 - acc: 0.9783 - val_loss: 0.3987 - val_acc: 0.9351
# Epoch 44/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0483 - acc: 0.9793 - val_loss: 0.3786 - val_acc: 0.9363
# Epoch 45/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0463 - acc: 0.9801 - val_loss: 0.3870 - val_acc: 0.9366
# Epoch 46/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0448 - acc: 0.9807 - val_loss: 0.4104 - val_acc: 0.9373
# Epoch 47/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0450 - acc: 0.9807 - val_loss: 0.4210 - val_acc: 0.9372
# Epoch 48/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0433 - acc: 0.9814 - val_loss: 0.4654 - val_acc: 0.9367
# Epoch 49/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0405 - acc: 0.9828 - val_loss: 0.4281 - val_acc: 0.9366
# Epoch 50/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0394 - acc: 0.9831 - val_loss: 0.4749 - val_acc: 0.9371
# Epoch 51/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0391 - acc: 0.9834 - val_loss: 0.4139 - val_acc: 0.9366
# Epoch 52/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0388 - acc: 0.9835 - val_loss: 0.4466 - val_acc: 0.9367
# Epoch 53/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0374 - acc: 0.9841 - val_loss: 0.4526 - val_acc: 0.9381
# Epoch 54/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0371 - acc: 0.9844 - val_loss: 0.4360 - val_acc: 0.9376
# Epoch 55/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0344 - acc: 0.9854 - val_loss: 0.4064 - val_acc: 0.9369
# Epoch 56/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0345 - acc: 0.9855 - val_loss: 0.4860 - val_acc: 0.9376
# Epoch 57/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0331 - acc: 0.9860 - val_loss: 0.5050 - val_acc: 0.9381
# Epoch 58/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0331 - acc: 0.9860 - val_loss: 0.4492 - val_acc: 0.9364
# Epoch 59/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0338 - acc: 0.9858 - val_loss: 0.5145 - val_acc: 0.9374
# Epoch 60/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0342 - acc: 0.9855 - val_loss: 0.4784 - val_acc: 0.9362
# Epoch 61/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0318 - acc: 0.9867 - val_loss: 0.4931 - val_acc: 0.9374
# Epoch 62/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0315 - acc: 0.9867 - val_loss: 0.5153 - val_acc: 0.9362
# Epoch 63/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0319 - acc: 0.9865 - val_loss: 0.4731 - val_acc: 0.9380
# Epoch 64/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0326 - acc: 0.9863 - val_loss: 0.4493 - val_acc: 0.9365
# Epoch 65/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0311 - acc: 0.9869 - val_loss: 0.4908 - val_acc: 0.9373
# Epoch 66/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0298 - acc: 0.9874 - val_loss: 0.4929 - val_acc: 0.9381
# Epoch 67/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0318 - acc: 0.9866 - val_loss: 0.5328 - val_acc: 0.9375
# Epoch 68/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0308 - acc: 0.9870 - val_loss: 0.4996 - val_acc: 0.9371
# Epoch 69/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0315 - acc: 0.9866 - val_loss: 0.4835 - val_acc: 0.9368
# Epoch 70/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0309 - acc: 0.9869 - val_loss: 0.4859 - val_acc: 0.9375
# Epoch 71/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0281 - acc: 0.9881 - val_loss: 0.5487 - val_acc: 0.9378
# Epoch 72/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0267 - acc: 0.9888 - val_loss: 0.5714 - val_acc: 0.9378
# Epoch 73/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0265 - acc: 0.9888 - val_loss: 0.5682 - val_acc: 0.9374
# Epoch 74/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0268 - acc: 0.9887 - val_loss: 0.5485 - val_acc: 0.9378
# Epoch 75/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0255 - acc: 0.9894 - val_loss: 0.5446 - val_acc: 0.9378
# Epoch 76/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0252 - acc: 0.9895 - val_loss: 0.5561 - val_acc: 0.9374
# Epoch 77/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0241 - acc: 0.9899 - val_loss: 0.5787 - val_acc: 0.9376
# Epoch 78/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0237 - acc: 0.9901 - val_loss: 0.5532 - val_acc: 0.9371
# Epoch 79/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0239 - acc: 0.9900 - val_loss: 0.5935 - val_acc: 0.9376
# Epoch 80/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0240 - acc: 0.9899 - val_loss: 0.5798 - val_acc: 0.9380
# Epoch 81/100
# 25/25 [==============================] - 0s 18ms/step - loss: 0.0249 - acc: 0.9895 - val_loss: 0.5185 - val_acc: 0.9357
# Epoch 82/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0259 - acc: 0.9891 - val_loss: 0.6092 - val_acc: 0.9376
# Epoch 83/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0272 - acc: 0.9885 - val_loss: 0.5409 - val_acc: 0.9372
# Epoch 84/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0281 - acc: 0.9882 - val_loss: 0.4894 - val_acc: 0.9363
# Epoch 85/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0262 - acc: 0.9889 - val_loss: 0.5649 - val_acc: 0.9377
# Epoch 86/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0243 - acc: 0.9899 - val_loss: 0.5331 - val_acc: 0.9372
# Epoch 87/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0243 - acc: 0.9899 - val_loss: 0.5357 - val_acc: 0.9378
# Epoch 88/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0236 - acc: 0.9902 - val_loss: 0.5508 - val_acc: 0.9372
# Epoch 89/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0213 - acc: 0.9912 - val_loss: 0.5988 - val_acc: 0.9373
# Epoch 90/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0206 - acc: 0.9916 - val_loss: 0.6420 - val_acc: 0.9373
# Epoch 91/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0204 - acc: 0.9916 - val_loss: 0.6010 - val_acc: 0.9367
# Epoch 92/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0216 - acc: 0.9909 - val_loss: 0.6159 - val_acc: 0.9373
# Epoch 93/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0236 - acc: 0.9900 - val_loss: 0.5889 - val_acc: 0.9371
# Epoch 94/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0229 - acc: 0.9904 - val_loss: 0.5676 - val_acc: 0.9374
# Epoch 95/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0217 - acc: 0.9909 - val_loss: 0.6581 - val_acc: 0.9370
# Epoch 96/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0205 - acc: 0.9914 - val_loss: 0.6838 - val_acc: 0.9376
# Epoch 97/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0197 - acc: 0.9918 - val_loss: 0.6499 - val_acc: 0.9379
# Epoch 98/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0193 - acc: 0.9920 - val_loss: 0.6678 - val_acc: 0.9369
# Epoch 99/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0207 - acc: 0.9913 - val_loss: 0.6108 - val_acc: 0.9374
# Epoch 100/100
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0224 - acc: 0.9905 - val_loss: 0.5761 - val_acc: 0.9364

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model_unet)

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_vgg19_unet(input_shape):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained VGG19 Model """
    vgg19 = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)

    """ Encoder """
    s1 = vgg19.get_layer("block1_conv2").output         ## (512 x 512)
    s2 = vgg19.get_layer("block2_conv2").output         ## (256 x 256)
    s3 = vgg19.get_layer("block3_conv4").output         ## (128 x 128)
    s4 = vgg19.get_layer("block4_conv4").output         ## (64 x 64)

    """ Bridge """
    b1 = vgg19.get_layer("block5_conv4").output         ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

    """ Output """
    outputs = Conv2D(2, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="VGG19_U-Net")
    return model

# %%
input_shape = (128,128, 3)
model_unet_vgg = build_vgg19_unet(input_shape)
model_unet_vgg.summary()
# Out:
# Model: "VGG19_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_2[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  1049088    ['block5_conv4[0][0]']
#  ose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'block4_conv4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 512)  2048       ['conv2d_19[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_20[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_1[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_21[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_22[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_3[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'block2_conv2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_6[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_23[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_24[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 64  256        ['conv2d_25[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 64  256        ['conv2d_26[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 2)  130         ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 31,172,098
# Trainable params: 31,168,258
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
model_unet_vgg.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
plot_model(model_unet_vgg)

# %%
history_2 = model_unet_vgg.fit(X_train, 
                    y_train,
                    batch_size=8, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 25/25 [==============================] - 6s 116ms/step - loss: 0.4852 - acc: 0.8489 - val_loss: 0.7620 - val_acc: 0.8925
# Epoch 2/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.2614 - acc: 0.9343 - val_loss: 0.5355 - val_acc: 0.8500
# Epoch 3/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1930 - acc: 0.9423 - val_loss: 0.6116 - val_acc: 0.8485
# Epoch 4/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1727 - acc: 0.9456 - val_loss: 0.2523 - val_acc: 0.9236
# Epoch 5/100
# 25/25 [==============================] - 2s 83ms/step - loss: 0.1610 - acc: 0.9487 - val_loss: 0.2256 - val_acc: 0.9316
# Epoch 6/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1489 - acc: 0.9515 - val_loss: 0.2243 - val_acc: 0.9233
# Epoch 7/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1386 - acc: 0.9536 - val_loss: 0.1945 - val_acc: 0.9395
# Epoch 8/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.1288 - acc: 0.9561 - val_loss: 0.1952 - val_acc: 0.9368
# Epoch 9/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.1246 - acc: 0.9568 - val_loss: 0.2025 - val_acc: 0.9311
# Epoch 10/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.1147 - acc: 0.9593 - val_loss: 0.1922 - val_acc: 0.9383
# Epoch 11/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1121 - acc: 0.9592 - val_loss: 0.2056 - val_acc: 0.9368
# Epoch 12/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1066 - acc: 0.9608 - val_loss: 0.2080 - val_acc: 0.9339
# Epoch 13/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.1004 - acc: 0.9624 - val_loss: 0.1985 - val_acc: 0.9390
# Epoch 14/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0919 - acc: 0.9652 - val_loss: 0.1902 - val_acc: 0.9349
# Epoch 15/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0920 - acc: 0.9648 - val_loss: 0.1888 - val_acc: 0.9387
# Epoch 16/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0867 - acc: 0.9663 - val_loss: 0.1983 - val_acc: 0.9409
# Epoch 17/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0778 - acc: 0.9695 - val_loss: 0.1950 - val_acc: 0.9410
# Epoch 18/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0736 - acc: 0.9710 - val_loss: 0.2104 - val_acc: 0.9387
# Epoch 19/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0700 - acc: 0.9727 - val_loss: 0.2043 - val_acc: 0.9409
# Epoch 20/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0661 - acc: 0.9738 - val_loss: 0.2040 - val_acc: 0.9418
# Epoch 21/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0669 - acc: 0.9732 - val_loss: 0.2186 - val_acc: 0.9406
# Epoch 22/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0639 - acc: 0.9744 - val_loss: 0.2105 - val_acc: 0.9418
# Epoch 23/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0587 - acc: 0.9766 - val_loss: 0.2051 - val_acc: 0.9426
# Epoch 24/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0615 - acc: 0.9750 - val_loss: 0.2289 - val_acc: 0.9382
# Epoch 25/100
# 25/25 [==============================] - 2s 81ms/step - loss: 0.0625 - acc: 0.9745 - val_loss: 0.2230 - val_acc: 0.9411
# Epoch 26/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0541 - acc: 0.9783 - val_loss: 0.2139 - val_acc: 0.9415
# Epoch 27/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0515 - acc: 0.9792 - val_loss: 0.2276 - val_acc: 0.9417
# Epoch 28/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0510 - acc: 0.9796 - val_loss: 0.2377 - val_acc: 0.9407
# Epoch 29/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0496 - acc: 0.9800 - val_loss: 0.2191 - val_acc: 0.9420
# Epoch 30/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0463 - acc: 0.9813 - val_loss: 0.2215 - val_acc: 0.9431
# Epoch 31/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0436 - acc: 0.9825 - val_loss: 0.2366 - val_acc: 0.9406
# Epoch 32/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0431 - acc: 0.9825 - val_loss: 0.2259 - val_acc: 0.9425
# Epoch 33/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0414 - acc: 0.9834 - val_loss: 0.2205 - val_acc: 0.9426
# Epoch 34/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0393 - acc: 0.9843 - val_loss: 0.2302 - val_acc: 0.9423
# Epoch 35/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0391 - acc: 0.9843 - val_loss: 0.2343 - val_acc: 0.9405
# Epoch 36/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0397 - acc: 0.9838 - val_loss: 0.2476 - val_acc: 0.9425
# Epoch 37/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0396 - acc: 0.9839 - val_loss: 0.2468 - val_acc: 0.9423
# Epoch 38/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0383 - acc: 0.9845 - val_loss: 0.2485 - val_acc: 0.9421
# Epoch 39/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0352 - acc: 0.9857 - val_loss: 0.2419 - val_acc: 0.9431
# Epoch 40/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0349 - acc: 0.9858 - val_loss: 0.2524 - val_acc: 0.9430
# Epoch 41/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0342 - acc: 0.9862 - val_loss: 0.2501 - val_acc: 0.9423
# Epoch 42/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0328 - acc: 0.9866 - val_loss: 0.2626 - val_acc: 0.9430
# Epoch 43/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0315 - acc: 0.9873 - val_loss: 0.2501 - val_acc: 0.9431
# Epoch 44/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0302 - acc: 0.9879 - val_loss: 0.2506 - val_acc: 0.9425
# Epoch 45/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0293 - acc: 0.9882 - val_loss: 0.2620 - val_acc: 0.9425
# Epoch 46/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0298 - acc: 0.9878 - val_loss: 0.2610 - val_acc: 0.9413
# Epoch 47/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0306 - acc: 0.9875 - val_loss: 0.2671 - val_acc: 0.9406
# Epoch 48/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0310 - acc: 0.9872 - val_loss: 0.2649 - val_acc: 0.9416
# Epoch 49/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0277 - acc: 0.9888 - val_loss: 0.2722 - val_acc: 0.9427
# Epoch 50/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0267 - acc: 0.9892 - val_loss: 0.2657 - val_acc: 0.9420
# Epoch 51/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0302 - acc: 0.9876 - val_loss: 0.2884 - val_acc: 0.9388
# Epoch 52/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0306 - acc: 0.9874 - val_loss: 0.2753 - val_acc: 0.9417
# Epoch 53/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0274 - acc: 0.9888 - val_loss: 0.2791 - val_acc: 0.9428
# Epoch 54/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0248 - acc: 0.9899 - val_loss: 0.2707 - val_acc: 0.9420
# Epoch 55/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0240 - acc: 0.9903 - val_loss: 0.2798 - val_acc: 0.9403
# Epoch 56/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0280 - acc: 0.9885 - val_loss: 0.2850 - val_acc: 0.9421
# Epoch 57/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0248 - acc: 0.9898 - val_loss: 0.2927 - val_acc: 0.9416
# Epoch 58/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0230 - acc: 0.9907 - val_loss: 0.2944 - val_acc: 0.9422
# Epoch 59/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0201 - acc: 0.9920 - val_loss: 0.2955 - val_acc: 0.9427
# Epoch 60/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0185 - acc: 0.9927 - val_loss: 0.2999 - val_acc: 0.9427
# Epoch 61/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0183 - acc: 0.9928 - val_loss: 0.2967 - val_acc: 0.9420
# Epoch 62/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0203 - acc: 0.9917 - val_loss: 0.3019 - val_acc: 0.9412
# Epoch 63/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0227 - acc: 0.9907 - val_loss: 0.3092 - val_acc: 0.9398
# Epoch 64/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0229 - acc: 0.9907 - val_loss: 0.2944 - val_acc: 0.9401
# Epoch 65/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0209 - acc: 0.9915 - val_loss: 0.3139 - val_acc: 0.9420
# Epoch 66/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0197 - acc: 0.9920 - val_loss: 0.2999 - val_acc: 0.9426
# Epoch 67/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0188 - acc: 0.9925 - val_loss: 0.3110 - val_acc: 0.9427
# Epoch 68/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0176 - acc: 0.9930 - val_loss: 0.3185 - val_acc: 0.9416
# Epoch 69/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0180 - acc: 0.9927 - val_loss: 0.3122 - val_acc: 0.9420
# Epoch 70/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0163 - acc: 0.9935 - val_loss: 0.3236 - val_acc: 0.9419
# Epoch 71/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0161 - acc: 0.9937 - val_loss: 0.3233 - val_acc: 0.9421
# Epoch 72/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0176 - acc: 0.9929 - val_loss: 0.3318 - val_acc: 0.9400
# Epoch 73/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0219 - acc: 0.9911 - val_loss: 0.3370 - val_acc: 0.9401
# Epoch 74/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0259 - acc: 0.9895 - val_loss: 0.3365 - val_acc: 0.9411
# Epoch 75/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0199 - acc: 0.9919 - val_loss: 0.3217 - val_acc: 0.9421
# Epoch 76/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0181 - acc: 0.9927 - val_loss: 0.3189 - val_acc: 0.9422
# Epoch 77/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0152 - acc: 0.9940 - val_loss: 0.3260 - val_acc: 0.9422
# Epoch 78/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0128 - acc: 0.9951 - val_loss: 0.3326 - val_acc: 0.9422
# Epoch 79/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0124 - acc: 0.9952 - val_loss: 0.3300 - val_acc: 0.9430
# Epoch 80/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0136 - acc: 0.9947 - val_loss: 0.3326 - val_acc: 0.9421
# Epoch 81/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0135 - acc: 0.9946 - val_loss: 0.3358 - val_acc: 0.9413
# Epoch 82/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0149 - acc: 0.9941 - val_loss: 0.3409 - val_acc: 0.9410
# Epoch 83/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0152 - acc: 0.9939 - val_loss: 0.3436 - val_acc: 0.9421
# Epoch 84/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0140 - acc: 0.9945 - val_loss: 0.3514 - val_acc: 0.9422
# Epoch 85/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0117 - acc: 0.9955 - val_loss: 0.3562 - val_acc: 0.9420
# Epoch 86/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0110 - acc: 0.9958 - val_loss: 0.3487 - val_acc: 0.9426
# Epoch 87/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0103 - acc: 0.9961 - val_loss: 0.3654 - val_acc: 0.9409
# Epoch 88/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0116 - acc: 0.9954 - val_loss: 0.3560 - val_acc: 0.9411
# Epoch 89/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0121 - acc: 0.9952 - val_loss: 0.3587 - val_acc: 0.9414
# Epoch 90/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0111 - acc: 0.9957 - val_loss: 0.3624 - val_acc: 0.9415
# Epoch 91/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0102 - acc: 0.9961 - val_loss: 0.3534 - val_acc: 0.9420
# Epoch 92/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0123 - acc: 0.9952 - val_loss: 0.3628 - val_acc: 0.9402
# Epoch 93/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0143 - acc: 0.9944 - val_loss: 0.3545 - val_acc: 0.9411
# Epoch 94/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0120 - acc: 0.9953 - val_loss: 0.3999 - val_acc: 0.9395
# Epoch 95/100
# 25/25 [==============================] - 2s 79ms/step - loss: 0.0118 - acc: 0.9954 - val_loss: 0.3685 - val_acc: 0.9424
# Epoch 96/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0088 - acc: 0.9968 - val_loss: 0.3680 - val_acc: 0.9421
# Epoch 97/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0069 - acc: 0.9976 - val_loss: 0.3763 - val_acc: 0.9418
# Epoch 98/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0057 - acc: 0.9981 - val_loss: 0.3808 - val_acc: 0.9416
# Epoch 99/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0054 - acc: 0.9982 - val_loss: 0.3864 - val_acc: 0.9418
# Epoch 100/100
# 25/25 [==============================] - 2s 80ms/step - loss: 0.0051 - acc: 0.9983 - val_loss: 0.3907 - val_acc: 0.9422

# %%
#plot the training and validation IoU and loss at each epoch
loss_1 = history_1.history['loss']
val_loss_1 = history_1.history['val_loss']
epochs = range(1, 100 + 1)
plt.plot(epochs, loss_1, 'y-', label='UNet Training loss')
plt.plot(epochs, val_loss_1, 'r-', label='UNet Validation loss')
loss_2 = history_2.history['loss']
val_loss_2 = history_2.history['val_loss']
epochs = range(1, 100 + 1)
plt.plot(epochs, loss_2, 'y--', label='UNet VGG Training loss')
plt.plot(epochs, val_loss_2, 'r--', label='UNet VGG Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend()
plt.show()

acc_1 = history_1.history['acc']
val_acc_1 = history_1.history['val_acc']
acc_2 = history_2.history['acc']
val_acc_2 = history_2.history['val_acc']

plt.plot(epochs, acc_1, 'y-', label='UNet Training Acc')
plt.plot(epochs, val_acc_1, 'r-', label='UNet Validation Acc')
plt.plot(epochs, acc_2, 'y--', label='UNet VGG Training Acc')
plt.plot(epochs, val_acc_2, 'r--', label='UNet VGG Validation Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.ylim([0.8, 1])
plt.legend()
plt.show()

# %%
#Predict on the test data
y_pred_1=model_unet.predict(X_test)
y_pred_argmax_1=np.argmax(y_pred_1, axis=3)
y_pred_2=model_unet_vgg.predict(X_test)
y_pred_argmax_2=np.argmax(y_pred_2, axis=3)
y_test_argmax = np.argmax(y_test, axis=3)

# %%
IOU_keras_1 = MeanIoU(num_classes=2)  
IOU_keras_1.update_state(y_test_argmax, y_pred_argmax_1)
print("Mean IoU Test UNet=", IOU_keras_1.result().numpy())
IOU_keras_2 = MeanIoU(num_classes=2)  
IOU_keras_2.update_state(y_test_argmax, y_pred_argmax_2)
print("Mean IoU Test UNet VGG=", IOU_keras_2.result().numpy())
# Out:
# Mean IoU Test UNet= 0.6712806
# Mean IoU Test UNet VGG= 0.69233143

# %%
plt.figure(figsize=(15, 3))
ax1 = plt.subplot(141)
ax2 = plt.subplot(142)
ax3 = plt.subplot(143)
ax4 = plt.subplot(144)
randil = np.random.randint(0, len(X_test), 1)[0]
ax1.imshow(X_test[randil, : , :, 1].T)
ax2.imshow(y_test_argmax[randil, : , :].T)
ax3.imshow(y_pred_argmax_1[randil, : , :].T)
ax4.imshow(y_pred_argmax_2[randil, : , :].T)
ax1.set_title('Input')
ax2.set_title('Ground Truth')
ax3.set_title('UNet')
ax4.set_title('UNet VGG')
plt.tight_layout()
plt.show()

# %%
# Prediction
seismic = np.reshape(np.fromfile("/content/drive/MyDrive/UTP_dGB_Documents/data/prediction/f3d/gxl.dat",dtype=np.single),(512,384,128))
seismic.shape
# Out:
# (512, 384, 128)

# %%
def prediction(model):
  # Append 2D seismic into 3D seismic
  predicted = []
  for i in range(512):
    val_input = seismic[i, :, :]
    patches = patchify(val_input, (128, 128), step=128)
    predicted_patches = []
    for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
        single_patch = patches[i,j,:,:]
        single_patch_3ch = np.stack((single_patch,)*3, axis=-1)
        single_patch_3ch_input = np.expand_dims(single_patch_3ch, axis=0)
        single_patch_prediction = model.predict(single_patch_3ch_input)
        single_patch_prediction_argmax = np.argmax(single_patch_prediction, axis=3)[0,:,:]
        predicted_patches.append(single_patch_prediction_argmax)
    predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patches.shape[2], patches.shape[3]))
    reconstructed_seismic = unpatchify(predicted_patches_reshaped, val_input.shape)
    predicted.append(reconstructed_seismic)
  return np.reshape(predicted, (512, 384, 128))

# %%
# def prediction(model):
#   il_range = np.arange(0, 640, 128)
#   pred_3d = []
#   for i in range(384):
#     pred_2d = []
#     for j in range(0, 4):
#       il_min = il_range[j]
#       il_max = il_range[j+1]
#       seis = seismic[il_min:il_max, i, :]
#       pred = np.stack((seis,)*3, axis=-1)
#       pred_2d.append(pred)
#     pred_3d.append(np.vstack(np.argmax(model.predict(np.array(pred_2d)), axis=3)))
#   return np.array(pred_3d).reshape(512, 384, 128)

# %%
unet_prediction = prediction(model_unet)

# %%
unet_vgg_prediction = prediction(model_unet_vgg)

# %%
ncolors = 256
color_array = plt.get_cmap('gray')(range(ncolors))
color_array[:,-1] = np.linspace(0.0,0,ncolors)
color_array[255:256] = [1, 0.0, 0., 1]
map_object = LinearSegmentedColormap.from_list(name='fault',colors=color_array)
plt.register_cmap(cmap=map_object)

# %%
vm = np.percentile(seismic, 99)

# %%
fig, ax = plt.subplots(1, 2, figsize=(25, 8))
ax[0].imshow(seismic[114,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0].imshow(unet_prediction[114, :, :].T, cmap='fault')
ax[0].set_title('UNet')
ax[1].imshow(seismic[114,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1].imshow(unet_vgg_prediction[114, :, :].T, cmap='fault')
ax[1].set_title('UNet VGG')
plt.show()

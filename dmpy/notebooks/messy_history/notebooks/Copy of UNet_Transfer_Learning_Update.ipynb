# %%
# !pip install segyio
# !pip install segysak
# !pip install patchify
# !pip install segmentation_models_3D
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segyio
#   Downloading segyio-1.9.9-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.4 MB/s
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from segyio) (1.21.6)
# Installing collected packages: segyio
# Successfully installed segyio-1.9.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segysak
#   Downloading segysak-0.3.4-py3-none-any.whl (310 kB)
#      |████████████████████████████████| 310 kB 8.2 MB/s
# Requirement already satisfied: distributed in /usr/local/lib/python3.7/dist-packages (from segysak) (1.25.3)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from segysak) (7.1.2)
# Collecting setuptools-scm
#   Downloading setuptools_scm-7.0.5-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.5 MB/s
# Requirement already satisfied: more-itertools>=8.0 in /usr/local/lib/python3.7/dist-packages (from segysak) (8.14.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.7.3)
# Requirement already satisfied: dask in /usr/local/lib/python3.7/dist-packages (from segysak) (2.12.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.21.6)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from segysak) (4.64.0)
# Collecting h5netcdf
#   Downloading h5netcdf-1.0.2-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from segysak) (1.3.5)
# Requirement already satisfied: xarray in /usr/local/lib/python3.7/dist-packages (from segysak) (0.20.2)
# Requirement already satisfied: segyio in /usr/local/lib/python3.7/dist-packages (from segysak) (1.9.9)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.3.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.4.8)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.7.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.4.0)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.15.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.2.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (3.13)
# Requirement already satisfied: toolz>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (0.12.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.0.4)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed->segysak) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (21.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->h5netcdf->segysak) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->h5netcdf->segysak) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2022.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.1.1)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (2.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->setuptools-scm->segysak) (3.8.1)
# Installing collected packages: setuptools-scm, h5netcdf, addict, segysak
# Successfully installed addict-2.4.0 h5netcdf-1.0.2 segysak-0.3.4 setuptools-scm-7.0.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.21.6)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation_models_3D
#   Downloading segmentation_models_3D-1.0.4-py3-none-any.whl (33 kB)
# Collecting classification-models-3D>=1.0.6
#   Downloading classification_models_3D-1.0.6-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.3 MB/s
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 7.4 MB/s
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_3D) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (1.21.6)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.5.3)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.2)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.26.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.14.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (14.0.6)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.15.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (57.4.0)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.17.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (4.1.1)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.47.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.6.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->segmentation_models_3D) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->segmentation_models_3D) (1.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.23.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.6)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.2.0)
# Installing collected packages: keras-applications, classification-models-3D, segmentation-models-3D
# Successfully installed classification-models-3D-1.0.6 keras-applications-1.0.8 segmentation-models-3D-1.0.4

# %%
import tensorflow as tf
import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.8.2
# 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import segyio
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import segmentation_models_3D as sm
from patchify import patchify, unpatchify
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam
from keras.models import load_model
from segysak.segy import segy_header_scan, segy_header_scrape, get_segy_texthead, segy_loader
from keras.metrics import MeanIoU
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from matplotlib.colors import LinearSegmentedColormap
# Out:
# Segmentation Models: using `tf.keras` framework.
# /usr/local/lib/python3.7/dist-packages/segysak/segy/_segy_core.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Normalization
def normalization(data, clip_factor=2.5):
  clipFactor = clip_factor
  std0 = np.std(data)
  stdClip = std0 * clipFactor
  clippedCube = np.clip(data, -stdClip, +stdClip)
  return np.asarray(clippedCube / stdClip, dtype='single')

# %% [markdown]
# ## Dataset Preparation

# %%
train_seismic_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/train/seis'
train_fault_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/train/fault'

valid_seismic_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/validation/seis'
valid_fault_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/validation/fault'

# %%
train_seis_input = []
train_fault_output = []

index = [0, 63, 127]
for i in os.listdir(train_seismic_path):
  for j in index:
    # iline
    train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    # xline
    train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])
    train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])

# %%
valid_seis_input = []
valid_fault_output = []

for i in os.listdir(valid_seismic_path):
  for j in index:
    # iline
    valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    # xline
    valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])
    valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])

# %%
np.array(train_seis_input).tofile('/content/drive/MyDrive/UTP_dGB_Documents/data/train/seis/1200.dat')
np.array(train_fault_output).tofile('/content/drive/MyDrive/UTP_dGB_Documents/data/train/fault/1200.dat')

# %%
np.array(valid_seis_input).tofile('/content/drive/MyDrive/UTP_dGB_Documents/data/validation/seis/1200.dat')
np.array(valid_fault_output).tofile('/content/drive/MyDrive/UTP_dGB_Documents/data/validation/fault/1200.dat')

# %% [markdown]
# ## Run if we want to train new model

# %%
train_seis_input = np.reshape(np.fromfile('/content/drive/MyDrive/UTP_dGB_Documents/data/train/seis/1200.dat', dtype=np.single), (1200, 128, 128))
train_fault_output = np.reshape(np.fromfile('/content/drive/MyDrive/UTP_dGB_Documents/data/train/fault/1200.dat', dtype=np.single), (1200, 128, 128))
valid_seis_input = np.reshape(np.fromfile('/content/drive/MyDrive/UTP_dGB_Documents/data/validation/seis/1200.dat', dtype=np.single), (120, 128, 128))
valid_fault_output = np.reshape(np.fromfile('/content/drive/MyDrive/UTP_dGB_Documents/data/validation/fault/1200.dat', dtype=np.single), (120, 128, 128))

# %%
X_train = np.stack((train_seis_input,)*3, axis=-1)
X_test = np.stack((valid_seis_input,)*3, axis=-1)

train_mask = np.expand_dims(train_fault_output, axis=3)
y_train = tf.keras.utils.to_categorical(train_mask, num_classes=2)
test_mask = np.expand_dims(valid_fault_output, axis=3)
y_test = tf.keras.utils.to_categorical(test_mask, num_classes=2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1200, 128, 128, 3)
# (120, 128, 128, 3)
# (1200, 128, 128, 2)
# (120, 128, 128, 2)

# %%
X_train_norm = normalization(X_train)
X_test_norm = normalization(X_test)

# %%
fig, ax = plt.subplots(1, 2, figsize=(5,5))
ax[0].imshow(X_train_norm[1, :, :, 1].T, cmap='Greys')
ax[1].imshow(y_train[1, :, :, 1].T, cmap='Greys_r')
fig.suptitle('Training Dataset')
plt.show()

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose
from tensorflow.keras.models import Model
from keras.callbacks import EarlyStopping

# %%
batch_size = 8
image_size = 128

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %%
def UNet():
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    # encoder
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    # bridge
    bn = bottleneck(p4, f[4])
    
    # decoder
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model_unet = UNet()
model_unet.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
train_steps = len(X_train_norm)//batch_size
valid_steps = len(X_test_norm)//batch_size

# %%
history_1 = model_unet.fit(X_train_norm, 
                    y_train,
                    batch_size=batch_size, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test_norm, y_test), ) # callbacks=EarlyStopping(monitor='val_acc', mode='max',patience=10))
# Out:
# Epoch 1/100
# 150/150 [==============================] - 16s 20ms/step - loss: 0.2513 - acc: 0.9343 - val_loss: 0.2190 - val_acc: 0.9352
# Epoch 2/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1779 - acc: 0.9409 - val_loss: 0.1549 - val_acc: 0.9479
# Epoch 3/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1401 - acc: 0.9529 - val_loss: 0.1520 - val_acc: 0.9492
# Epoch 4/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1254 - acc: 0.9568 - val_loss: 0.1286 - val_acc: 0.9551
# Epoch 5/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1172 - acc: 0.9589 - val_loss: 0.1276 - val_acc: 0.9564
# Epoch 6/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1111 - acc: 0.9604 - val_loss: 0.1179 - val_acc: 0.9576
# Epoch 7/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1057 - acc: 0.9619 - val_loss: 0.1178 - val_acc: 0.9583
# Epoch 8/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1005 - acc: 0.9633 - val_loss: 0.1143 - val_acc: 0.9594
# Epoch 9/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0977 - acc: 0.9640 - val_loss: 0.1195 - val_acc: 0.9592
# Epoch 10/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0930 - acc: 0.9653 - val_loss: 0.1116 - val_acc: 0.9616
# Epoch 11/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0873 - acc: 0.9668 - val_loss: 0.1063 - val_acc: 0.9621
# Epoch 12/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0846 - acc: 0.9675 - val_loss: 0.1165 - val_acc: 0.9614
# Epoch 13/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0810 - acc: 0.9685 - val_loss: 0.1150 - val_acc: 0.9605
# Epoch 14/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0819 - acc: 0.9681 - val_loss: 0.1100 - val_acc: 0.9623
# Epoch 15/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0744 - acc: 0.9701 - val_loss: 0.1084 - val_acc: 0.9621
# Epoch 16/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0705 - acc: 0.9714 - val_loss: 0.1166 - val_acc: 0.9626
# Epoch 17/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0670 - acc: 0.9723 - val_loss: 0.1193 - val_acc: 0.9622
# Epoch 18/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0621 - acc: 0.9740 - val_loss: 0.1197 - val_acc: 0.9634
# Epoch 19/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0621 - acc: 0.9740 - val_loss: 0.1242 - val_acc: 0.9628
# Epoch 20/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0580 - acc: 0.9755 - val_loss: 0.1312 - val_acc: 0.9627
# Epoch 21/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0575 - acc: 0.9756 - val_loss: 0.1372 - val_acc: 0.9623
# Epoch 22/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0569 - acc: 0.9760 - val_loss: 0.1445 - val_acc: 0.9625
# Epoch 23/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0563 - acc: 0.9762 - val_loss: 0.1398 - val_acc: 0.9616
# Epoch 24/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0517 - acc: 0.9780 - val_loss: 0.1340 - val_acc: 0.9622
# Epoch 25/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0484 - acc: 0.9793 - val_loss: 0.1668 - val_acc: 0.9633
# Epoch 26/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0466 - acc: 0.9801 - val_loss: 0.1560 - val_acc: 0.9635
# Epoch 27/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0457 - acc: 0.9805 - val_loss: 0.1625 - val_acc: 0.9624
# Epoch 28/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0438 - acc: 0.9813 - val_loss: 0.1674 - val_acc: 0.9625
# Epoch 29/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0422 - acc: 0.9820 - val_loss: 0.1603 - val_acc: 0.9623
# Epoch 30/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0421 - acc: 0.9821 - val_loss: 0.1693 - val_acc: 0.9626
# Epoch 31/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0410 - acc: 0.9825 - val_loss: 0.1738 - val_acc: 0.9625
# Epoch 32/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0397 - acc: 0.9831 - val_loss: 0.1912 - val_acc: 0.9627
# Epoch 33/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0385 - acc: 0.9836 - val_loss: 0.1896 - val_acc: 0.9630
# Epoch 34/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0376 - acc: 0.9840 - val_loss: 0.1885 - val_acc: 0.9632
# Epoch 35/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0363 - acc: 0.9846 - val_loss: 0.2050 - val_acc: 0.9629
# Epoch 36/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0354 - acc: 0.9849 - val_loss: 0.2113 - val_acc: 0.9631
# Epoch 37/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0350 - acc: 0.9851 - val_loss: 0.2062 - val_acc: 0.9629
# Epoch 38/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0347 - acc: 0.9853 - val_loss: 0.1943 - val_acc: 0.9626
# Epoch 39/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0336 - acc: 0.9858 - val_loss: 0.2135 - val_acc: 0.9625
# Epoch 40/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0322 - acc: 0.9863 - val_loss: 0.2151 - val_acc: 0.9630
# Epoch 41/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0328 - acc: 0.9862 - val_loss: 0.2184 - val_acc: 0.9627
# Epoch 42/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0348 - acc: 0.9853 - val_loss: 0.2171 - val_acc: 0.9628
# Epoch 43/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0328 - acc: 0.9861 - val_loss: 0.2032 - val_acc: 0.9623
# Epoch 44/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0320 - acc: 0.9865 - val_loss: 0.1953 - val_acc: 0.9625
# Epoch 45/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0300 - acc: 0.9873 - val_loss: 0.1959 - val_acc: 0.9622
# Epoch 46/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0301 - acc: 0.9873 - val_loss: 0.2124 - val_acc: 0.9630
# Epoch 47/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0290 - acc: 0.9878 - val_loss: 0.2345 - val_acc: 0.9628
# Epoch 48/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0282 - acc: 0.9881 - val_loss: 0.2776 - val_acc: 0.9624
# Epoch 49/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0280 - acc: 0.9882 - val_loss: 0.2245 - val_acc: 0.9625
# Epoch 50/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0276 - acc: 0.9884 - val_loss: 0.2428 - val_acc: 0.9624
# Epoch 51/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0275 - acc: 0.9884 - val_loss: 0.2461 - val_acc: 0.9628
# Epoch 52/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0549 - acc: 0.9785 - val_loss: 0.1353 - val_acc: 0.9606
# Epoch 53/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0471 - acc: 0.9807 - val_loss: 0.1574 - val_acc: 0.9622
# Epoch 54/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0347 - acc: 0.9853 - val_loss: 0.2047 - val_acc: 0.9626
# Epoch 55/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0289 - acc: 0.9878 - val_loss: 0.2195 - val_acc: 0.9631
# Epoch 56/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0263 - acc: 0.9889 - val_loss: 0.2080 - val_acc: 0.9627
# Epoch 57/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0253 - acc: 0.9894 - val_loss: 0.2514 - val_acc: 0.9629
# Epoch 58/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0245 - acc: 0.9898 - val_loss: 0.2441 - val_acc: 0.9630
# Epoch 59/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0239 - acc: 0.9900 - val_loss: 0.2497 - val_acc: 0.9627
# Epoch 60/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0235 - acc: 0.9902 - val_loss: 0.2480 - val_acc: 0.9633
# Epoch 61/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0230 - acc: 0.9904 - val_loss: 0.2409 - val_acc: 0.9628
# Epoch 62/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0229 - acc: 0.9904 - val_loss: 0.2483 - val_acc: 0.9630
# Epoch 63/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0236 - acc: 0.9901 - val_loss: 0.2627 - val_acc: 0.9627
# Epoch 64/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0233 - acc: 0.9902 - val_loss: 0.2431 - val_acc: 0.9632
# Epoch 65/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0237 - acc: 0.9900 - val_loss: 0.2555 - val_acc: 0.9628
# Epoch 66/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0243 - acc: 0.9898 - val_loss: 0.2488 - val_acc: 0.9624
# Epoch 67/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0250 - acc: 0.9895 - val_loss: 0.2472 - val_acc: 0.9628
# Epoch 68/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0247 - acc: 0.9896 - val_loss: 0.2614 - val_acc: 0.9629
# Epoch 69/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0239 - acc: 0.9899 - val_loss: 0.2582 - val_acc: 0.9628
# Epoch 70/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0227 - acc: 0.9905 - val_loss: 0.2297 - val_acc: 0.9629
# Epoch 71/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0226 - acc: 0.9905 - val_loss: 0.2635 - val_acc: 0.9627
# Epoch 72/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0225 - acc: 0.9905 - val_loss: 0.2571 - val_acc: 0.9630
# Epoch 73/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0231 - acc: 0.9903 - val_loss: 0.2425 - val_acc: 0.9627
# Epoch 74/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0228 - acc: 0.9904 - val_loss: 0.2470 - val_acc: 0.9633
# Epoch 75/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0225 - acc: 0.9906 - val_loss: 0.2449 - val_acc: 0.9632
# Epoch 76/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0219 - acc: 0.9908 - val_loss: 0.2681 - val_acc: 0.9629
# Epoch 77/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0221 - acc: 0.9907 - val_loss: 0.2779 - val_acc: 0.9633
# Epoch 78/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0222 - acc: 0.9906 - val_loss: 0.2707 - val_acc: 0.9631
# Epoch 79/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0227 - acc: 0.9904 - val_loss: 0.2479 - val_acc: 0.9629
# Epoch 80/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0222 - acc: 0.9906 - val_loss: 0.2557 - val_acc: 0.9626
# Epoch 81/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0222 - acc: 0.9906 - val_loss: 0.2462 - val_acc: 0.9629
# Epoch 82/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0329 - acc: 0.9867 - val_loss: 0.1378 - val_acc: 0.9596
# Epoch 83/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0552 - acc: 0.9780 - val_loss: 0.1558 - val_acc: 0.9610
# Epoch 84/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0335 - acc: 0.9860 - val_loss: 0.1830 - val_acc: 0.9619
# Epoch 85/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0259 - acc: 0.9891 - val_loss: 0.2177 - val_acc: 0.9628
# Epoch 86/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0221 - acc: 0.9908 - val_loss: 0.2636 - val_acc: 0.9631
# Epoch 87/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0202 - acc: 0.9916 - val_loss: 0.2913 - val_acc: 0.9626
# Epoch 88/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0195 - acc: 0.9919 - val_loss: 0.2767 - val_acc: 0.9630
# Epoch 89/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0191 - acc: 0.9920 - val_loss: 0.2707 - val_acc: 0.9628
# Epoch 90/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0191 - acc: 0.9920 - val_loss: 0.2805 - val_acc: 0.9630
# Epoch 91/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0189 - acc: 0.9921 - val_loss: 0.2751 - val_acc: 0.9632
# Epoch 92/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0188 - acc: 0.9921 - val_loss: 0.2804 - val_acc: 0.9629
# Epoch 93/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0190 - acc: 0.9920 - val_loss: 0.2659 - val_acc: 0.9629
# Epoch 94/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0191 - acc: 0.9920 - val_loss: 0.2562 - val_acc: 0.9632
# Epoch 95/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0190 - acc: 0.9920 - val_loss: 0.2545 - val_acc: 0.9629
# Epoch 96/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0189 - acc: 0.9920 - val_loss: 0.2964 - val_acc: 0.9631
# Epoch 97/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0196 - acc: 0.9917 - val_loss: 0.2932 - val_acc: 0.9629
# Epoch 98/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0193 - acc: 0.9919 - val_loss: 0.2451 - val_acc: 0.9636
# Epoch 99/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0193 - acc: 0.9919 - val_loss: 0.2808 - val_acc: 0.9632
# Epoch 100/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0186 - acc: 0.9922 - val_loss: 0.3053 - val_acc: 0.9631

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model_unet)

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_vgg19_unet(input_shape, fine_tune=0):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained VGG19 Model """
    vgg19 = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)
    
    # select trainable layers layer 1:4 ==> Trainable = True, 5 = False
    if fine_tune > 0:
      for layer in vgg19.layers[:-fine_tune]:
        layer.trainable = False
    else:
      for layer in vgg19.layers[:]:
        layer.trainable = False
    
    for layer in vgg19.layers:
      print(layer, layer.trainable)

    """ Encoder """
    s1 = vgg19.get_layer("block1_conv2").output         ## (512 x 512)
    s2 = vgg19.get_layer("block2_conv2").output         ## (256 x 256)
    s3 = vgg19.get_layer("block3_conv4").output         ## (128 x 128)
    s4 = vgg19.get_layer("block4_conv4").output         ## (64 x 64)

    """ Bridge """
    b1 = vgg19.get_layer("block5_conv4").output         ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

    """ Output """
    outputs = Conv2D(2, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="VGG19_U-Net")
    return model

# %%
input_shape = (128,128, 3)
model_unet_vgg = build_vgg19_unet(input_shape, fine_tune=4)
model_unet_vgg.summary()
# Out:
# <keras.engine.input_layer.InputLayer object at 0x7f15a80f2f50> False
# <keras.layers.convolutional.Conv2D object at 0x7f15867e2690> False
# <keras.layers.convolutional.Conv2D object at 0x7f15862ed410> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f1587d8d710> False
# <keras.layers.convolutional.Conv2D object at 0x7f1587d013d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f158604eb90> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f158654f390> False
# <keras.layers.convolutional.Conv2D object at 0x7f1587d3c750> False
# <keras.layers.convolutional.Conv2D object at 0x7f158635dcd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f1587d08710> False
# <keras.layers.convolutional.Conv2D object at 0x7f158476e050> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f15864a8610> False
# <keras.layers.convolutional.Conv2D object at 0x7f15d07c1a10> False
# <keras.layers.convolutional.Conv2D object at 0x7f1587d21350> False
# <keras.layers.convolutional.Conv2D object at 0x7f15a808a290> False
# <keras.layers.convolutional.Conv2D object at 0x7f1586abebd0> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f15d01ad7d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f1587cda750> False
# <keras.layers.convolutional.Conv2D object at 0x7f1586feb110> True
# <keras.layers.convolutional.Conv2D object at 0x7f1587d76c90> True
# <keras.layers.convolutional.Conv2D object at 0x7f1587d2bed0> True
# <keras.layers.pooling.MaxPooling2D object at 0x7f1587d2b290> True
# Model: "VGG19_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_4[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv3[0][0]']
#
#  conv2d_transpose_8 (Conv2DTran  (None, 16, 16, 512)  1049088    ['block5_conv4[0][0]']
#  spose)
#
#  concatenate_12 (Concatenate)   (None, 16, 16, 1024  0           ['conv2d_transpose_8[0][0]',
#                                 )                                 'block4_conv4[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate_12[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_37[0][0]']
#  ormalization)
#
#  activation_16 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_16[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation_16[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_38[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 16, 16, 512)  0           ['batch_normalization_17[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_17[0][0]']
#  spose)
#
#  concatenate_13 (Concatenate)   (None, 32, 32, 512)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_13[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_39[0][0]']
#  ormalization)
#
#  activation_18 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_18[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_18[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_40[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 32, 32, 256)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_transpose_10 (Conv2DTra  (None, 64, 64, 128)  131200     ['activation_19[0][0]']
#  nspose)
#
#  concatenate_14 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_10[0][0]',
#                                                                   'block2_conv2[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_14[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 128)  512        ['conv2d_41[0][0]']
#  ormalization)
#
#  activation_20 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_20[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 128)  512        ['conv2d_42[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 64, 64, 128)  0           ['batch_normalization_21[0][0]']
#
#  conv2d_transpose_11 (Conv2DTra  (None, 128, 128, 64  32832      ['activation_21[0][0]']
#  nspose)                        )
#
#  concatenate_15 (Concatenate)   (None, 128, 128, 12  0           ['conv2d_transpose_11[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_15[0][0]']
#                                 )
#
#  batch_normalization_22 (BatchN  (None, 128, 128, 64  256        ['conv2d_43[0][0]']
#  ormalization)                  )
#
#  activation_22 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_22[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 128, 128, 64  36928       ['activation_22[0][0]']
#                                 )
#
#  batch_normalization_23 (BatchN  (None, 128, 128, 64  256        ['conv2d_44[0][0]']
#  ormalization)                  )
#
#  activation_23 (Activation)     (None, 128, 128, 64  0           ['batch_normalization_23[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 128, 128, 2)  130         ['activation_23[0][0]']
#
# ==================================================================================================
# Total params: 31,172,098
# Trainable params: 18,223,298
# Non-trainable params: 12,948,800
# __________________________________________________________________________________________________

# %%
model_unet_vgg.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
plot_model(model_unet_vgg)

# %%
history_2 = model_unet_vgg.fit(X_train_norm, 
                    y_train,
                    batch_size=8, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test_norm, y_test), ) # callbacks=EarlyStopping(monitor='val_acc', mode='max',patience=10))
# Out:
# Epoch 1/100
# 150/150 [==============================] - 11s 62ms/step - loss: 0.2605 - acc: 0.9168 - val_loss: 0.1771 - val_acc: 0.9470
# Epoch 2/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.1424 - acc: 0.9540 - val_loss: 0.1446 - val_acc: 0.9523
# Epoch 3/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.1286 - acc: 0.9567 - val_loss: 0.1497 - val_acc: 0.9529
# Epoch 4/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.1203 - acc: 0.9587 - val_loss: 0.1318 - val_acc: 0.9556
# Epoch 5/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.1139 - acc: 0.9605 - val_loss: 0.1302 - val_acc: 0.9553
# Epoch 6/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.1092 - acc: 0.9616 - val_loss: 0.1291 - val_acc: 0.9571
# Epoch 7/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.1048 - acc: 0.9624 - val_loss: 0.1364 - val_acc: 0.9569
# Epoch 8/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0998 - acc: 0.9638 - val_loss: 0.1264 - val_acc: 0.9571
# Epoch 9/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0942 - acc: 0.9651 - val_loss: 0.1245 - val_acc: 0.9590
# Epoch 10/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0886 - acc: 0.9667 - val_loss: 0.1273 - val_acc: 0.9573
# Epoch 11/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0818 - acc: 0.9688 - val_loss: 0.1316 - val_acc: 0.9582
# Epoch 12/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0758 - acc: 0.9706 - val_loss: 0.1497 - val_acc: 0.9569
# Epoch 13/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0711 - acc: 0.9719 - val_loss: 0.1334 - val_acc: 0.9548
# Epoch 14/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0659 - acc: 0.9737 - val_loss: 0.1471 - val_acc: 0.9566
# Epoch 15/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0621 - acc: 0.9751 - val_loss: 0.1583 - val_acc: 0.9564
# Epoch 16/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0586 - acc: 0.9763 - val_loss: 0.1662 - val_acc: 0.9576
# Epoch 17/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0548 - acc: 0.9776 - val_loss: 0.1620 - val_acc: 0.9557
# Epoch 18/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0516 - acc: 0.9788 - val_loss: 0.1667 - val_acc: 0.9563
# Epoch 19/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0490 - acc: 0.9798 - val_loss: 0.1557 - val_acc: 0.9543
# Epoch 20/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0470 - acc: 0.9806 - val_loss: 0.1891 - val_acc: 0.9561
# Epoch 21/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0464 - acc: 0.9809 - val_loss: 0.1855 - val_acc: 0.9562
# Epoch 22/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0434 - acc: 0.9820 - val_loss: 0.1919 - val_acc: 0.9567
# Epoch 23/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0418 - acc: 0.9827 - val_loss: 0.1917 - val_acc: 0.9565
# Epoch 24/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0403 - acc: 0.9833 - val_loss: 0.2049 - val_acc: 0.9573
# Epoch 25/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0394 - acc: 0.9836 - val_loss: 0.1758 - val_acc: 0.9539
# Epoch 26/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0379 - acc: 0.9843 - val_loss: 0.1909 - val_acc: 0.9549
# Epoch 27/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0369 - acc: 0.9847 - val_loss: 0.2041 - val_acc: 0.9558
# Epoch 28/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0358 - acc: 0.9852 - val_loss: 0.1996 - val_acc: 0.9548
# Epoch 29/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0354 - acc: 0.9854 - val_loss: 0.2016 - val_acc: 0.9555
# Epoch 30/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0342 - acc: 0.9858 - val_loss: 0.2171 - val_acc: 0.9564
# Epoch 31/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0329 - acc: 0.9863 - val_loss: 0.2100 - val_acc: 0.9551
# Epoch 32/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0325 - acc: 0.9865 - val_loss: 0.2224 - val_acc: 0.9555
# Epoch 33/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0315 - acc: 0.9869 - val_loss: 0.2134 - val_acc: 0.9541
# Epoch 34/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0311 - acc: 0.9871 - val_loss: 0.2248 - val_acc: 0.9558
# Epoch 35/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0302 - acc: 0.9874 - val_loss: 0.2240 - val_acc: 0.9562
# Epoch 36/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0296 - acc: 0.9877 - val_loss: 0.2254 - val_acc: 0.9562
# Epoch 37/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0292 - acc: 0.9879 - val_loss: 0.2371 - val_acc: 0.9562
# Epoch 38/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0285 - acc: 0.9882 - val_loss: 0.2248 - val_acc: 0.9554
# Epoch 39/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0282 - acc: 0.9883 - val_loss: 0.2254 - val_acc: 0.9556
# Epoch 40/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0272 - acc: 0.9887 - val_loss: 0.2449 - val_acc: 0.9561
# Epoch 41/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0266 - acc: 0.9890 - val_loss: 0.2351 - val_acc: 0.9541
# Epoch 42/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0264 - acc: 0.9891 - val_loss: 0.2264 - val_acc: 0.9547
# Epoch 43/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0262 - acc: 0.9892 - val_loss: 0.2378 - val_acc: 0.9544
# Epoch 44/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0258 - acc: 0.9893 - val_loss: 0.2531 - val_acc: 0.9551
# Epoch 45/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0243 - acc: 0.9899 - val_loss: 0.2542 - val_acc: 0.9562
# Epoch 46/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0241 - acc: 0.9900 - val_loss: 0.2506 - val_acc: 0.9554
# Epoch 47/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0238 - acc: 0.9902 - val_loss: 0.2702 - val_acc: 0.9563
# Epoch 48/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0236 - acc: 0.9903 - val_loss: 0.2620 - val_acc: 0.9551
# Epoch 49/100
# 150/150 [==============================] - 9s 60ms/step - loss: 0.0231 - acc: 0.9904 - val_loss: 0.2384 - val_acc: 0.9543
# Epoch 50/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0231 - acc: 0.9905 - val_loss: 0.2680 - val_acc: 0.9561
# Epoch 51/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0237 - acc: 0.9902 - val_loss: 0.2935 - val_acc: 0.9553
# Epoch 52/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0251 - acc: 0.9897 - val_loss: 0.2542 - val_acc: 0.9556
# Epoch 53/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0221 - acc: 0.9909 - val_loss: 0.2737 - val_acc: 0.9560
# Epoch 54/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0210 - acc: 0.9913 - val_loss: 0.2690 - val_acc: 0.9562
# Epoch 55/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0205 - acc: 0.9916 - val_loss: 0.2671 - val_acc: 0.9557
# Epoch 56/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0209 - acc: 0.9913 - val_loss: 0.2817 - val_acc: 0.9558
# Epoch 57/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0207 - acc: 0.9914 - val_loss: 0.3021 - val_acc: 0.9556
# Epoch 58/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0205 - acc: 0.9915 - val_loss: 0.2909 - val_acc: 0.9557
# Epoch 59/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0206 - acc: 0.9915 - val_loss: 0.2685 - val_acc: 0.9538
# Epoch 60/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0212 - acc: 0.9912 - val_loss: 0.2556 - val_acc: 0.9532
# Epoch 61/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0196 - acc: 0.9919 - val_loss: 0.2974 - val_acc: 0.9559
# Epoch 62/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0189 - acc: 0.9922 - val_loss: 0.2959 - val_acc: 0.9554
# Epoch 63/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0194 - acc: 0.9920 - val_loss: 0.3339 - val_acc: 0.9560
# Epoch 64/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0194 - acc: 0.9919 - val_loss: 0.2947 - val_acc: 0.9561
# Epoch 65/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0185 - acc: 0.9924 - val_loss: 0.3021 - val_acc: 0.9555
# Epoch 66/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0180 - acc: 0.9926 - val_loss: 0.2679 - val_acc: 0.9547
# Epoch 67/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0182 - acc: 0.9925 - val_loss: 0.3058 - val_acc: 0.9545
# Epoch 68/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0187 - acc: 0.9923 - val_loss: 0.2785 - val_acc: 0.9551
# Epoch 69/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0179 - acc: 0.9926 - val_loss: 0.3036 - val_acc: 0.9553
# Epoch 70/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0176 - acc: 0.9927 - val_loss: 0.3482 - val_acc: 0.9556
# Epoch 71/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0172 - acc: 0.9929 - val_loss: 0.3193 - val_acc: 0.9555
# Epoch 72/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0172 - acc: 0.9929 - val_loss: 0.3130 - val_acc: 0.9544
# Epoch 73/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0168 - acc: 0.9931 - val_loss: 0.3103 - val_acc: 0.9557
# Epoch 74/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0185 - acc: 0.9924 - val_loss: 0.3340 - val_acc: 0.9561
# Epoch 75/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0172 - acc: 0.9929 - val_loss: 0.2956 - val_acc: 0.9551
# Epoch 76/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0161 - acc: 0.9934 - val_loss: 0.3328 - val_acc: 0.9556
# Epoch 77/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0159 - acc: 0.9935 - val_loss: 0.3341 - val_acc: 0.9556
# Epoch 78/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0154 - acc: 0.9937 - val_loss: 0.3321 - val_acc: 0.9557
# Epoch 79/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0155 - acc: 0.9936 - val_loss: 0.3789 - val_acc: 0.9556
# Epoch 80/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0151 - acc: 0.9938 - val_loss: 0.3525 - val_acc: 0.9556
# Epoch 81/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0154 - acc: 0.9937 - val_loss: 0.3792 - val_acc: 0.9557
# Epoch 82/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0155 - acc: 0.9936 - val_loss: 0.3496 - val_acc: 0.9551
# Epoch 83/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0149 - acc: 0.9938 - val_loss: 0.3476 - val_acc: 0.9558
# Epoch 84/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0145 - acc: 0.9940 - val_loss: 0.3809 - val_acc: 0.9550
# Epoch 85/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0147 - acc: 0.9939 - val_loss: 0.3688 - val_acc: 0.9557
# Epoch 86/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0147 - acc: 0.9940 - val_loss: 0.3554 - val_acc: 0.9564
# Epoch 87/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0144 - acc: 0.9941 - val_loss: 0.3996 - val_acc: 0.9557
# Epoch 88/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0142 - acc: 0.9942 - val_loss: 0.3542 - val_acc: 0.9558
# Epoch 89/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0138 - acc: 0.9944 - val_loss: 0.3708 - val_acc: 0.9556
# Epoch 90/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0134 - acc: 0.9945 - val_loss: 0.4174 - val_acc: 0.9559
# Epoch 91/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0134 - acc: 0.9945 - val_loss: 0.3908 - val_acc: 0.9550
# Epoch 92/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0136 - acc: 0.9944 - val_loss: 0.3728 - val_acc: 0.9554
# Epoch 93/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0135 - acc: 0.9945 - val_loss: 0.3543 - val_acc: 0.9545
# Epoch 94/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0132 - acc: 0.9946 - val_loss: 0.4215 - val_acc: 0.9555
# Epoch 95/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0129 - acc: 0.9947 - val_loss: 0.3882 - val_acc: 0.9558
# Epoch 96/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0129 - acc: 0.9947 - val_loss: 0.3778 - val_acc: 0.9532
# Epoch 97/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0130 - acc: 0.9947 - val_loss: 0.4137 - val_acc: 0.9557
# Epoch 98/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0124 - acc: 0.9949 - val_loss: 0.4184 - val_acc: 0.9551
# Epoch 99/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0125 - acc: 0.9949 - val_loss: 0.4366 - val_acc: 0.9553
# Epoch 100/100
# 150/150 [==============================] - 9s 59ms/step - loss: 0.0136 - acc: 0.9945 - val_loss: 0.4447 - val_acc: 0.9556

# %%
#plot the training and validation IoU and loss at each epoch
loss_1 = history_1.history['loss']
val_loss_1 = history_1.history['val_loss']
epochs = range(1, len(loss_1) + 1)
plt.plot(epochs, loss_1, 'y-', label='UNet Training loss')
plt.plot(epochs, val_loss_1, 'r-', label='UNet Validation loss')
loss_2 = history_2.history['loss']
val_loss_2 = history_2.history['val_loss']
epochs = range(1, len(loss_2) + 1)
plt.plot(epochs, loss_2, 'y--', label='UNet VGG Training loss')
plt.plot(epochs, val_loss_2, 'r--', label='UNet VGG Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend()
plt.show()

acc_1 = history_1.history['acc']
val_acc_1 = history_1.history['val_acc']
acc_2 = history_2.history['acc']
val_acc_2 = history_2.history['val_acc']
epochs = range(1, len(acc_1) + 1)
plt.plot(epochs, acc_1, 'y-', label='UNet Training Acc')
plt.plot(epochs, val_acc_1, 'r-', label='UNet Validation Acc')
epochs = range(1, len(acc_2) + 1)
plt.plot(epochs, acc_2, 'y--', label='UNet VGG Training Acc')
plt.plot(epochs, val_acc_2, 'r--', label='UNet VGG Validation Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.ylim([0.8, 1])
plt.legend()
plt.show()

# %%
#Predict on the test data
y_pred_1=model_unet.predict(X_test_norm)
y_pred_argmax_1=np.argmax(y_pred_1, axis=3)
y_pred_2=model_unet_vgg.predict(X_test_norm)
y_pred_argmax_2=np.argmax(y_pred_2, axis=3)
y_test_argmax = np.argmax(y_test, axis=3)

# %%
IOU_keras_1 = MeanIoU(num_classes=2)  
IOU_keras_1.update_state(y_test_argmax, y_pred_argmax_1)
print("Mean IoU Test UNet=", IOU_keras_1.result().numpy())
IOU_keras_2 = MeanIoU(num_classes=2)  
IOU_keras_2.update_state(y_test_argmax, y_pred_argmax_2)
print("Mean IoU Test UNet VGG=", IOU_keras_2.result().numpy())
# Out:
# Mean IoU Test UNet= 0.74252594
# Mean IoU Test UNet VGG= 0.6982785

# %%
plt.figure(figsize=(15, 3))
ax1 = plt.subplot(141)
ax2 = plt.subplot(142)
ax3 = plt.subplot(143)
ax4 = plt.subplot(144)
randil = np.random.randint(0, len(X_test_norm), 1)[0]
ax1.imshow(X_test_norm[randil, : , :, 1].T)
ax2.imshow(y_test_argmax[randil, : , :].T)
ax3.imshow(y_pred_argmax_1[randil, : , :].T)
ax4.imshow(y_pred_argmax_2[randil, : , :].T)
ax1.set_title('Input')
ax2.set_title('Ground Truth')
ax3.set_title('UNet')
ax4.set_title('UNet VGG')
plt.tight_layout()
plt.show()

# %%
model_unet.save('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_1200data.h5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
model_unet_vgg.save('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_vgg_1200data.h5')

# %% [markdown]
# ## Prediction

# %%
model_unet = load_model('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_1200data.h5', compile=False)

# %%
model_unet_vgg = load_model('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_vgg_1200data.h5', compile=False)

# %%
# Prediction
seismic = np.reshape(np.fromfile("/content/drive/MyDrive/UTP_dGB_Documents/data/prediction/f3d/gxl.dat",dtype=np.single),(512,384,128))
seismic.shape
# Out:
# (512, 384, 128)

# %%
seisnorm = normalization(seismic)

# %%
def prediction(seismic, model, mode='inline'):
  # Append 2D seismic into 3D seismic
  if mode=='inline':
    predicted = []
    for i in range(seismic.shape[0]):
      val_input = seismic[i, :, :]
      patches = patchify(val_input, (128, 128), step=128)
      predicted_patches = []
      for i in range(patches.shape[0]):
        for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_3ch = np.stack((single_patch,)*3, axis=-1)
          single_patch_3ch_input = np.expand_dims(single_patch_3ch, axis=0)
          single_patch_prediction = model.predict(single_patch_3ch_input)
          single_patch_prediction_argmax = np.argmax(single_patch_prediction, axis=3)[0,:,:]
          predicted_patches.append(single_patch_prediction_argmax)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patches.shape[2], patches.shape[3]))
      reconstructed_seismic = unpatchify(predicted_patches_reshaped, val_input.shape)
      predicted.append(reconstructed_seismic)
    return np.array(predicted)
  elif mode=='crossline':
    predicted = []
    for i in range(seismic.shape[1]):
      val_input = seismic[:, i, :]
      patches = patchify(val_input, (128, 128), step=128)
      predicted_patches = []
      for i in range(patches.shape[0]):
        for j in range(patches.shape[1]):
          single_patch = patches[i,j,:,:]
          single_patch_3ch = np.stack((single_patch,)*3, axis=-1)
          single_patch_3ch_input = np.expand_dims(single_patch_3ch, axis=0)
          single_patch_prediction = model.predict(single_patch_3ch_input)
          single_patch_prediction_argmax = np.argmax(single_patch_prediction, axis=3)[0,:,:]
          predicted_patches.append(single_patch_prediction_argmax)
      predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patches.shape[2], patches.shape[3]))
      reconstructed_seismic = unpatchify(predicted_patches_reshaped, val_input.shape)
      predicted.append(reconstructed_seismic)
    return np.array(predicted)

# %%
unet_predicted_il = prediction(seisnorm, model_unet, mode='inline')
unet_predicted_xl = prediction(seisnorm, model_unet, mode='crossline')

# %%
unet_vgg_predicted_il = prediction(seisnorm, model_unet_vgg, mode='inline')
unet_vgg_predicted_xl = prediction(seisnorm, model_unet_vgg, mode='crossline')

# %%
# def prediction(model):
#   il_range = np.arange(0, 640, 128)
#   pred_3d = []
#   for i in range(384):
#     pred_2d = []
#     for j in range(0, 4):
#       il_min = il_range[j]
#       il_max = il_range[j+1]
#       seis = seismic[il_min:il_max, i, :]
#       pred = np.stack((seis,)*3, axis=-1)
#       pred_2d.append(pred)
#     pred_3d.append(np.vstack(np.argmax(model.predict(np.array(pred_2d)), axis=3)))
#   return np.array(pred_3d).reshape(512, 384, 128)

# %%
# unet_prediction = prediction(seisnorm, model_unet)

# %%
# unet_vgg_prediction = prediction(seisnorm, model_unet_vgg)

# %%
ncolors = 256
color_array = plt.get_cmap('gray')(range(ncolors))
color_array[:,-1] = np.linspace(0.0,0,ncolors)
color_array[253:256] = [1, 0.0, 0., 1]
map_object = LinearSegmentedColormap.from_list(name='fault',colors=color_array)
plt.register_cmap(cmap=map_object)

# %%
vm = np.percentile(seisnorm, 99)

# %%
il = 53
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(seisnorm[il,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0].imshow(unet_predicted_il[il, :, :].T, cmap='fault')
ax[0].set_title('UNet')
ax[1].imshow(seisnorm[il,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1].imshow(unet_vgg_predicted_il[il, :, :].T, cmap='fault')
ax[1].set_title('UNet VGG')
plt.suptitle('Inline')
plt.show()

# %%
xl = 24
fig, ax = plt.subplots(1, 2, figsize=(15, 5))
ax[0].imshow(seisnorm[:,xl,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0].imshow(unet_predicted_xl[xl, :, :].T, cmap='fault')
ax[0].set_title('UNet')
ax[1].imshow(seisnorm[:,xl,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1].imshow(unet_vgg_predicted_xl[xl, :, :].T, cmap='fault')
ax[1].set_title('UNet VGG')
plt.suptitle('Crossline')
plt.show()

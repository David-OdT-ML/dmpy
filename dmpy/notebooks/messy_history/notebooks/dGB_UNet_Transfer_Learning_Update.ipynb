# %%
# !pip install segyio
# !pip install segysak
# !pip install patchify
# !pip install segmentation_models_3D
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segyio
#   Downloading segyio-1.9.9-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (84 kB)
#      |████████████████████████████████| 84 kB 1.8 MB/s
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from segyio) (1.21.6)
# Installing collected packages: segyio
# Successfully installed segyio-1.9.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segysak
#   Downloading segysak-0.3.4-py3-none-any.whl (310 kB)
#      |████████████████████████████████| 310 kB 5.1 MB/s
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from segysak) (7.1.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.7.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from segysak) (4.64.0)
# Requirement already satisfied: dask in /usr/local/lib/python3.7/dist-packages (from segysak) (2.12.0)
# Requirement already satisfied: segyio in /usr/local/lib/python3.7/dist-packages (from segysak) (1.9.9)
# Collecting h5netcdf
#   Downloading h5netcdf-1.0.2-py2.py3-none-any.whl (24 kB)
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Requirement already satisfied: more-itertools>=8.0 in /usr/local/lib/python3.7/dist-packages (from segysak) (8.13.0)
# Collecting setuptools-scm
#   Downloading setuptools_scm-7.0.5-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 994 kB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from segysak) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.21.6)
# Requirement already satisfied: distributed in /usr/local/lib/python3.7/dist-packages (from segysak) (1.25.3)
# Requirement already satisfied: xarray in /usr/local/lib/python3.7/dist-packages (from segysak) (0.20.2)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.7.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (3.13)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.15.0)
# Requirement already satisfied: toolz>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (0.12.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.0.4)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.4.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.4.8)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.3.0)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.2.0)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.1.1)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed->segysak) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (21.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->h5netcdf->segysak) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->h5netcdf->segysak) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2022.1)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (2.0.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.1.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (57.4.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->setuptools-scm->segysak) (3.8.1)
# Installing collected packages: setuptools-scm, h5netcdf, addict, segysak
# Successfully installed addict-2.4.0 h5netcdf-1.0.2 segysak-0.3.4 setuptools-scm-7.0.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.21.6)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation_models_3D
#   Downloading segmentation_models_3D-1.0.4-py3-none-any.whl (33 kB)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 5.7 MB/s
# Collecting classification-models-3D>=1.0.6
#   Downloading classification_models_3D-1.0.6-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.4 MB/s
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_3D) (2.8.2+zzzcolab20220719082949)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (1.21.6)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (3.1.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (14.0.6)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.17.3)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.0)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.26.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.47.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (4.1.1)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (57.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.6.3)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.2)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.14.1)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.5.3)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.2.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.3.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->segmentation_models_3D) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->segmentation_models_3D) (1.5.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.23.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.8.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.4.1)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.2.0)
# Installing collected packages: keras-applications, classification-models-3D, segmentation-models-3D
# Successfully installed classification-models-3D-1.0.6 keras-applications-1.0.8 segmentation-models-3D-1.0.4

# %%
import tensorflow as tf
import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.8.2
# 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import segyio
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import segmentation_models_3D as sm
from patchify import patchify, unpatchify
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam
from segysak.segy import segy_header_scan, segy_header_scrape, get_segy_texthead, segy_loader
from keras.metrics import MeanIoU
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from matplotlib.colors import LinearSegmentedColormap
# Out:
# Segmentation Models: using `tf.keras` framework.
# /usr/local/lib/python3.7/dist-packages/segysak/segy/_segy_core.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
train_seismic_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/train/seis'
train_fault_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/train/fault'

valid_seismic_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/validation/seis'
valid_fault_path = '/content/drive/MyDrive/UTP_dGB_Documents/data/validation/fault'

# %%
train_seis_input = []
train_fault_output = []

index = np.arange(0, 129, 60)
for i in os.listdir(train_seismic_path):
  for j in index:
    # iline
    train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    # xline
    train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])
    train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])

# %%
valid_seis_input = []
valid_fault_output = []

index = np.arange(0, 129, 60)
for i in os.listdir(valid_seismic_path):
  for j in index:
    # iline
    valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    # xline
    valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])
    valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])

# %%
X_train = np.stack((train_seis_input,)*3, axis=-1)
X_test = np.stack((valid_seis_input,)*3, axis=-1)

train_mask = np.expand_dims(train_fault_output, axis=3)
y_train = tf.keras.utils.to_categorical(train_mask, num_classes=2)
test_mask = np.expand_dims(valid_fault_output, axis=3)
y_test = tf.keras.utils.to_categorical(test_mask, num_classes=2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (1200, 128, 128, 3)
# (120, 128, 128, 3)
# (1200, 128, 128, 2)
# (120, 128, 128, 2)

# %%
fig, ax = plt.subplots(1, 2, figsize=(5,5))
ax[0].imshow(X_train[1, :, :, 1].T, cmap='Greys')
ax[1].imshow(y_train[1, :, :, 1].T, cmap='Greys_r')
fig.suptitle('Training Dataset')
plt.show()

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose
from tensorflow.keras.models import Model

# %%
batch_size = 8
image_size = 128

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %%
def UNet():
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    bn = bottleneck(p4, f[4])
    
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model_unet = UNet()
model_unet.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
train_steps = len(X_train)//batch_size
valid_steps = len(X_test)//batch_size

# %%
history_1 = model_unet.fit(X_train, 
                    y_train,
                    batch_size=batch_size, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 150/150 [==============================] - 19s 25ms/step - loss: 0.2529 - acc: 0.9296 - val_loss: 0.2240 - val_acc: 0.9335
# Epoch 2/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.1812 - acc: 0.9408 - val_loss: 0.1580 - val_acc: 0.9463
# Epoch 3/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.1457 - acc: 0.9512 - val_loss: 0.1476 - val_acc: 0.9505
# Epoch 4/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1286 - acc: 0.9558 - val_loss: 0.1283 - val_acc: 0.9554
# Epoch 5/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1197 - acc: 0.9581 - val_loss: 0.1314 - val_acc: 0.9564
# Epoch 6/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1130 - acc: 0.9595 - val_loss: 0.1280 - val_acc: 0.9578
# Epoch 7/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.1059 - acc: 0.9615 - val_loss: 0.1252 - val_acc: 0.9595
# Epoch 8/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.1020 - acc: 0.9628 - val_loss: 0.1166 - val_acc: 0.9592
# Epoch 9/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0972 - acc: 0.9637 - val_loss: 0.1163 - val_acc: 0.9611
# Epoch 10/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0928 - acc: 0.9650 - val_loss: 0.1166 - val_acc: 0.9593
# Epoch 11/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0903 - acc: 0.9655 - val_loss: 0.1162 - val_acc: 0.9625
# Epoch 12/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0860 - acc: 0.9667 - val_loss: 0.1168 - val_acc: 0.9605
# Epoch 13/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0815 - acc: 0.9680 - val_loss: 0.1188 - val_acc: 0.9622
# Epoch 14/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0773 - acc: 0.9688 - val_loss: 0.1290 - val_acc: 0.9623
# Epoch 15/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0730 - acc: 0.9700 - val_loss: 0.1280 - val_acc: 0.9620
# Epoch 16/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0683 - acc: 0.9714 - val_loss: 0.1219 - val_acc: 0.9595
# Epoch 17/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0686 - acc: 0.9714 - val_loss: 0.1281 - val_acc: 0.9629
# Epoch 18/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0616 - acc: 0.9740 - val_loss: 0.1277 - val_acc: 0.9610
# Epoch 19/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0584 - acc: 0.9751 - val_loss: 0.1507 - val_acc: 0.9628
# Epoch 20/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0584 - acc: 0.9753 - val_loss: 0.1386 - val_acc: 0.9619
# Epoch 21/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0573 - acc: 0.9756 - val_loss: 0.1357 - val_acc: 0.9607
# Epoch 22/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0557 - acc: 0.9764 - val_loss: 0.1521 - val_acc: 0.9617
# Epoch 23/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0529 - acc: 0.9774 - val_loss: 0.1578 - val_acc: 0.9625
# Epoch 24/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0497 - acc: 0.9788 - val_loss: 0.1673 - val_acc: 0.9627
# Epoch 25/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0462 - acc: 0.9802 - val_loss: 0.1794 - val_acc: 0.9626
# Epoch 26/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0442 - acc: 0.9811 - val_loss: 0.1907 - val_acc: 0.9624
# Epoch 27/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0441 - acc: 0.9812 - val_loss: 0.1792 - val_acc: 0.9624
# Epoch 28/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0418 - acc: 0.9820 - val_loss: 0.1974 - val_acc: 0.9628
# Epoch 29/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0407 - acc: 0.9826 - val_loss: 0.1880 - val_acc: 0.9620
# Epoch 30/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0398 - acc: 0.9830 - val_loss: 0.1970 - val_acc: 0.9626
# Epoch 31/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0392 - acc: 0.9833 - val_loss: 0.2021 - val_acc: 0.9631
# Epoch 32/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0379 - acc: 0.9839 - val_loss: 0.1928 - val_acc: 0.9628
# Epoch 33/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0390 - acc: 0.9834 - val_loss: 0.1870 - val_acc: 0.9619
# Epoch 34/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0389 - acc: 0.9834 - val_loss: 0.1919 - val_acc: 0.9624
# Epoch 35/100
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0365 - acc: 0.9844 - val_loss: 0.1922 - val_acc: 0.9613
# Epoch 36/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0358 - acc: 0.9847 - val_loss: 0.2139 - val_acc: 0.9620
# Epoch 37/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0341 - acc: 0.9855 - val_loss: 0.2153 - val_acc: 0.9627
# Epoch 38/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0374 - acc: 0.9842 - val_loss: 0.1870 - val_acc: 0.9620
# Epoch 39/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0347 - acc: 0.9852 - val_loss: 0.2077 - val_acc: 0.9624
# Epoch 40/100
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0320 - acc: 0.9865 - val_loss: 0.2110 - val_acc: 0.9613
# Epoch 41/100
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0310 - acc: 0.9869 - val_loss: 0.2131 - val_acc: 0.9625
# Epoch 42/100
# 150/150 [==============================] - 3s 20ms/step - loss: 0.0310 - acc: 0.9869 - val_loss: 0.2375 - val_acc: 0.9624
# Epoch 43/100
# 150/150 [==============================] - 3s 21ms/step - loss: 0.0310 - acc: 0.9869 - val_loss: 0.2379 - val_acc: 0.9623
# Epoch 44/100
# 150/150 [==============================] - 3s 20ms/step - loss: 0.0314 - acc: 0.9867 - val_loss: 0.2351 - val_acc: 0.9626
# Epoch 45/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0304 - acc: 0.9872 - val_loss: 0.2240 - val_acc: 0.9625
# Epoch 46/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0296 - acc: 0.9875 - val_loss: 0.2380 - val_acc: 0.9625
# Epoch 47/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0288 - acc: 0.9878 - val_loss: 0.2397 - val_acc: 0.9624
# Epoch 48/100
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0282 - acc: 0.9881 - val_loss: 0.2391 - val_acc: 0.9626
# Epoch 49/100
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0287 - acc: 0.9879 - val_loss: 0.2570 - val_acc: 0.9632
# Epoch 50/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0285 - acc: 0.9880 - val_loss: 0.2360 - val_acc: 0.9628
# Epoch 51/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0281 - acc: 0.9881 - val_loss: 0.2226 - val_acc: 0.9621
# Epoch 52/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0279 - acc: 0.9882 - val_loss: 0.2404 - val_acc: 0.9628
# Epoch 53/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0279 - acc: 0.9882 - val_loss: 0.2611 - val_acc: 0.9629
# Epoch 54/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0430 - acc: 0.9827 - val_loss: 0.1332 - val_acc: 0.9601
# Epoch 55/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0579 - acc: 0.9769 - val_loss: 0.1552 - val_acc: 0.9600
# Epoch 56/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0427 - acc: 0.9823 - val_loss: 0.1967 - val_acc: 0.9624
# Epoch 57/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0313 - acc: 0.9868 - val_loss: 0.2216 - val_acc: 0.9626
# Epoch 58/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0274 - acc: 0.9884 - val_loss: 0.2375 - val_acc: 0.9626
# Epoch 59/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0254 - acc: 0.9894 - val_loss: 0.2635 - val_acc: 0.9630
# Epoch 60/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0243 - acc: 0.9898 - val_loss: 0.2622 - val_acc: 0.9625
# Epoch 61/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0239 - acc: 0.9899 - val_loss: 0.2912 - val_acc: 0.9628
# Epoch 62/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0236 - acc: 0.9901 - val_loss: 0.2762 - val_acc: 0.9629
# Epoch 63/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0236 - acc: 0.9901 - val_loss: 0.2917 - val_acc: 0.9629
# Epoch 64/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0232 - acc: 0.9902 - val_loss: 0.2735 - val_acc: 0.9624
# Epoch 65/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0233 - acc: 0.9902 - val_loss: 0.2891 - val_acc: 0.9627
# Epoch 66/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0236 - acc: 0.9900 - val_loss: 0.2867 - val_acc: 0.9628
# Epoch 67/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0232 - acc: 0.9902 - val_loss: 0.2846 - val_acc: 0.9631
# Epoch 68/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0234 - acc: 0.9901 - val_loss: 0.2686 - val_acc: 0.9628
# Epoch 69/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0235 - acc: 0.9901 - val_loss: 0.2942 - val_acc: 0.9627
# Epoch 70/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0231 - acc: 0.9903 - val_loss: 0.2859 - val_acc: 0.9629
# Epoch 71/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0228 - acc: 0.9904 - val_loss: 0.2851 - val_acc: 0.9629
# Epoch 72/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0225 - acc: 0.9905 - val_loss: 0.2898 - val_acc: 0.9625
# Epoch 73/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0228 - acc: 0.9903 - val_loss: 0.2784 - val_acc: 0.9629
# Epoch 74/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0228 - acc: 0.9904 - val_loss: 0.3001 - val_acc: 0.9625
# Epoch 75/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0227 - acc: 0.9904 - val_loss: 0.2999 - val_acc: 0.9629
# Epoch 76/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0225 - acc: 0.9905 - val_loss: 0.2899 - val_acc: 0.9629
# Epoch 77/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0229 - acc: 0.9903 - val_loss: 0.2771 - val_acc: 0.9629
# Epoch 78/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0224 - acc: 0.9906 - val_loss: 0.2924 - val_acc: 0.9627
# Epoch 79/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0229 - acc: 0.9903 - val_loss: 0.2726 - val_acc: 0.9631
# Epoch 80/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0223 - acc: 0.9906 - val_loss: 0.2890 - val_acc: 0.9630
# Epoch 81/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0218 - acc: 0.9908 - val_loss: 0.2909 - val_acc: 0.9629
# Epoch 82/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0212 - acc: 0.9911 - val_loss: 0.3019 - val_acc: 0.9628
# Epoch 83/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0212 - acc: 0.9910 - val_loss: 0.3112 - val_acc: 0.9629
# Epoch 84/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0215 - acc: 0.9909 - val_loss: 0.3158 - val_acc: 0.9631
# Epoch 85/100
# 150/150 [==============================] - 3s 18ms/step - loss: 0.0216 - acc: 0.9909 - val_loss: 0.3191 - val_acc: 0.9630
# Epoch 86/100
# 150/150 [==============================] - 3s 19ms/step - loss: 0.0211 - acc: 0.9911 - val_loss: 0.3187 - val_acc: 0.9630
# Epoch 87/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0208 - acc: 0.9912 - val_loss: 0.2960 - val_acc: 0.9629
# Epoch 88/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0210 - acc: 0.9911 - val_loss: 0.3136 - val_acc: 0.9630
# Epoch 89/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0209 - acc: 0.9912 - val_loss: 0.2850 - val_acc: 0.9627
# Epoch 90/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0217 - acc: 0.9909 - val_loss: 0.2847 - val_acc: 0.9628
# Epoch 91/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0224 - acc: 0.9905 - val_loss: 0.2779 - val_acc: 0.9629
# Epoch 92/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0216 - acc: 0.9909 - val_loss: 0.2994 - val_acc: 0.9633
# Epoch 93/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0208 - acc: 0.9913 - val_loss: 0.2873 - val_acc: 0.9631
# Epoch 94/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0213 - acc: 0.9910 - val_loss: 0.2991 - val_acc: 0.9628
# Epoch 95/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0279 - acc: 0.9884 - val_loss: 0.1518 - val_acc: 0.9562
# Epoch 96/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0569 - acc: 0.9777 - val_loss: 0.1616 - val_acc: 0.9609
# Epoch 97/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0352 - acc: 0.9853 - val_loss: 0.1812 - val_acc: 0.9616
# Epoch 98/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0278 - acc: 0.9883 - val_loss: 0.2385 - val_acc: 0.9632
# Epoch 99/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0220 - acc: 0.9907 - val_loss: 0.2488 - val_acc: 0.9630
# Epoch 100/100
# 150/150 [==============================] - 3s 17ms/step - loss: 0.0199 - acc: 0.9916 - val_loss: 0.2719 - val_acc: 0.9625

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model_unet)

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_vgg19_unet(input_shape):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained VGG19 Model """
    vgg19 = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)

    """ Encoder """
    s1 = vgg19.get_layer("block1_conv2").output         ## (512 x 512)
    s2 = vgg19.get_layer("block2_conv2").output         ## (256 x 256)
    s3 = vgg19.get_layer("block3_conv4").output         ## (128 x 128)
    s4 = vgg19.get_layer("block4_conv4").output         ## (64 x 64)

    """ Bridge """
    b1 = vgg19.get_layer("block5_conv4").output         ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

    """ Output """
    outputs = Conv2D(2, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="VGG19_U-Net")
    return model

# %%
input_shape = (128,128, 3)
model_unet_vgg = build_vgg19_unet(input_shape)
model_unet_vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 1s 0us/step
# 80150528/80134624 [==============================] - 1s 0us/step
# Model: "VGG19_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_2[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  1049088    ['block5_conv4[0][0]']
#  ose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'block4_conv4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 512)  2048       ['conv2d_19[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_20[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_1[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_21[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_22[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_3[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'block2_conv2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_6[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_23[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_24[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 64  256        ['conv2d_25[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 64  256        ['conv2d_26[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 2)  130         ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 31,172,098
# Trainable params: 31,168,258
# Non-trainable params: 3,840
# __________________________________________________________________________________________________

# %%
model_unet_vgg.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
plot_model(model_unet_vgg)

# %%
history_2 = model_unet_vgg.fit(X_train, 
                    y_train,
                    batch_size=8, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test, y_test))
# Out:
# Epoch 1/100
# 150/150 [==============================] - 17s 83ms/step - loss: 0.2368 - acc: 0.9358 - val_loss: 0.1713 - val_acc: 0.9465
# Epoch 2/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.1280 - acc: 0.9576 - val_loss: 0.1334 - val_acc: 0.9538
# Epoch 3/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.1142 - acc: 0.9603 - val_loss: 0.1217 - val_acc: 0.9586
# Epoch 4/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.1069 - acc: 0.9622 - val_loss: 0.1207 - val_acc: 0.9610
# Epoch 5/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0971 - acc: 0.9651 - val_loss: 0.1170 - val_acc: 0.9611
# Epoch 6/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0928 - acc: 0.9662 - val_loss: 0.1044 - val_acc: 0.9640
# Epoch 7/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0872 - acc: 0.9676 - val_loss: 0.1045 - val_acc: 0.9641
# Epoch 8/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0830 - acc: 0.9689 - val_loss: 0.1049 - val_acc: 0.9648
# Epoch 9/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0786 - acc: 0.9698 - val_loss: 0.1084 - val_acc: 0.9648
# Epoch 10/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0750 - acc: 0.9707 - val_loss: 0.1151 - val_acc: 0.9645
# Epoch 11/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0745 - acc: 0.9707 - val_loss: 0.1176 - val_acc: 0.9612
# Epoch 12/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0705 - acc: 0.9721 - val_loss: 0.1091 - val_acc: 0.9660
# Epoch 13/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0646 - acc: 0.9740 - val_loss: 0.1143 - val_acc: 0.9653
# Epoch 14/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0631 - acc: 0.9746 - val_loss: 0.1148 - val_acc: 0.9610
# Epoch 15/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0608 - acc: 0.9751 - val_loss: 0.1119 - val_acc: 0.9649
# Epoch 16/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0562 - acc: 0.9769 - val_loss: 0.1150 - val_acc: 0.9656
# Epoch 17/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0529 - acc: 0.9782 - val_loss: 0.1170 - val_acc: 0.9660
# Epoch 18/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0521 - acc: 0.9784 - val_loss: 0.1263 - val_acc: 0.9655
# Epoch 19/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0497 - acc: 0.9793 - val_loss: 0.1215 - val_acc: 0.9639
# Epoch 20/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0482 - acc: 0.9799 - val_loss: 0.1346 - val_acc: 0.9655
# Epoch 21/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0452 - acc: 0.9811 - val_loss: 0.1283 - val_acc: 0.9660
# Epoch 22/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0432 - acc: 0.9819 - val_loss: 0.1265 - val_acc: 0.9653
# Epoch 23/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0418 - acc: 0.9825 - val_loss: 0.1298 - val_acc: 0.9658
# Epoch 24/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0396 - acc: 0.9834 - val_loss: 0.1369 - val_acc: 0.9660
# Epoch 25/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0381 - acc: 0.9840 - val_loss: 0.1373 - val_acc: 0.9656
# Epoch 26/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0371 - acc: 0.9845 - val_loss: 0.1445 - val_acc: 0.9647
# Epoch 27/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0365 - acc: 0.9847 - val_loss: 0.1409 - val_acc: 0.9662
# Epoch 28/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0339 - acc: 0.9858 - val_loss: 0.1457 - val_acc: 0.9657
# Epoch 29/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0326 - acc: 0.9864 - val_loss: 0.1466 - val_acc: 0.9657
# Epoch 30/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0310 - acc: 0.9870 - val_loss: 0.1550 - val_acc: 0.9657
# Epoch 31/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0298 - acc: 0.9875 - val_loss: 0.1517 - val_acc: 0.9657
# Epoch 32/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0282 - acc: 0.9882 - val_loss: 0.1596 - val_acc: 0.9655
# Epoch 33/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0284 - acc: 0.9881 - val_loss: 0.1689 - val_acc: 0.9653
# Epoch 34/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0289 - acc: 0.9879 - val_loss: 0.1541 - val_acc: 0.9654
# Epoch 35/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0274 - acc: 0.9886 - val_loss: 0.1548 - val_acc: 0.9653
# Epoch 36/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0264 - acc: 0.9890 - val_loss: 0.1618 - val_acc: 0.9648
# Epoch 37/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0253 - acc: 0.9895 - val_loss: 0.1630 - val_acc: 0.9652
# Epoch 38/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0244 - acc: 0.9898 - val_loss: 0.1733 - val_acc: 0.9655
# Epoch 39/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0242 - acc: 0.9899 - val_loss: 0.1781 - val_acc: 0.9653
# Epoch 40/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0234 - acc: 0.9902 - val_loss: 0.1782 - val_acc: 0.9653
# Epoch 41/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0240 - acc: 0.9900 - val_loss: 0.1721 - val_acc: 0.9650
# Epoch 42/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0221 - acc: 0.9908 - val_loss: 0.1769 - val_acc: 0.9656
# Epoch 43/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0216 - acc: 0.9910 - val_loss: 0.1834 - val_acc: 0.9650
# Epoch 44/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0217 - acc: 0.9909 - val_loss: 0.1949 - val_acc: 0.9650
# Epoch 45/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0208 - acc: 0.9913 - val_loss: 0.1921 - val_acc: 0.9648
# Epoch 46/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0204 - acc: 0.9915 - val_loss: 0.1908 - val_acc: 0.9657
# Epoch 47/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0195 - acc: 0.9918 - val_loss: 0.1912 - val_acc: 0.9652
# Epoch 48/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0190 - acc: 0.9921 - val_loss: 0.2005 - val_acc: 0.9655
# Epoch 49/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0287 - acc: 0.9883 - val_loss: 0.1895 - val_acc: 0.9611
# Epoch 50/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0403 - acc: 0.9836 - val_loss: 0.1408 - val_acc: 0.9575
# Epoch 51/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0252 - acc: 0.9894 - val_loss: 0.1612 - val_acc: 0.9652
# Epoch 52/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0188 - acc: 0.9922 - val_loss: 0.1874 - val_acc: 0.9654
# Epoch 53/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0165 - acc: 0.9932 - val_loss: 0.1968 - val_acc: 0.9654
# Epoch 54/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0164 - acc: 0.9932 - val_loss: 0.2099 - val_acc: 0.9654
# Epoch 55/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0164 - acc: 0.9932 - val_loss: 0.2124 - val_acc: 0.9659
# Epoch 56/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0164 - acc: 0.9932 - val_loss: 0.2055 - val_acc: 0.9656
# Epoch 57/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0158 - acc: 0.9934 - val_loss: 0.2206 - val_acc: 0.9657
# Epoch 58/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0153 - acc: 0.9936 - val_loss: 0.2230 - val_acc: 0.9655
# Epoch 59/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0144 - acc: 0.9940 - val_loss: 0.2157 - val_acc: 0.9652
# Epoch 60/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0142 - acc: 0.9941 - val_loss: 0.2375 - val_acc: 0.9652
# Epoch 61/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0142 - acc: 0.9941 - val_loss: 0.2349 - val_acc: 0.9654
# Epoch 62/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0142 - acc: 0.9941 - val_loss: 0.2211 - val_acc: 0.9652
# Epoch 63/100
# 150/150 [==============================] - 12s 81ms/step - loss: 0.0136 - acc: 0.9944 - val_loss: 0.2273 - val_acc: 0.9653
# Epoch 64/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0132 - acc: 0.9945 - val_loss: 0.2276 - val_acc: 0.9647
# Epoch 65/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0129 - acc: 0.9947 - val_loss: 0.2379 - val_acc: 0.9646
# Epoch 66/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0130 - acc: 0.9946 - val_loss: 0.2360 - val_acc: 0.9652
# Epoch 67/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0131 - acc: 0.9946 - val_loss: 0.2530 - val_acc: 0.9649
# Epoch 68/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0125 - acc: 0.9949 - val_loss: 0.2405 - val_acc: 0.9650
# Epoch 69/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0125 - acc: 0.9949 - val_loss: 0.2559 - val_acc: 0.9650
# Epoch 70/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0119 - acc: 0.9951 - val_loss: 0.2505 - val_acc: 0.9654
# Epoch 71/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0118 - acc: 0.9952 - val_loss: 0.2464 - val_acc: 0.9652
# Epoch 72/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0115 - acc: 0.9953 - val_loss: 0.2743 - val_acc: 0.9654
# Epoch 73/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0114 - acc: 0.9953 - val_loss: 0.2723 - val_acc: 0.9651
# Epoch 74/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0107 - acc: 0.9956 - val_loss: 0.2627 - val_acc: 0.9649
# Epoch 75/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0105 - acc: 0.9957 - val_loss: 0.2842 - val_acc: 0.9650
# Epoch 76/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0107 - acc: 0.9956 - val_loss: 0.2684 - val_acc: 0.9650
# Epoch 77/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0105 - acc: 0.9957 - val_loss: 0.2639 - val_acc: 0.9647
# Epoch 78/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0107 - acc: 0.9956 - val_loss: 0.2701 - val_acc: 0.9648
# Epoch 79/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0100 - acc: 0.9959 - val_loss: 0.2853 - val_acc: 0.9648
# Epoch 80/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0097 - acc: 0.9961 - val_loss: 0.2709 - val_acc: 0.9649
# Epoch 81/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0095 - acc: 0.9961 - val_loss: 0.2994 - val_acc: 0.9653
# Epoch 82/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0095 - acc: 0.9962 - val_loss: 0.2825 - val_acc: 0.9650
# Epoch 83/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0085 - acc: 0.9966 - val_loss: 0.3091 - val_acc: 0.9652
# Epoch 84/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0079 - acc: 0.9969 - val_loss: 0.3103 - val_acc: 0.9653
# Epoch 85/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0078 - acc: 0.9969 - val_loss: 0.3134 - val_acc: 0.9652
# Epoch 86/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0077 - acc: 0.9969 - val_loss: 0.3137 - val_acc: 0.9650
# Epoch 87/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0079 - acc: 0.9969 - val_loss: 0.3330 - val_acc: 0.9651
# Epoch 88/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0077 - acc: 0.9970 - val_loss: 0.3157 - val_acc: 0.9649
# Epoch 89/100
# 150/150 [==============================] - 12s 81ms/step - loss: 0.0074 - acc: 0.9971 - val_loss: 0.3296 - val_acc: 0.9651
# Epoch 90/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0069 - acc: 0.9973 - val_loss: 0.3347 - val_acc: 0.9650
# Epoch 91/100
# 150/150 [==============================] - 12s 80ms/step - loss: 0.0071 - acc: 0.9972 - val_loss: 0.3309 - val_acc: 0.9649
# Epoch 92/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0072 - acc: 0.9972 - val_loss: 0.3095 - val_acc: 0.9647
# Epoch 93/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0072 - acc: 0.9972 - val_loss: 0.3266 - val_acc: 0.9649
# Epoch 94/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0065 - acc: 0.9975 - val_loss: 0.3088 - val_acc: 0.9651
# Epoch 95/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0065 - acc: 0.9975 - val_loss: 0.3393 - val_acc: 0.9648
# Epoch 96/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0062 - acc: 0.9976 - val_loss: 0.3474 - val_acc: 0.9649
# Epoch 97/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0061 - acc: 0.9976 - val_loss: 0.3418 - val_acc: 0.9650
# Epoch 98/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0057 - acc: 0.9978 - val_loss: 0.3505 - val_acc: 0.9649
# Epoch 99/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0054 - acc: 0.9979 - val_loss: 0.3476 - val_acc: 0.9650
# Epoch 100/100
# 150/150 [==============================] - 12s 79ms/step - loss: 0.0050 - acc: 0.9981 - val_loss: 0.3617 - val_acc: 0.9647

# %%
#plot the training and validation IoU and loss at each epoch
loss_1 = history_1.history['loss']
val_loss_1 = history_1.history['val_loss']
epochs = range(1, 100 + 1)
plt.plot(epochs, loss_1, 'y-', label='UNet Training loss')
plt.plot(epochs, val_loss_1, 'r-', label='UNet Validation loss')
loss_2 = history_2.history['loss']
val_loss_2 = history_2.history['val_loss']
epochs = range(1, 100 + 1)
plt.plot(epochs, loss_2, 'y--', label='UNet VGG Training loss')
plt.plot(epochs, val_loss_2, 'r--', label='UNet VGG Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend()
plt.show()

acc_1 = history_1.history['acc']
val_acc_1 = history_1.history['val_acc']
acc_2 = history_2.history['acc']
val_acc_2 = history_2.history['val_acc']

plt.plot(epochs, acc_1, 'y-', label='UNet Training Acc')
plt.plot(epochs, val_acc_1, 'r-', label='UNet Validation Acc')
plt.plot(epochs, acc_2, 'y--', label='UNet VGG Training Acc')
plt.plot(epochs, val_acc_2, 'r--', label='UNet VGG Validation Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.ylim([0.8, 1])
plt.legend()
plt.show()

# %%
model_unet.save('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_1200data.h5')

# %%
model_unet_vgg.save('/content/drive/MyDrive/UTP_dGB_Documents/model/model_unet_vgg_1200data.h5')

# %%
#Predict on the test data
y_pred_1=model_unet.predict(X_test)
y_pred_argmax_1=np.argmax(y_pred_1, axis=3)
y_pred_2=model_unet_vgg.predict(X_test)
y_pred_argmax_2=np.argmax(y_pred_2, axis=3)
y_test_argmax = np.argmax(y_test, axis=3)

# %%
IOU_keras_1 = MeanIoU(num_classes=2)  
IOU_keras_1.update_state(y_test_argmax, y_pred_argmax_1)
print("Mean IoU Test UNet=", IOU_keras_1.result().numpy())
IOU_keras_2 = MeanIoU(num_classes=2)  
IOU_keras_2.update_state(y_test_argmax, y_pred_argmax_2)
print("Mean IoU Test UNet VGG=", IOU_keras_2.result().numpy())
# Out:
# Mean IoU Test UNet= 0.74329394
# Mean IoU Test UNet VGG= 0.76304585

# %%
plt.figure(figsize=(15, 3))
ax1 = plt.subplot(141)
ax2 = plt.subplot(142)
ax3 = plt.subplot(143)
ax4 = plt.subplot(144)
randil = np.random.randint(0, len(X_test), 1)[0]
ax1.imshow(X_test[randil, : , :, 1].T)
ax2.imshow(y_test_argmax[randil, : , :].T)
ax3.imshow(y_pred_argmax_1[randil, : , :].T)
ax4.imshow(y_pred_argmax_2[randil, : , :].T)
ax1.set_title('Input')
ax2.set_title('Ground Truth')
ax3.set_title('UNet')
ax4.set_title('UNet VGG')
plt.tight_layout()
plt.show()

# %%
# Prediction
seismic = np.reshape(np.fromfile("/content/drive/MyDrive/UTP_dGB_Documents/data/prediction/f3d/gxl.dat",dtype=np.single),(512,384,128))
seismic.shape
# Out:
# (512, 384, 128)

# %%
# Normalization
clipFactor = 2.5
std0 = np.std(seismic)
stdClip = std0 * clipFactor
print(std0)
print(stdClip)
clippedCube = np.clip(seismic, -stdClip, +stdClip)
normalCube = np.asarray(clippedCube / stdClip, dtype='single')
# Out:
# 2966.2146
# 7415.5364990234375

# %%
def prediction(seismic, model):
  # Append 2D seismic into 3D seismic
  predicted = []
  for i in range(512):
    val_input = seismic[i, :, :]
    patches = patchify(val_input, (128, 128), step=128)
    predicted_patches = []
    for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
        single_patch = patches[i,j,:,:]
        single_patch_3ch = np.stack((single_patch,)*3, axis=-1)
        single_patch_3ch_input = np.expand_dims(single_patch_3ch, axis=0)
        single_patch_prediction = model.predict(single_patch_3ch_input)
        single_patch_prediction_argmax = np.argmax(single_patch_prediction, axis=3)[0,:,:]
        predicted_patches.append(single_patch_prediction_argmax)
    predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patches.shape[2], patches.shape[3]))
    reconstructed_seismic = unpatchify(predicted_patches_reshaped, val_input.shape)
    predicted.append(reconstructed_seismic)
  return np.reshape(predicted, (512, 384, 128))

# %%
# def prediction(model):
#   il_range = np.arange(0, 640, 128)
#   pred_3d = []
#   for i in range(384):
#     pred_2d = []
#     for j in range(0, 4):
#       il_min = il_range[j]
#       il_max = il_range[j+1]
#       seis = seismic[il_min:il_max, i, :]
#       pred = np.stack((seis,)*3, axis=-1)
#       pred_2d.append(pred)
#     pred_3d.append(np.vstack(np.argmax(model.predict(np.array(pred_2d)), axis=3)))
#   return np.array(pred_3d).reshape(512, 384, 128)

# %%
unet_prediction = prediction(normalCube, model_unet)

# %%
unet_vgg_prediction = prediction(normalCube, model_unet_vgg)

# %%
ncolors = 256
color_array = plt.get_cmap('gray')(range(ncolors))
color_array[:,-1] = np.linspace(0.0,0,ncolors)
color_array[255:256] = [1, 0.0, 0., 1]
map_object = LinearSegmentedColormap.from_list(name='fault',colors=color_array)
plt.register_cmap(cmap=map_object)

# %%
vm = np.percentile(normalCube, 99)

# %%
fig, ax = plt.subplots(1, 2, figsize=(25, 8))
ax[0].imshow(normalCube[114,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0].imshow(unet_prediction[114, :, :].T, cmap='fault')
ax[0].set_title('UNet')
ax[1].imshow(normalCube[114,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1].imshow(unet_vgg_prediction[114, :, :].T, cmap='fault')
ax[1].set_title('UNet VGG')
plt.show()

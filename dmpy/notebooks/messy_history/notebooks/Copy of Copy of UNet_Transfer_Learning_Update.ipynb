# %%
# !pip install segyio
# !pip install segysak
# !pip install patchify
# !pip install segmentation_models_3D
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segyio
#   Downloading segyio-1.9.9-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (84 kB)
#      |████████████████████████████████| 84 kB 2.6 MB/s
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.7/dist-packages (from segyio) (1.21.6)
# Installing collected packages: segyio
# Successfully installed segyio-1.9.9
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segysak
#   Downloading segysak-0.3.4-py3-none-any.whl (310 kB)
#      |████████████████████████████████| 310 kB 8.0 MB/s
# Collecting addict
#   Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Collecting h5netcdf
#   Downloading h5netcdf-1.0.2-py2.py3-none-any.whl (24 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from segysak) (4.64.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from segysak) (7.1.2)
# Requirement already satisfied: dask in /usr/local/lib/python3.7/dist-packages (from segysak) (2.12.0)
# Requirement already satisfied: more-itertools>=8.0 in /usr/local/lib/python3.7/dist-packages (from segysak) (8.14.0)
# Collecting setuptools-scm
#   Downloading setuptools_scm-7.0.5-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.8 MB/s
# Requirement already satisfied: xarray in /usr/local/lib/python3.7/dist-packages (from segysak) (0.20.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from segysak) (1.3.5)
# Requirement already satisfied: distributed in /usr/local/lib/python3.7/dist-packages (from segysak) (1.25.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.21.6)
# Requirement already satisfied: segyio in /usr/local/lib/python3.7/dist-packages (from segysak) (1.9.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from segysak) (1.7.3)
# Requirement already satisfied: zict>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.2.0)
# Requirement already satisfied: sortedcontainers!=2.0.0,!=2.0.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (2.4.0)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.4.8)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.15.0)
# Requirement already satisfied: tornado>=4.5.1 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (5.1.1)
# Requirement already satisfied: toolz>=0.7.4 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (0.12.0)
# Requirement already satisfied: tblib in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.7.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.0.4)
# Requirement already satisfied: cloudpickle>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (1.3.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from distributed->segysak) (3.13)
# Requirement already satisfied: heapdict in /usr/local/lib/python3.7/dist-packages (from zict>=0.1.3->distributed->segysak) (1.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (3.1.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from h5netcdf->segysak) (21.3)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->h5netcdf->segysak) (1.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->h5netcdf->segysak) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->segysak) (2022.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (57.4.0)
# Requirement already satisfied: tomli>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (2.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.12.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from setuptools-scm->segysak) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->setuptools-scm->segysak) (3.8.1)
# Installing collected packages: setuptools-scm, h5netcdf, addict, segysak
# Successfully installed addict-2.4.0 h5netcdf-1.0.2 segysak-0.3.4 setuptools-scm-7.0.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting patchify
#   Downloading patchify-0.2.3-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.7/dist-packages (from patchify) (1.21.6)
# Installing collected packages: patchify
# Successfully installed patchify-0.2.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting segmentation_models_3D
#   Downloading segmentation_models_3D-1.0.4-py3-none-any.whl (33 kB)
# Requirement already satisfied: tensorflow>=2.8.0 in /usr/local/lib/python3.7/dist-packages (from segmentation_models_3D) (2.8.2+zzzcolab20220719082949)
# Collecting keras-applications>=1.0.8
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.3 MB/s
# Collecting classification-models-3D>=1.0.6
#   Downloading classification_models_3D-1.0.6-py3-none-any.whl (62 kB)
#      |████████████████████████████████| 62 kB 1.6 MB/s
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.8->segmentation_models_3D) (1.21.6)
# Requirement already satisfied: gast>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.5.3)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.47.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (57.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.17.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.15.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.2)
# Requirement already satisfied: flatbuffers>=1.12 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.0)
# Requirement already satisfied: keras<2.9,>=2.8.0rc0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: absl-py>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.2.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.26.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.14.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (3.3.0)
# Requirement already satisfied: libclang>=9.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (14.0.6)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (0.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (4.1.1)
# Requirement already satisfied: tensorflow-estimator<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.6.3)
# Requirement already satisfied: tensorboard<2.9,>=2.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (2.8.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow>=2.8.0->segmentation_models_3D) (1.1.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.7/dist-packages (from astunparse>=1.6.0->tensorflow>=2.8.0->segmentation_models_3D) (0.37.1)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.8->segmentation_models_3D) (1.5.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.4.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.23.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (0.4.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (2022.6.15)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.0.4)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.9,>=2.8->tensorflow>=2.8.0->segmentation_models_3D) (3.2.0)
# Installing collected packages: keras-applications, classification-models-3D, segmentation-models-3D
# Successfully installed classification-models-3D-1.0.6 keras-applications-1.0.8 segmentation-models-3D-1.0.4

# %%
import tensorflow as tf
import keras
print(tf.__version__)
print(keras.__version__)
# Out:
# 2.8.2
# 2.8.0

# %%
from google.colab import drive
drive.mount('/content/drive',force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import segyio
import shutil
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import segmentation_models_3D as sm
from patchify import patchify, unpatchify
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.optimizers import Adam
from segysak.segy import segy_header_scan, segy_header_scrape, get_segy_texthead, segy_loader
from keras.metrics import MeanIoU
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
from matplotlib.colors import LinearSegmentedColormap
# Out:
# Segmentation Models: using `tf.keras` framework.
# /usr/local/lib/python3.7/dist-packages/segysak/segy/_segy_core.py:7: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
train_seismic_path = '/content/drive/My Drive/UTP_dGB_Documents/data/train/seis'
train_fault_path = '/content/drive/My Drive/UTP_dGB_Documents/data/train/fault'

valid_seismic_path = '/content/drive/My Drive/UTP_dGB_Documents/data/validation/seis'
valid_fault_path = '/content/drive/My Drive/UTP_dGB_Documents/data/validation/fault'

# %%
train_seis_input = []
train_fault_output = []

index = [60, 120]
for i in os.listdir(train_seismic_path):
  for j in index:
    # iline
    train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    # xline
    train_seis_input.append(np.reshape(np.fromfile(train_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])
    train_fault_output.append(np.reshape(np.fromfile(train_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])

# %%
valid_seis_input = []
valid_fault_output = []

index = np.arange(0, 128, 64)
for i in os.listdir(valid_seismic_path):
  for j in index:
    # iline
    valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[j, :, :])
    # xline
    valid_seis_input.append(np.reshape(np.fromfile(valid_seismic_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])
    valid_fault_output.append(np.reshape(np.fromfile(valid_fault_path+'/'+i,dtype=np.single), (128, 128, 128))[:, j, :])

# %%
X_train = np.stack((train_seis_input,)*3, axis=-1)
X_test = np.stack((valid_seis_input,)*3, axis=-1)

train_mask = np.expand_dims(train_fault_output, axis=3)
y_train = tf.keras.utils.to_categorical(train_mask, num_classes=2)
test_mask = np.expand_dims(valid_fault_output, axis=3)
y_test = tf.keras.utils.to_categorical(test_mask, num_classes=2)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (800, 128, 128, 3)
# (80, 128, 128, 3)
# (800, 128, 128, 2)
# (80, 128, 128, 2)

# %%
# Normalization
def normalization(data, clip_factor=2.5):
  clipFactor = clip_factor
  std0 = np.std(data)
  stdClip = std0 * clipFactor
  clippedCube = np.clip(data, -stdClip, +stdClip)
  return np.asarray(clippedCube / stdClip, dtype='single')

# %%
X_train_norm = normalization(X_train)
X_test_norm = normalization(X_test)

# %%
fig, ax = plt.subplots(1, 2, figsize=(5,5))
ax[0].imshow(X_train_norm[1, :, :, 1].T, cmap='Greys')
ax[1].imshow(y_train[1, :, :, 1].T, cmap='Greys_r')
fig.suptitle('Training Dataset')
plt.show()

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose
from tensorflow.keras.models import Model
from keras.callbacks import EarlyStopping

# %%
batch_size = 8
image_size = 128

# %%
def down_block(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    p = keras.layers.MaxPool2D((2, 2), (2, 2))(c)
    return c, p

def up_block(x, skip, filters, kernel_size=(3, 3), padding="same", strides=1):
    us = keras.layers.UpSampling2D((2, 2))(x)
    concat = keras.layers.Concatenate()([us, skip])
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(concat)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

def bottleneck(x, filters, kernel_size=(3, 3), padding="same", strides=1):
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(x)
    c = keras.layers.Conv2D(filters, kernel_size, padding=padding, strides=strides, activation="relu")(c)
    return c

# %%
def UNet():
    f = [16, 32, 64, 128, 256]
    inputs = keras.layers.Input((image_size, image_size, 3))
    
    # encoder
    p0 = inputs
    c1, p1 = down_block(p0, f[0]) #128 -> 64
    c2, p2 = down_block(p1, f[1]) #64 -> 32
    c3, p3 = down_block(p2, f[2]) #32 -> 16
    c4, p4 = down_block(p3, f[3]) #16->8
    
    # bridge
    bn = bottleneck(p4, f[4])
    
    # decoder
    u1 = up_block(bn, c4, f[3]) #8 -> 16
    u2 = up_block(u1, c3, f[2]) #16 -> 32
    u3 = up_block(u2, c2, f[1]) #32 -> 64
    u4 = up_block(u3, c1, f[0]) #64 -> 128
    
    outputs = keras.layers.Conv2D(2, (1, 1), padding="same", activation="sigmoid")(u4)
    model = keras.models.Model(inputs, outputs)
    return model

# %%
model_unet = UNet()
model_unet.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
train_steps = len(X_train_norm)//batch_size
valid_steps = len(X_test_norm)//batch_size

# %%
history_1 = model_unet.fit(X_train_norm, 
                    y_train,
                    batch_size=batch_size, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test_norm, y_test), ) # callbacks=EarlyStopping(monitor='val_acc', mode='max',patience=10))
# Out:
# Epoch 1/100
# 100/100 [==============================] - 14s 19ms/step - loss: 0.3398 - acc: 0.9282 - val_loss: 0.2345 - val_acc: 0.9360
# Epoch 2/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.2366 - acc: 0.9307 - val_loss: 0.1902 - val_acc: 0.9360
# Epoch 3/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1929 - acc: 0.9307 - val_loss: 0.1607 - val_acc: 0.9367
# Epoch 4/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.1656 - acc: 0.9430 - val_loss: 0.1423 - val_acc: 0.9512
# Epoch 5/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1504 - acc: 0.9483 - val_loss: 0.1453 - val_acc: 0.9518
# Epoch 6/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1400 - acc: 0.9514 - val_loss: 0.1312 - val_acc: 0.9545
# Epoch 7/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.1332 - acc: 0.9532 - val_loss: 0.1278 - val_acc: 0.9555
# Epoch 8/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1282 - acc: 0.9544 - val_loss: 0.1204 - val_acc: 0.9582
# Epoch 9/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1238 - acc: 0.9553 - val_loss: 0.1177 - val_acc: 0.9585
# Epoch 10/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1174 - acc: 0.9570 - val_loss: 0.1179 - val_acc: 0.9593
# Epoch 11/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1155 - acc: 0.9574 - val_loss: 0.1198 - val_acc: 0.9587
# Epoch 12/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1100 - acc: 0.9585 - val_loss: 0.1178 - val_acc: 0.9597
# Epoch 13/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.1060 - acc: 0.9595 - val_loss: 0.1220 - val_acc: 0.9592
# Epoch 14/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.1031 - acc: 0.9602 - val_loss: 0.1202 - val_acc: 0.9588
# Epoch 15/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0993 - acc: 0.9610 - val_loss: 0.1164 - val_acc: 0.9586
# Epoch 16/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0980 - acc: 0.9613 - val_loss: 0.1165 - val_acc: 0.9597
# Epoch 17/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0907 - acc: 0.9636 - val_loss: 0.1248 - val_acc: 0.9595
# Epoch 18/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0864 - acc: 0.9647 - val_loss: 0.1275 - val_acc: 0.9608
# Epoch 19/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0838 - acc: 0.9656 - val_loss: 0.1298 - val_acc: 0.9602
# Epoch 20/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0818 - acc: 0.9661 - val_loss: 0.1282 - val_acc: 0.9579
# Epoch 21/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0861 - acc: 0.9648 - val_loss: 0.1184 - val_acc: 0.9613
# Epoch 22/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0752 - acc: 0.9685 - val_loss: 0.1295 - val_acc: 0.9601
# Epoch 23/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0707 - acc: 0.9700 - val_loss: 0.1294 - val_acc: 0.9601
# Epoch 24/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0667 - acc: 0.9716 - val_loss: 0.1381 - val_acc: 0.9608
# Epoch 25/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0648 - acc: 0.9722 - val_loss: 0.1346 - val_acc: 0.9608
# Epoch 26/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0642 - acc: 0.9725 - val_loss: 0.1434 - val_acc: 0.9610
# Epoch 27/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0677 - acc: 0.9714 - val_loss: 0.1325 - val_acc: 0.9599
# Epoch 28/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0612 - acc: 0.9738 - val_loss: 0.1529 - val_acc: 0.9608
# Epoch 29/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0575 - acc: 0.9752 - val_loss: 0.1660 - val_acc: 0.9613
# Epoch 30/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0576 - acc: 0.9752 - val_loss: 0.1550 - val_acc: 0.9607
# Epoch 31/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0552 - acc: 0.9762 - val_loss: 0.1615 - val_acc: 0.9601
# Epoch 32/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0529 - acc: 0.9772 - val_loss: 0.1700 - val_acc: 0.9603
# Epoch 33/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0528 - acc: 0.9773 - val_loss: 0.1764 - val_acc: 0.9607
# Epoch 34/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0513 - acc: 0.9780 - val_loss: 0.1785 - val_acc: 0.9594
# Epoch 35/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0515 - acc: 0.9779 - val_loss: 0.1729 - val_acc: 0.9612
# Epoch 36/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0576 - acc: 0.9757 - val_loss: 0.1437 - val_acc: 0.9593
# Epoch 37/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0564 - acc: 0.9760 - val_loss: 0.1575 - val_acc: 0.9598
# Epoch 38/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0501 - acc: 0.9785 - val_loss: 0.1760 - val_acc: 0.9600
# Epoch 39/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0459 - acc: 0.9803 - val_loss: 0.1869 - val_acc: 0.9610
# Epoch 40/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0440 - acc: 0.9812 - val_loss: 0.1854 - val_acc: 0.9609
# Epoch 41/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0429 - acc: 0.9816 - val_loss: 0.1862 - val_acc: 0.9607
# Epoch 42/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0423 - acc: 0.9820 - val_loss: 0.1931 - val_acc: 0.9607
# Epoch 43/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0407 - acc: 0.9827 - val_loss: 0.2080 - val_acc: 0.9612
# Epoch 44/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0397 - acc: 0.9831 - val_loss: 0.2158 - val_acc: 0.9607
# Epoch 45/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0394 - acc: 0.9832 - val_loss: 0.2068 - val_acc: 0.9608
# Epoch 46/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0386 - acc: 0.9835 - val_loss: 0.2282 - val_acc: 0.9611
# Epoch 47/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0385 - acc: 0.9837 - val_loss: 0.2094 - val_acc: 0.9600
# Epoch 48/100
# 100/100 [==============================] - 2s 18ms/step - loss: 0.0394 - acc: 0.9832 - val_loss: 0.2100 - val_acc: 0.9599
# Epoch 49/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0388 - acc: 0.9835 - val_loss: 0.2022 - val_acc: 0.9611
# Epoch 50/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0372 - acc: 0.9842 - val_loss: 0.1908 - val_acc: 0.9598
# Epoch 51/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0396 - acc: 0.9832 - val_loss: 0.2056 - val_acc: 0.9601
# Epoch 52/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0385 - acc: 0.9837 - val_loss: 0.1986 - val_acc: 0.9602
# Epoch 53/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0378 - acc: 0.9839 - val_loss: 0.2010 - val_acc: 0.9605
# Epoch 54/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0366 - acc: 0.9844 - val_loss: 0.2433 - val_acc: 0.9604
# Epoch 55/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0345 - acc: 0.9854 - val_loss: 0.2045 - val_acc: 0.9594
# Epoch 56/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0333 - acc: 0.9859 - val_loss: 0.2324 - val_acc: 0.9610
# Epoch 57/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0328 - acc: 0.9861 - val_loss: 0.2235 - val_acc: 0.9599
# Epoch 58/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0342 - acc: 0.9855 - val_loss: 0.2224 - val_acc: 0.9602
# Epoch 59/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0339 - acc: 0.9857 - val_loss: 0.2027 - val_acc: 0.9614
# Epoch 60/100
# 100/100 [==============================] - 2s 16ms/step - loss: 0.0373 - acc: 0.9842 - val_loss: 0.2183 - val_acc: 0.9603
# Epoch 61/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0331 - acc: 0.9860 - val_loss: 0.2384 - val_acc: 0.9608
# Epoch 62/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0319 - acc: 0.9865 - val_loss: 0.2578 - val_acc: 0.9609
# Epoch 63/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0310 - acc: 0.9869 - val_loss: 0.2522 - val_acc: 0.9609
# Epoch 64/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0309 - acc: 0.9870 - val_loss: 0.2323 - val_acc: 0.9597
# Epoch 65/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0307 - acc: 0.9870 - val_loss: 0.2615 - val_acc: 0.9616
# Epoch 66/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0318 - acc: 0.9865 - val_loss: 0.2510 - val_acc: 0.9613
# Epoch 67/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0311 - acc: 0.9868 - val_loss: 0.2357 - val_acc: 0.9607
# Epoch 68/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0306 - acc: 0.9871 - val_loss: 0.2533 - val_acc: 0.9607
# Epoch 69/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0294 - acc: 0.9876 - val_loss: 0.2517 - val_acc: 0.9611
# Epoch 70/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0288 - acc: 0.9879 - val_loss: 0.2542 - val_acc: 0.9615
# Epoch 71/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0296 - acc: 0.9875 - val_loss: 0.2531 - val_acc: 0.9611
# Epoch 72/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0292 - acc: 0.9877 - val_loss: 0.2507 - val_acc: 0.9607
# Epoch 73/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0290 - acc: 0.9877 - val_loss: 0.2325 - val_acc: 0.9603
# Epoch 74/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0293 - acc: 0.9877 - val_loss: 0.2542 - val_acc: 0.9607
# Epoch 75/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0287 - acc: 0.9879 - val_loss: 0.2518 - val_acc: 0.9606
# Epoch 76/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0283 - acc: 0.9881 - val_loss: 0.2787 - val_acc: 0.9608
# Epoch 77/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0279 - acc: 0.9882 - val_loss: 0.2517 - val_acc: 0.9605
# Epoch 78/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0279 - acc: 0.9882 - val_loss: 0.2727 - val_acc: 0.9603
# Epoch 79/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0285 - acc: 0.9880 - val_loss: 0.2642 - val_acc: 0.9604
# Epoch 80/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0285 - acc: 0.9880 - val_loss: 0.2522 - val_acc: 0.9605
# Epoch 81/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0279 - acc: 0.9883 - val_loss: 0.2915 - val_acc: 0.9611
# Epoch 82/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0267 - acc: 0.9887 - val_loss: 0.2748 - val_acc: 0.9603
# Epoch 83/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0263 - acc: 0.9889 - val_loss: 0.2753 - val_acc: 0.9610
# Epoch 84/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0257 - acc: 0.9892 - val_loss: 0.2636 - val_acc: 0.9610
# Epoch 85/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0262 - acc: 0.9889 - val_loss: 0.2747 - val_acc: 0.9612
# Epoch 86/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0265 - acc: 0.9888 - val_loss: 0.2648 - val_acc: 0.9607
# Epoch 87/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0265 - acc: 0.9888 - val_loss: 0.2614 - val_acc: 0.9603
# Epoch 88/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0260 - acc: 0.9890 - val_loss: 0.2781 - val_acc: 0.9602
# Epoch 89/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0251 - acc: 0.9894 - val_loss: 0.2798 - val_acc: 0.9609
# Epoch 90/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0256 - acc: 0.9892 - val_loss: 0.2713 - val_acc: 0.9606
# Epoch 91/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0258 - acc: 0.9891 - val_loss: 0.2548 - val_acc: 0.9603
# Epoch 92/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0339 - acc: 0.9858 - val_loss: 0.1620 - val_acc: 0.9551
# Epoch 93/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0634 - acc: 0.9750 - val_loss: 0.1553 - val_acc: 0.9570
# Epoch 94/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0501 - acc: 0.9793 - val_loss: 0.1874 - val_acc: 0.9608
# Epoch 95/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0345 - acc: 0.9854 - val_loss: 0.2050 - val_acc: 0.9610
# Epoch 96/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0289 - acc: 0.9878 - val_loss: 0.2462 - val_acc: 0.9610
# Epoch 97/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0252 - acc: 0.9894 - val_loss: 0.2678 - val_acc: 0.9614
# Epoch 98/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0236 - acc: 0.9901 - val_loss: 0.2845 - val_acc: 0.9611
# Epoch 99/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0223 - acc: 0.9907 - val_loss: 0.2692 - val_acc: 0.9609
# Epoch 100/100
# 100/100 [==============================] - 2s 17ms/step - loss: 0.0223 - acc: 0.9907 - val_loss: 0.2872 - val_acc: 0.9611

# %%
from tensorflow.keras.utils import plot_model

# %%
plot_model(model_unet)

# %%
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input
from tensorflow.keras.models import Model
from tensorflow.keras.applications import VGG19

def conv_block(input, num_filters):
    x = Conv2D(num_filters, 3, padding="same")(input)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    x = Conv2D(num_filters, 3, padding="same")(x)
    x = BatchNormalization()(x)
    x = Activation("relu")(x)

    return x

def decoder_block(input, skip_features, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    x = Concatenate()([x, skip_features])
    x = conv_block(x, num_filters)
    return x

def build_vgg19_unet(input_shape):
    """ Input """
    inputs = Input(input_shape)

    """ Pre-trained VGG19 Model """
    vgg19 = VGG19(include_top=False, weights="imagenet", input_tensor=inputs)
    
    # select trainable layers layer 1 ==> Trainable = True, else = False
    for layer in vgg19.layers[1:]:
      layer.trainable = False
    
    for layer in vgg19.layers:
      print(layer, layer.trainable)

    """ Encoder """
    s1 = vgg19.get_layer("block1_conv2").output         ## (512 x 512)
    s2 = vgg19.get_layer("block2_conv2").output         ## (256 x 256)
    s3 = vgg19.get_layer("block3_conv4").output         ## (128 x 128)
    s4 = vgg19.get_layer("block4_conv4").output         ## (64 x 64)

    """ Bridge """
    b1 = vgg19.get_layer("block5_conv4").output         ## (32 x 32)

    """ Decoder """
    d1 = decoder_block(b1, s4, 512)                     ## (64 x 64)
    d2 = decoder_block(d1, s3, 256)                     ## (128 x 128)
    d3 = decoder_block(d2, s2, 128)                     ## (256 x 256)
    d4 = decoder_block(d3, s1, 64)                      ## (512 x 512)

    """ Output """
    outputs = Conv2D(2, 1, padding="same", activation="sigmoid")(d4)

    model = Model(inputs, outputs, name="VGG19_U-Net")
    return model

# %%
input_shape = (128,128, 3)
model_unet_vgg = build_vgg19_unet(input_shape)
model_unet_vgg.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# <keras.engine.input_layer.InputLayer object at 0x7f3c300e21d0> True
# <keras.layers.convolutional.Conv2D object at 0x7f3c303cb250> False
# <keras.layers.convolutional.Conv2D object at 0x7f3c36277990> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f3bedf7ed90> False
# <keras.layers.convolutional.Conv2D object at 0x7f3c3610ba10> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedf7ee10> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f3c300dedd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedf2e550> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedf265d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedf30b90> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedf32910> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f3bedec0290> False
# <keras.layers.convolutional.Conv2D object at 0x7f3c30151110> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedf21cd0> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedecd1d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f3c36161210> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f3c300bc1d0> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bededaf10> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedf7e610> False
# <keras.layers.convolutional.Conv2D object at 0x7f3beded7490> False
# <keras.layers.convolutional.Conv2D object at 0x7f3bedfc5990> False
# <keras.layers.pooling.MaxPooling2D object at 0x7f3c300e27d0> False
# Model: "VGG19_U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  block1_conv1 (Conv2D)          (None, 128, 128, 64  1792        ['input_2[0][0]']
#                                 )
#
#  block1_conv2 (Conv2D)          (None, 128, 128, 64  36928       ['block1_conv1[0][0]']
#                                 )
#
#  block1_pool (MaxPooling2D)     (None, 64, 64, 64)   0           ['block1_conv2[0][0]']
#
#  block2_conv1 (Conv2D)          (None, 64, 64, 128)  73856       ['block1_pool[0][0]']
#
#  block2_conv2 (Conv2D)          (None, 64, 64, 128)  147584      ['block2_conv1[0][0]']
#
#  block2_pool (MaxPooling2D)     (None, 32, 32, 128)  0           ['block2_conv2[0][0]']
#
#  block3_conv1 (Conv2D)          (None, 32, 32, 256)  295168      ['block2_pool[0][0]']
#
#  block3_conv2 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv1[0][0]']
#
#  block3_conv3 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv2[0][0]']
#
#  block3_conv4 (Conv2D)          (None, 32, 32, 256)  590080      ['block3_conv3[0][0]']
#
#  block3_pool (MaxPooling2D)     (None, 16, 16, 256)  0           ['block3_conv4[0][0]']
#
#  block4_conv1 (Conv2D)          (None, 16, 16, 512)  1180160     ['block3_pool[0][0]']
#
#  block4_conv2 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv1[0][0]']
#
#  block4_conv3 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv2[0][0]']
#
#  block4_conv4 (Conv2D)          (None, 16, 16, 512)  2359808     ['block4_conv3[0][0]']
#
#  block4_pool (MaxPooling2D)     (None, 8, 8, 512)    0           ['block4_conv4[0][0]']
#
#  block5_conv1 (Conv2D)          (None, 8, 8, 512)    2359808     ['block4_pool[0][0]']
#
#  block5_conv2 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv1[0][0]']
#
#  block5_conv3 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv2[0][0]']
#
#  block5_conv4 (Conv2D)          (None, 8, 8, 512)    2359808     ['block5_conv3[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 512)  1049088    ['block5_conv4[0][0]']
#  ose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'block4_conv4[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 16, 16, 512)  4719104     ['concatenate_4[0][0]']
#
#  batch_normalization (BatchNorm  (None, 16, 16, 512)  2048       ['conv2d_19[0][0]']
#  alization)
#
#  activation (Activation)        (None, 16, 16, 512)  0           ['batch_normalization[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 16, 16, 512)  2359808     ['activation[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 16, 16, 512)  2048       ['conv2d_20[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 16, 16, 512)  0           ['batch_normalization_1[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 256)  524544     ['activation_1[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'block3_conv4[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_5[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_21[0][0]']
#  rmalization)
#
#  activation_2 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_2[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 32, 32, 256)  590080      ['activation_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 32, 32, 256)  1024       ['conv2d_22[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 32, 32, 256)  0           ['batch_normalization_3[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 128)  131200     ['activation_3[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_2[0][0]',
#                                                                   'block2_conv2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_6[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_23[0][0]']
#  rmalization)
#
#  activation_4 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 128)  147584      ['activation_4[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 64, 64, 128)  512        ['conv2d_24[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 64, 64, 128)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 64  32832      ['activation_5[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'block1_conv2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_6 (BatchNo  (None, 128, 128, 64  256        ['conv2d_25[0][0]']
#  rmalization)                   )
#
#  activation_6 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_6[0][0]']
#                                 )
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 64  36928       ['activation_6[0][0]']
#                                 )
#
#  batch_normalization_7 (BatchNo  (None, 128, 128, 64  256        ['conv2d_26[0][0]']
#  rmalization)                   )
#
#  activation_7 (Activation)      (None, 128, 128, 64  0           ['batch_normalization_7[0][0]']
#                                 )
#
#  conv2d_27 (Conv2D)             (None, 128, 128, 2)  130         ['activation_7[0][0]']
#
# ==================================================================================================
# Total params: 31,172,098
# Trainable params: 11,143,874
# Non-trainable params: 20,028,224
# __________________________________________________________________________________________________

# %%
model_unet_vgg.compile(optimizer="adam", loss="binary_crossentropy", metrics=["acc"])

# %%
plot_model(model_unet_vgg)

# %%
history_2 = model_unet_vgg.fit(X_train_norm, 
                    y_train,
                    batch_size=8, 
                    epochs=100,
                    verbose=1,
                    validation_data=(X_test_norm, y_test), ) # callbacks=EarlyStopping(monitor='val_acc', mode='max',patience=10))
# Out:
# Epoch 1/100
# 100/100 [==============================] - 8s 59ms/step - loss: 0.2797 - acc: 0.9183 - val_loss: 0.3706 - val_acc: 0.8904
# Epoch 2/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.1644 - acc: 0.9471 - val_loss: 0.1583 - val_acc: 0.9490
# Epoch 3/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.1493 - acc: 0.9501 - val_loss: 0.1454 - val_acc: 0.9523
# Epoch 4/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.1407 - acc: 0.9518 - val_loss: 0.1386 - val_acc: 0.9548
# Epoch 5/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.1337 - acc: 0.9535 - val_loss: 0.1360 - val_acc: 0.9560
# Epoch 6/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.1259 - acc: 0.9554 - val_loss: 0.1395 - val_acc: 0.9537
# Epoch 7/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.1190 - acc: 0.9573 - val_loss: 0.1323 - val_acc: 0.9542
# Epoch 8/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.1124 - acc: 0.9588 - val_loss: 0.1335 - val_acc: 0.9555
# Epoch 9/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.1035 - acc: 0.9612 - val_loss: 0.1393 - val_acc: 0.9518
# Epoch 10/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0973 - acc: 0.9630 - val_loss: 0.1445 - val_acc: 0.9549
# Epoch 11/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0867 - acc: 0.9664 - val_loss: 0.1318 - val_acc: 0.9564
# Epoch 12/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0799 - acc: 0.9687 - val_loss: 0.1462 - val_acc: 0.9533
# Epoch 13/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0755 - acc: 0.9700 - val_loss: 0.1563 - val_acc: 0.9537
# Epoch 14/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0702 - acc: 0.9720 - val_loss: 0.1538 - val_acc: 0.9539
# Epoch 15/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0643 - acc: 0.9740 - val_loss: 0.1575 - val_acc: 0.9533
# Epoch 16/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0602 - acc: 0.9755 - val_loss: 0.1758 - val_acc: 0.9525
# Epoch 17/100
# 100/100 [==============================] - 5s 55ms/step - loss: 0.0572 - acc: 0.9765 - val_loss: 0.1568 - val_acc: 0.9546
# Epoch 18/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0556 - acc: 0.9772 - val_loss: 0.1673 - val_acc: 0.9508
# Epoch 19/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0525 - acc: 0.9784 - val_loss: 0.1702 - val_acc: 0.9497
# Epoch 20/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0495 - acc: 0.9795 - val_loss: 0.1847 - val_acc: 0.9489
# Epoch 21/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0479 - acc: 0.9801 - val_loss: 0.1639 - val_acc: 0.9516
# Epoch 22/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0459 - acc: 0.9809 - val_loss: 0.1815 - val_acc: 0.9537
# Epoch 23/100
# 100/100 [==============================] - 5s 55ms/step - loss: 0.0431 - acc: 0.9821 - val_loss: 0.1925 - val_acc: 0.9508
# Epoch 24/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0436 - acc: 0.9818 - val_loss: 0.1865 - val_acc: 0.9478
# Epoch 25/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0426 - acc: 0.9823 - val_loss: 0.1809 - val_acc: 0.9517
# Epoch 26/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0404 - acc: 0.9832 - val_loss: 0.1945 - val_acc: 0.9474
# Epoch 27/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0399 - acc: 0.9834 - val_loss: 0.1921 - val_acc: 0.9532
# Epoch 28/100
# 100/100 [==============================] - 6s 56ms/step - loss: 0.0377 - acc: 0.9843 - val_loss: 0.2068 - val_acc: 0.9530
# Epoch 29/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0368 - acc: 0.9846 - val_loss: 0.2089 - val_acc: 0.9531
# Epoch 30/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0356 - acc: 0.9851 - val_loss: 0.2054 - val_acc: 0.9510
# Epoch 31/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0348 - acc: 0.9855 - val_loss: 0.2024 - val_acc: 0.9532
# Epoch 32/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0351 - acc: 0.9854 - val_loss: 0.2099 - val_acc: 0.9526
# Epoch 33/100
# 100/100 [==============================] - 6s 56ms/step - loss: 0.0337 - acc: 0.9859 - val_loss: 0.2066 - val_acc: 0.9527
# Epoch 34/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0337 - acc: 0.9859 - val_loss: 0.2160 - val_acc: 0.9503
# Epoch 35/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0329 - acc: 0.9863 - val_loss: 0.2264 - val_acc: 0.9531
# Epoch 36/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0324 - acc: 0.9864 - val_loss: 0.2149 - val_acc: 0.9496
# Epoch 37/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0322 - acc: 0.9865 - val_loss: 0.2099 - val_acc: 0.9515
# Epoch 38/100
# 100/100 [==============================] - 5s 55ms/step - loss: 0.0304 - acc: 0.9873 - val_loss: 0.2151 - val_acc: 0.9518
# Epoch 39/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0295 - acc: 0.9878 - val_loss: 0.2260 - val_acc: 0.9532
# Epoch 40/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0295 - acc: 0.9877 - val_loss: 0.2286 - val_acc: 0.9517
# Epoch 41/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0298 - acc: 0.9876 - val_loss: 0.2400 - val_acc: 0.9543
# Epoch 42/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0295 - acc: 0.9877 - val_loss: 0.2198 - val_acc: 0.9530
# Epoch 43/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0287 - acc: 0.9880 - val_loss: 0.2166 - val_acc: 0.9518
# Epoch 44/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0291 - acc: 0.9880 - val_loss: 0.2246 - val_acc: 0.9505
# Epoch 45/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0278 - acc: 0.9885 - val_loss: 0.2403 - val_acc: 0.9530
# Epoch 46/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0266 - acc: 0.9890 - val_loss: 0.2369 - val_acc: 0.9530
# Epoch 47/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0266 - acc: 0.9889 - val_loss: 0.2410 - val_acc: 0.9521
# Epoch 48/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0257 - acc: 0.9894 - val_loss: 0.2266 - val_acc: 0.9536
# Epoch 49/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0252 - acc: 0.9896 - val_loss: 0.2352 - val_acc: 0.9507
# Epoch 50/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0256 - acc: 0.9894 - val_loss: 0.2376 - val_acc: 0.9529
# Epoch 51/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0261 - acc: 0.9892 - val_loss: 0.2394 - val_acc: 0.9526
# Epoch 52/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0256 - acc: 0.9894 - val_loss: 0.2472 - val_acc: 0.9521
# Epoch 53/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0249 - acc: 0.9897 - val_loss: 0.2388 - val_acc: 0.9532
# Epoch 54/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0235 - acc: 0.9903 - val_loss: 0.2564 - val_acc: 0.9535
# Epoch 55/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0237 - acc: 0.9902 - val_loss: 0.2417 - val_acc: 0.9519
# Epoch 56/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0229 - acc: 0.9905 - val_loss: 0.2783 - val_acc: 0.9536
# Epoch 57/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0239 - acc: 0.9901 - val_loss: 0.2620 - val_acc: 0.9529
# Epoch 58/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0234 - acc: 0.9903 - val_loss: 0.2514 - val_acc: 0.9521
# Epoch 59/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0227 - acc: 0.9906 - val_loss: 0.2708 - val_acc: 0.9541
# Epoch 60/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0217 - acc: 0.9910 - val_loss: 0.2468 - val_acc: 0.9536
# Epoch 61/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0210 - acc: 0.9913 - val_loss: 0.2421 - val_acc: 0.9538
# Epoch 62/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0210 - acc: 0.9914 - val_loss: 0.2354 - val_acc: 0.9530
# Epoch 63/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0216 - acc: 0.9910 - val_loss: 0.2663 - val_acc: 0.9523
# Epoch 64/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0213 - acc: 0.9912 - val_loss: 0.2553 - val_acc: 0.9517
# Epoch 65/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0206 - acc: 0.9914 - val_loss: 0.2696 - val_acc: 0.9528
# Epoch 66/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0202 - acc: 0.9917 - val_loss: 0.2620 - val_acc: 0.9534
# Epoch 67/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0199 - acc: 0.9918 - val_loss: 0.2493 - val_acc: 0.9526
# Epoch 68/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0200 - acc: 0.9917 - val_loss: 0.2572 - val_acc: 0.9517
# Epoch 69/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0200 - acc: 0.9917 - val_loss: 0.2712 - val_acc: 0.9516
# Epoch 70/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0194 - acc: 0.9920 - val_loss: 0.2781 - val_acc: 0.9525
# Epoch 71/100
# 100/100 [==============================] - 6s 56ms/step - loss: 0.0191 - acc: 0.9922 - val_loss: 0.3057 - val_acc: 0.9528
# Epoch 72/100
# 100/100 [==============================] - 6s 56ms/step - loss: 0.0193 - acc: 0.9920 - val_loss: 0.2595 - val_acc: 0.9522
# Epoch 73/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0187 - acc: 0.9923 - val_loss: 0.2794 - val_acc: 0.9509
# Epoch 74/100
# 100/100 [==============================] - 5s 55ms/step - loss: 0.0183 - acc: 0.9924 - val_loss: 0.2891 - val_acc: 0.9537
# Epoch 75/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0181 - acc: 0.9925 - val_loss: 0.2887 - val_acc: 0.9517
# Epoch 76/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0177 - acc: 0.9927 - val_loss: 0.2876 - val_acc: 0.9533
# Epoch 77/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0173 - acc: 0.9929 - val_loss: 0.3459 - val_acc: 0.9529
# Epoch 78/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0172 - acc: 0.9929 - val_loss: 0.2812 - val_acc: 0.9524
# Epoch 79/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0172 - acc: 0.9929 - val_loss: 0.2854 - val_acc: 0.9526
# Epoch 80/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0164 - acc: 0.9933 - val_loss: 0.2997 - val_acc: 0.9530
# Epoch 81/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0162 - acc: 0.9933 - val_loss: 0.3026 - val_acc: 0.9535
# Epoch 82/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0166 - acc: 0.9931 - val_loss: 0.3126 - val_acc: 0.9537
# Epoch 83/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0170 - acc: 0.9930 - val_loss: 0.2902 - val_acc: 0.9523
# Epoch 84/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0162 - acc: 0.9933 - val_loss: 0.3163 - val_acc: 0.9540
# Epoch 85/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0162 - acc: 0.9933 - val_loss: 0.3287 - val_acc: 0.9529
# Epoch 86/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0164 - acc: 0.9933 - val_loss: 0.3256 - val_acc: 0.9523
# Epoch 87/100
# 100/100 [==============================] - 6s 56ms/step - loss: 0.0159 - acc: 0.9934 - val_loss: 0.2935 - val_acc: 0.9532
# Epoch 88/100
# 100/100 [==============================] - 6s 56ms/step - loss: 0.0157 - acc: 0.9935 - val_loss: 0.3104 - val_acc: 0.9535
# Epoch 89/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0152 - acc: 0.9938 - val_loss: 0.3296 - val_acc: 0.9535
# Epoch 90/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0159 - acc: 0.9934 - val_loss: 0.3272 - val_acc: 0.9534
# Epoch 91/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0157 - acc: 0.9935 - val_loss: 0.3160 - val_acc: 0.9534
# Epoch 92/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0171 - acc: 0.9932 - val_loss: 0.4493 - val_acc: 0.9240
# Epoch 93/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0185 - acc: 0.9925 - val_loss: 0.3184 - val_acc: 0.9534
# Epoch 94/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0147 - acc: 0.9940 - val_loss: 0.2909 - val_acc: 0.9531
# Epoch 95/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0130 - acc: 0.9947 - val_loss: 0.3121 - val_acc: 0.9536
# Epoch 96/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0126 - acc: 0.9949 - val_loss: 0.3191 - val_acc: 0.9529
# Epoch 97/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0128 - acc: 0.9948 - val_loss: 0.3251 - val_acc: 0.9532
# Epoch 98/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0130 - acc: 0.9947 - val_loss: 0.3233 - val_acc: 0.9531
# Epoch 99/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0132 - acc: 0.9946 - val_loss: 0.3346 - val_acc: 0.9524
# Epoch 100/100
# 100/100 [==============================] - 6s 55ms/step - loss: 0.0131 - acc: 0.9947 - val_loss: 0.3470 - val_acc: 0.9537

# %%
#plot the training and validation IoU and loss at each epoch
loss_1 = history_1.history['loss']
val_loss_1 = history_1.history['val_loss']
epochs = range(1, len(loss_1) + 1)
plt.plot(epochs, loss_1, 'y-', label='UNet Training loss')
plt.plot(epochs, val_loss_1, 'r-', label='UNet Validation loss')
loss_2 = history_2.history['loss']
val_loss_2 = history_2.history['val_loss']
epochs = range(1, len(loss_2) + 1)
plt.plot(epochs, loss_2, 'y--', label='UNet VGG Training loss')
plt.plot(epochs, val_loss_2, 'r--', label='UNet VGG Validation loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.ylim([0, 1])
plt.legend()
plt.show()

acc_1 = history_1.history['acc']
val_acc_1 = history_1.history['val_acc']
acc_2 = history_2.history['acc']
val_acc_2 = history_2.history['val_acc']
epochs = range(1, len(acc_1) + 1)
plt.plot(epochs, acc_1, 'y-', label='UNet Training Acc')
plt.plot(epochs, val_acc_1, 'r-', label='UNet Validation Acc')
epochs = range(1, len(acc_2) + 1)
plt.plot(epochs, acc_2, 'y--', label='UNet VGG Training Acc')
plt.plot(epochs, val_acc_2, 'r--', label='UNet VGG Validation Acc')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.ylim([0.8, 1])
plt.legend()
plt.show()

# %%
model_unet.save('/content/drive/My Drive/model_unet_1200data.h5')

# %%
model_unet_vgg.save('/content/drive/My Drive/model_unet_vgg_1200data.h5')

# %%
#Predict on the test data
y_pred_1=model_unet.predict(X_test_norm)
y_pred_argmax_1=np.argmax(y_pred_1, axis=3)
y_pred_2=model_unet_vgg.predict(X_test_norm)
y_pred_argmax_2=np.argmax(y_pred_2, axis=3)
y_test_argmax = np.argmax(y_test, axis=3)

# %%
IOU_keras_1 = MeanIoU(num_classes=2)  
IOU_keras_1.update_state(y_test_argmax, y_pred_argmax_1)
print("Mean IoU Test UNet=", IOU_keras_1.result().numpy())
IOU_keras_2 = MeanIoU(num_classes=2)  
IOU_keras_2.update_state(y_test_argmax, y_pred_argmax_2)
print("Mean IoU Test UNet VGG=", IOU_keras_2.result().numpy())
# Out:
# Mean IoU Test UNet= 0.73372614
# Mean IoU Test UNet VGG= 0.68942827

# %%
plt.figure(figsize=(15, 3))
ax1 = plt.subplot(141)
ax2 = plt.subplot(142)
ax3 = plt.subplot(143)
ax4 = plt.subplot(144)
randil = np.random.randint(0, len(X_test_norm), 1)[0]
ax1.imshow(X_test_norm[randil, : , :, 1].T)
ax2.imshow(y_test_argmax[randil, : , :].T)
ax3.imshow(y_pred_argmax_1[randil, : , :].T)
ax4.imshow(y_pred_argmax_2[randil, : , :].T)
ax1.set_title('Input')
ax2.set_title('Ground Truth')
ax3.set_title('UNet')
ax4.set_title('UNet VGG')
plt.tight_layout()
plt.show()

# %%
# Prediction
seismic = np.reshape(np.fromfile("/content/drive/MyDrive/UTP_dGB_Documents/data/prediction/f3d/gxl.dat",dtype=np.single),(512,384,128))
seismic.shape
# Out:
# (512, 384, 128)

# %%
seisnorm = normalization(seismic)

# %%
def prediction(seismic, model):
  # Append 2D seismic into 3D seismic
  predicted = []
  for i in range(512):
    val_input = seismic[i, :, :]
    patches = patchify(val_input, (128, 128), step=128)
    predicted_patches = []
    for i in range(patches.shape[0]):
      for j in range(patches.shape[1]):
        single_patch = patches[i,j,:,:]
        single_patch_3ch = np.stack((single_patch,)*3, axis=-1)
        single_patch_3ch_input = np.expand_dims(single_patch_3ch, axis=0)
        single_patch_prediction = model.predict(single_patch_3ch_input)
        single_patch_prediction_argmax = np.argmax(single_patch_prediction, axis=3)[0,:,:]
        predicted_patches.append(single_patch_prediction_argmax)
    predicted_patches_reshaped = np.reshape(predicted_patches, (patches.shape[0], patches.shape[1], patches.shape[2], patches.shape[3]))
    reconstructed_seismic = unpatchify(predicted_patches_reshaped, val_input.shape)
    predicted.append(reconstructed_seismic)
  return np.reshape(predicted, (512, 384, 128))

# %%
# def prediction(model):
#   il_range = np.arange(0, 640, 128)
#   pred_3d = []
#   for i in range(384):
#     pred_2d = []
#     for j in range(0, 4):
#       il_min = il_range[j]
#       il_max = il_range[j+1]
#       seis = seismic[il_min:il_max, i, :]
#       pred = np.stack((seis,)*3, axis=-1)
#       pred_2d.append(pred)
#     pred_3d.append(np.vstack(np.argmax(model.predict(np.array(pred_2d)), axis=3)))
#   return np.array(pred_3d).reshape(512, 384, 128)

# %%
unet_prediction = prediction(seisnorm, model_unet)

# %%
unet_vgg_prediction = prediction(seisnorm, model_unet_vgg)

# %%
ncolors = 256
color_array = plt.get_cmap('gray')(range(ncolors))
color_array[:,-1] = np.linspace(0.0,0,ncolors)
color_array[253:256] = [1, 0.0, 0., 1]
map_object = LinearSegmentedColormap.from_list(name='fault',colors=color_array)
plt.register_cmap(cmap=map_object)

# %%
vm = np.percentile(seisnorm, 99)

# %%
il = 53
xl = 86
ts = 24

fig, ax = plt.subplots(3, 2, figsize=(25, 8))
ax[0, 0].imshow(seisnorm[il,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0, 0].imshow(unet_prediction[il, :, :].T, cmap='fault')
ax[0, 0].set_title('UNet')
ax[0, 1].imshow(seisnorm[il,:,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[0, 1].imshow(unet_vgg_prediction[il, :, :].T, cmap='fault')
ax[0, 1].set_title('UNet VGG')
ax[1, 0].imshow(seisnorm[:,xl,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1, 0].imshow(unet_prediction[:, xl, :].T, cmap='fault')
ax[1, 0].set_title('UNet')
ax[1, 1].imshow(seisnorm[:,xl,:].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[1, 1].imshow(unet_vgg_prediction[:, xl, :].T, cmap='fault')
ax[1, 1].set_title('UNet VGG')
ax[2, 0].imshow(seisnorm[:,:, ts].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[2, 0].imshow(unet_prediction[:, :, ts].T, cmap='fault')
ax[2, 0].set_title('UNet')
ax[2, 1].imshow(seisnorm[:,:, ts].T, cmap='Greys', vmin=-vm, vmax=vm, interpolation='bicubic')
ax[2, 1].imshow(unet_vgg_prediction[:, :, ts].T, cmap='fault')
ax[2, 1].set_title('UNet VGG')
plt.show()

# NOTE this prediction is in INLINES only... no CROSSLINE prediction is done as of yet, no merge is being perfomed
